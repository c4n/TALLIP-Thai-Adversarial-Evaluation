# %%
# %load_ext autoreload
# %autoreload 2
import torch
import math
from pathlib import Path
import os
os.chdir("/home/datamind/can/BASIL/")
mypath = Path().absolute()
print(mypath)
from basil.select_device import device
# Out:
# /home/datamind/can/BASIL

# %%
# !pwd
# Out:
# /home/datamind/can/BASIL

# %%
torch.device(device)
# Out:
# device(type='cuda', index=1)

# %%
from pathlib import Path
import os
os.chdir("/home/datamind/can/BASIL/")
mypath = Path().absolute()
print(mypath)
# Out:
# /home/datamind/can/BASIL

# %%
affixes = r"^การ|^ความ|^นัก|^ผู้|^ไอ้|กร$|^ที่\w+|^อย่าง|^แบบ|^โดย|^น่า"

# %%
import sys
sys.path.append('/home/datamind/can/BASIL/')

# %%
import basil

# %%
from basil.select_device import device

# %%
# %autoreload 2
from basil.preprocessing.prep_best_corpus import Best2010NECTEC
from basil.models.multitasks.BiLSTM_BA import LSTMTagger
from basil.training.train_BiLSTM_BA import TrainModel
# Out:
# /home/datamind/can/BASIL/basil/preprocessing/prep_best_corpus.py:9: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   cfg = yaml.load(ymlfile)

# %%
best2010  = Best2010NECTEC()
# Out:
# Preprocessing BEST2010 corpus
# Done!

# %%
best2010.train_data[0]
# Out:
# [['นุ้ย', 'NR', 'PER_B'],
#  ['EFM', 'FWN', 'ORG_B'],
#  ['งง', 'VV', 'O'],
#  ['หยาด', 'NR', 'PER_B'],
#  [' ', 'space', 'space'],
#  ['ขู่', 'VV', 'O'],
#  ['ฟ้อง', 'VV', 'O'],
#  ['ยัน', 'VV', 'O'],
#  ['ไม่', 'NEG', 'O'],
#  ['เจตนา', 'VV', 'O'],
#  ['พาดพิง', 'VV', 'O'],
#  [' ', 'space', 'space'],
#  ["'", 'PU', 'O'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  [' ', 'space', 'space'],
#  ['EFM', 'FWN', 'ORG_B'],
#  ["'", 'PU', 'O'],
#  [' ', 'space', 'space'],
#  ['งง', 'VV', 'O'],
#  [' ', 'space', 'space'],
#  ["'", 'PU', 'O'],
#  ['หยาด', 'NR', 'PER_B'],
#  ["'", 'PU', 'O'],
#  [' ', 'space', 'space'],
#  ['ขู่', 'VV', 'O'],
#  ['ฟ้อง', 'VV', 'O'],
#  [' ', 'space', 'space'],
#  ['ยัน', 'VV', 'O'],
#  ['ไม่', 'NEG', 'O'],
#  ['เจตนา', 'VV', 'O'],
#  ['พาดพิง', 'VV', 'O'],
#  ['ใคร', 'PDEM', 'O'],
#  [' ', 'space', 'space'],
#  ['แจง', 'VV', 'O'],
#  ['หัวเราะ', 'VV', 'O'],
#  ['เปล่า', 'NN', 'O'],
#  ['เยาะเย้ย', 'NN', 'O'],
#  [' ', 'space', 'space'],
#  ['แค่', 'PDT', 'O'],
#  ['สไตล์', 'NN', 'O'],
#  ['การ', 'FXN', 'O'],
#  ['จัด', 'VV', 'O'],
#  ['รายการ', 'NN', 'O'],
#  [' ', 'space', 'space'],
#  ['หลังจาก', 'CNJ', 'O'],
#  [' ', 'space', 'space'],
#  ['นางเอก', 'NN', 'O'],
#  ['สาว', 'JJA', 'O'],
#  [' ', 'space', 'space'],
#  ['หยาดทิพย์', 'NR', 'PER_B'],
#  [' ', 'space', 'space'],
#  ['ราชปาล', 'NR', 'PER_I'],
#  [' ', 'space', 'space'],
#  ['เปรย', 'NN', 'O'],
#  [' ', 'space', 'space'],
#  ['ๆ', 'PU', 'O'],
#  [' ', 'space', 'space'],
#  ['ว่า', 'COMP', 'O'],
#  [' ', 'space', 'space'],
#  ['อยาก', 'VV', 'O'],
#  ['จะ', 'AUX', 'O'],
#  ['ให้', 'COMP', 'O'],
#  ['ทาง', 'NN', 'O'],
#  [' ', 'space', 'space'],
#  ['EFM', 'FWN', 'ORG_B'],
#  [' ', 'space', 'space'],
#  ['รับผิดชอบ', 'VV', 'O'],
#  [' ', 'space', 'space'],
#  [' ', 'space', 'space'],
#  ['หลังจาก', 'CNJ', 'O'],
#  ['ปูด', 'VV', 'O'],
#  ['ข่าว', 'NN', 'O'],
#  ['ทำ', 'VV', 'O'],
#  ['ให้', 'COMP', 'O'],
#  ['เสีย', 'VV', 'O'],
#  ['ชื่อ', 'NN', 'O'],
#  ['ไม่', 'NEG', 'O'],
#  ['เช่น', 'NN', 'O'],
#  ['นั้น', 'DDEM', 'O'],
#  ['คง', 'AUX', 'O'],
#  ['ต้อง', 'AUX', 'O'],
#  ['พึ่ง', 'VV', 'O'],
#  ['กระบวน', 'NN', 'O'],
#  ['ทาง', 'NN', 'O'],
#  ['กฎหมาย', 'NN', 'O'],
#  [' ', 'space', 'space'],
#  [' ', 'space', 'space'],
#  ['ล่าสุด', 'ADV', 'O'],
#  [' ', 'space', 'space'],
#  ['ดีเจ', 'NN', 'TTL_B'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  [' ', 'space', 'space'],
#  ['คู่', 'NN', 'O'],
#  ['กรณี', 'NN', 'O'],
#  [' ', 'space', 'space'],
#  ['ออก', 'VV', 'O'],
#  ['มา', 'VV', 'O'],
#  ['ให้', 'VV', 'O'],
#  ['สัมภาษณ์', 'VV', 'O'],
#  ['เป็น', 'VV', 'O'],
#  ['ครั้ง', 'CL', 'O'],
#  ['แรก', 'JJA', 'O'],
#  [' ', 'space', 'space'],
#  ['ถึง', 'VV', 'O'],
#  ['เรื่องราว', 'NN', 'O'],
#  ['ที่', 'COMP', 'O'],
#  ['เกิด', 'VV', 'O'],
#  ['ขึ้น', 'ADV', 'O'],
#  ['ว่า', 'NN', 'O'],
#  [' ', 'space', 'space'],
#  ['ไม่', 'NEG', 'O'],
#  ['มี', 'VV', 'O'],
#  ['เจตนา', 'VV', 'O'],
#  ['จะ', 'AUX', 'O'],
#  ['พาดพิง', 'VV', 'O'],
#  ['ใคร', 'PDEM', 'O'],
#  [' ', 'space', 'space'],
#  [' ', 'space', 'space'],
#  ['ทั้งนี้', 'CNJ', 'O'],
#  [' ', 'space', 'space'],
#  ['ทำ', 'VV', 'O'],
#  ['ทุก', 'PDT', 'O'],
#  ['อย่าง', 'CL', 'O'],
#  ['ไป', 'VV', 'O'],
#  ['ตาม', 'VV', 'O'],
#  ['หน้าที่', 'NN', 'O'],
#  ['จริง', 'JJA', 'O'],
#  [' ', 'space', 'space'],
#  ['ๆ', 'PU', 'O'],
#  [' ', 'space', 'space'],
#  ['"', 'PU', 'O'],
#  ['คือ', 'VV', 'O'],
#  ['ตอน', 'ADV', 'O'],
#  ['นี้', 'DDEM', 'O'],
#  [' ', 'space', 'space'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  [' ', 'space', 'space'],
#  ['งง', 'VV', 'O'],
#  [' ', 'space', 'space'],
#  ['กับ', 'P', 'O'],
#  ['เรื่องราว', 'NN', 'O'],
#  ['ที่', 'COMP', 'O'],
#  ['เกิด', 'VV', 'O'],
#  ['ขึ้น', 'ADV', 'O'],
#  ['เหมือน', 'ADV', 'O'],
#  ['กัน', 'REFX', 'O'],
#  [' ', 'space', 'space'],
#  ['เพราะ', 'CNJ', 'O'],
#  ['ตอน', 'NN', 'O'],
#  ['ที่', 'COMP', 'O'],
#  [' ', 'space', 'space'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  [' ', 'space', 'space'],
#  ['ทำ', 'VV', 'O'],
#  ['รายการ', 'NN', 'O'],
#  [' ', 'space', 'space'],
#  ['ก็', 'AUX', 'O'],
#  ['ทำ', 'JJV', 'O'],
#  ['หน้าที่', 'NN', 'O'],
#  ['ไป', 'VV', 'O'],
#  ['ตาม', 'VV', 'O'],
#  ['ปกติ', 'ADV', 'O'],
#  [' ', 'space', 'space'],
#  ['เพื่อ', 'CNJ', 'O'],
#  ['ความ', 'FXN', 'O'],
#  ['สนุกสนาน', 'VV', 'O'],
#  ['ตลอด', 'ADV', 'O'],
#  [' ', 'space', 'space'],
#  ['ตอน', 'NN', 'O'],
#  ['จัด', 'VV', 'O'],
#  ['รายการ', 'NN', 'O'],
#  ['ไม่', 'NEG', 'O'],
#  ['ได้', 'AUX', 'O'],
#  ['คิด', 'VV', 'O'],
#  ['ถึง', 'VV', 'O'],
#  ['ใคร', 'PINT', 'O'],
#  [' ', 'space', 'space'],
#  ['หรือ', 'CNJ', 'O'],
#  ['พูด', 'VV', 'O'],
#  ['ถึง', 'P', 'O'],
#  ['ใคร', 'PINT', 'O'],
#  [' ', 'space', 'space'],
#  ['แล้ว', 'AUX', 'O'],
#  ['ก็', 'AUX', 'O'],
#  ['ไม่', 'NEG', 'O'],
#  ['ได้', 'AUX', 'O'],
#  ['มี', 'VV', 'O'],
#  ['เจตนา', 'VV', 'O'],
#  ['จะ', 'AUX', 'O'],
#  ['เอ่ย', 'VV', 'O'],
#  ['ถึง', 'P', 'O'],
#  ['ใคร', 'PINT', 'O'],
#  ['ด้วย', 'P', 'O'],
#  [' ', 'space', 'space'],
#  [' ', 'space', 'space'],
#  ['แม้กระทั่ง', 'CNJ', 'O'],
#  ['ตอน', 'NN', 'O'],
#  ['ที่', 'COMP', 'O'],
#  ['เล่า', 'VV', 'O'],
#  [' ', 'space', 'space'],
#  ['ๆ', 'PU', 'O'],
#  [' ', 'space', 'space'],
#  ['ไป', 'VV', 'O'],
#  ['ยัง', 'P', 'O'],
#  ['หัน', 'VV', 'O'],
#  ['หน้า', 'NN', 'O'],
#  ['มอง', 'VV', 'O'],
#  ['กับ', 'P', 'O'],
#  [' ', 'space', 'space'],
#  ['พี่', 'NN', 'TTL_B'],
#  ['ปอ', 'NR', 'PER_B'],
#  ['-', 'PU', 'O'],
#  ['วรฐก์', 'NR', 'PER_B'],
#  [' ', 'space', 'space'],
#  ['ว่า', 'COMP', 'O'],
#  ['มัน', 'PPER', 'O'],
#  ['เป็น', 'VV', 'O'],
#  ['แค่', 'PDT', 'O'],
#  ['เรื่อง', 'NN', 'O'],
#  [' ', 'space', 'space'],
#  ['ๆ', 'PU', 'O'],
#  [' ', 'space', 'space'],
#  ['หนึ่ง', 'NN', 'O'],
#  ['เท่านั้น', 'ADV', 'O'],
#  ['เอง', 'REFX', 'O'],
#  [' ', 'space', 'space'],
#  [' ', 'space', 'space'],
#  ['แล้ว', 'AUX', 'O'],
#  ['เรา', 'PPER', 'O'],
#  ['สอง', 'CD', 'MEA_B'],
#  ['คน', 'CL', 'MEA_I'],
#  ['ก็', 'AUX', 'O'],
#  ['ไม่', 'NEG', 'O'],
#  ['รู้', 'VV', 'O'],
#  ['เรื่อง', 'NN', 'O'],
#  ['นี้', 'DDEM', 'O'],
#  [' ', 'space', 'space'],
#  [' ', 'space', 'space'],
#  ['แล้ว', 'AUX', 'O'],
#  ['ตอน', 'NN', 'O'],
#  ['ที่', 'COMP', 'O'],
#  ['พูด', 'VV', 'O'],
#  ['ออก', 'ADV', 'O'],
#  ['ไป', 'VV', 'O'],
#  ['ก็', 'AUX', 'O'],
#  ['ไม่', 'NEG', 'O'],
#  ['ได้', 'AUX', 'O'],
#  ['มี', 'VV', 'O'],
#  ['โอกาส', 'NN', 'O'],
#  ['จะ', 'AUX', 'O'],
#  ['นึก', 'VV', 'O'],
#  ['ถึง', 'VV', 'O'],
#  ['ใคร', 'PINT', 'O'],
#  ['ด้วย', 'P', 'O'],
#  ['ซ้ำ', 'ADV', 'O'],
#  [' ', 'space', 'space'],
#  ['เพราะ', 'CNJ', 'O'],
#  ['ต้อง', 'AUX', 'O'],
#  ['เตรียม', 'VV', 'O'],
#  ['ข่าว', 'NN', 'O'],
#  ['ต่อไป', 'ADV', 'O'],
#  [' ', 'space', 'space'],
#  ['รายการ', 'NN', 'O'],
#  ['เรา', 'PPER', 'O'],
#  ['เป็น', 'VV', 'O'],
#  ['รายการ', 'NN', 'O'],
#  ['สด', 'JJA', 'O'],
#  [' ', 'space', 'space'],
#  ['2', 'CD', 'MEA_B'],
#  [' ', 'space', 'space'],
#  ['ชั่วโมง', 'CL', 'MEA_B'],
#  [' ', 'space', 'space'],
#  [' ', 'space', 'space'],
#  ['วัน', 'NN', 'O'],
#  ['นี้', 'DDEM', 'O'],
#  [' ', 'space', 'space'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  ['อยาก', 'VV', 'O'],
#  ['ให้', 'COMP', 'O'],
#  ['ดู', 'VV', 'O'],
#  ['ที่', 'P', 'O'],
#  ['เจตนา', 'VV', 'O'],
#  ['มาก', 'ADV', 'O'],
#  ['กว่า', 'ADV', 'O'],
#  [' ', 'space', 'space'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  ['ยืนยัน', 'VV', 'O'],
#  ['ว่า', 'COMP', 'O'],
#  [' ', 'space', 'space'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  ['ไม่', 'NEG', 'O'],
#  ['ได้', 'AUX', 'O'],
#  ['เอ่ย', 'VV', 'O'],
#  ['ถึง', 'P', 'O'],
#  ['ใคร', 'PDEM', 'O'],
#  ['เลย', 'PAR', 'O'],
#  ['แม้', 'CNJ', 'O'],
#  ['ซัก', 'VV', 'O'],
#  ['คน', 'CL', 'O'],
#  ['เดียว', 'CD', 'NUM_B'],
#  ['"', 'PU', 'O'],
#  [' ', 'space', 'space'],
#  ['แล้ว', 'AUX', 'O'],
#  ['ที่', 'COMP', 'O'],
#  ['หยาด', 'NR', 'PER_B'],
#  ['พูด', 'VV', 'O'],
#  ['ถึง', 'VV', 'O'],
#  ['เรื่อง', 'NN', 'O'],
#  ['ฟ้อง', 'VV', 'O'],
#  ['ล่ะ', 'PAR', 'O'],
#  [' ', 'space', 'space'],
#  [' ', 'space', 'space'],
#  ['"', 'PU', 'O'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  ['คิด', 'VV', 'O'],
#  ['ว่า', 'COMP', 'O'],
#  ['ไม่', 'NEG', 'O'],
#  ['น่า', 'AUX', 'O'],
#  ['จะ', 'AUX', 'O'],
#  ['ใหญ่โต', 'VA', 'O'],
#  [' ', 'space', 'space'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  ['ขอ', 'VV', 'O'],
#  ['ยืนยัน', 'VV', 'O'],
#  [' ', 'space', 'space'],
#  ['เรา', 'PPER', 'O'],
#  ['มี', 'VV', 'O'],
#  ['ใจ', 'NN', 'O'],
#  ['บริสุทธิ์', 'JJA', 'O'],
#  ['ไม่', 'NEG', 'O'],
#  ['ได้', 'AUX', 'O'],
#  ['มี', 'VV', 'O'],
#  ['เจตนา', 'VV', 'O'],
#  ['จะ', 'AUX', 'O'],
#  ['พูด', 'VV', 'O'],
#  ['ถึง', 'VV', 'O'],
#  ['ใคร', 'PDEM', 'O'],
#  ['เลย', 'PAR', 'O'],
#  ['ครับ', 'PAR', 'O'],
#  ['"', 'PU', 'O'],
#  [' ', 'space', 'space'],
#  [' ', 'space', 'space'],
#  ['จะ', 'AUX', 'O'],
#  ['มี', 'VV', 'O'],
#  ['การ', 'FXN', 'O'],
#  ['ขอโทษ', 'VV', 'O'],
#  ['กัน', 'REFX', 'O'],
#  ['มั้ย', 'PAR', 'O'],
#  [' ', 'space', 'space'],
#  [' ', 'space', 'space'],
#  ['"', 'PU', 'O'],
#  ['อย่าง', 'FXAV', 'O'],
#  ['ที่', 'COMP', 'O'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  ['บอก', 'VV', 'O'],
#  ['ไป', 'VV', 'O'],
#  ['ว่า', 'COMP', 'O'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  ['ไม่', 'NEG', 'O'],
#  ['ได้', 'AUX', 'O'],
#  ['เอ่ย', 'VV', 'O'],
#  ['เรา', 'PPER', 'O'],
#  ['กุ', 'VV', 'O'],
#  ['ข่าว', 'NN', 'O'],
#  ['ขึ้น', 'ADV', 'O'],
#  ['มา', 'VV', 'O'],
#  ['หรือ', 'CNJ', 'O'],
#  ['เปล่า', 'PINT', 'O'],
#  [' ', 'space', 'space'],
#  ['"', 'PU', 'O'],
#  [' ', 'space', 'space'],
#  ['รายการ', 'NN', 'O'],
#  ['ของ', 'P', 'O'],
#  ['เรา', 'DPER', 'O'],
#  ['เป็น', 'VV', 'O'],
#  ['เรื่องราว', 'NN', 'O'],
#  ['ที่', 'COMP', 'O'],
#  ['ให้', 'COMP', 'O'],
#  ['สีสัน', 'VV', 'O'],
#  ['กับ', 'P', 'O'],
#  ['วงการ', 'NN', 'ORG_B'],
#  ['บันเทิง', 'NN', 'ORG_I'],
#  [' ', 'space', 'space'],
#  ['สนุกสนาน', 'ADV', 'O'],
#  [' ', 'space', 'space'],
#  ['แล้ว', 'AUX', 'O'],
#  ['ใน', 'P', 'O'],
#  ['ส่วน', 'NN', 'O'],
#  ['ของ', 'P', 'O'],
#  ['ข่าว', 'NN', 'O'],
#  ['ก็', 'AUX', 'O'],
#  ['อยู่', 'VV', 'O'],
#  ['ใน', 'P', 'O'],
#  ['กระบวนการ', 'NN', 'O'],
#  [' ', 'space', 'space'],
#  ['การ', 'FXN', 'O'],
#  ['ทำ', 'VV', 'O'],
#  ['ข่าว', 'NN', 'O'],
#  [' ', 'space', 'space'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  ['ไม่', 'NEG', 'O'],
#  ['ขอ', 'VV', 'O'],
#  ['ลง', 'VV', 'O'],
#  ['ลึก', 'ADV', 'O'],
#  ['ดี', 'ADV', 'O'],
#  ['กว่า', 'ADV', 'O'],
#  ['ครับ', 'PAR', 'O'],
#  ['"', 'PU', 'O'],
#  [' ', 'space', 'space'],
#  [' ', 'space', 'space'],
#  ['หยาด', 'NR', 'PER_B'],
#  ['และ', 'CNJ', 'O'],
#  ['คุณ', 'NN', 'O'],
#  ['แม่', 'NN', 'O'],
#  ['ไม่', 'NEG', 'O'],
#  ['พอใจ', 'VV', 'O'],
#  [' ', 'space', 'space'],
#  ['ตรง', 'P', 'O'],
#  ['ที่', 'COMP', 'O'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  ['พูด', 'VV', 'O'],
#  ['ไป', 'VV', 'O'],
#  ['หัวเราะ', 'VV', 'O'],
#  ['ไป', 'VV', 'O'],
#  [' ', 'space', 'space'],
#  ['เหมือน', 'ADV', 'O'],
#  ['ไป', 'VV', 'O'],
#  ['เยาะเย้ย', 'VV', 'O'],
#  ['เค้า', 'NN', 'O'],
#  [' ', 'space', 'space'],
#  [' ', 'space', 'space'],
#  ['"', 'PU', 'O'],
#  ['เกี่ยว', 'P', 'O'],
#  ['กับ', 'P', 'O'],
#  ['เรื่อง', 'NN', 'O'],
#  ['หัวเราะ', 'NN', 'O'],
#  [' ', 'space', 'space'],
#  ['ถ้า', 'CNJ', 'O'],
#  ['ใคร', 'PDEM', 'O'],
#  ['ฟัง', 'VV', 'O'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  ['ตั้งแต่', 'P', 'O'],
#  ['ตอน', 'NN', 'O'],
#  ['จัด', 'VV', 'O'],
#  ['รายการ', 'NN', 'O'],
#  ['ใหม่', 'JJA', 'O'],
#  [' ', 'space', 'space'],
#  ['ๆ', 'PU', 'O'],
#  [' ', 'space', 'space'],
#  ['ก็', 'AUX', 'O'],
#  ['จะ', 'AUX', 'O'],
#  ['รู้', 'VV', 'O'],
#  ['ว่า', 'COMP', 'O'],
#  [' ', 'space', 'space'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  ['จะ', 'AUX', 'O'],
#  ['หัวเราะ', 'VV', 'O'],
#  ['ตลอด', 'ADV', 'O'],
#  ['การ', 'FXN', 'O'],
#  ['จัด', 'VV', 'O'],
#  ['รายการ', 'NN', 'O'],
#  ['อยู่แล้ว', 'ADV', 'O'],
#  [' ', 'space', 'space'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  ['เป็น', 'VV', 'O'],
#  ['คน', 'NN', 'O'],
#  ['อารมณ์', 'NN', 'O'],
#  ['ดี', 'ADV', 'O'],
#  ['ครับ', 'PAR', 'O'],
#  [' ', 'space', 'space'],
#  ['พูด', 'VV', 'O'],
#  ['ไป', 'VV', 'O'],
#  ['ขำ', 'VV', 'O'],
#  ['ไป', 'VV', 'O'],
#  [' ', 'space', 'space'],
#  ['เป็น', 'VV', 'O'],
#  ['สไตล์', 'NN', 'O'],
#  ['การ', 'FXN', 'O'],
#  ['จัด', 'VV', 'O'],
#  ['ของ', 'P', 'O'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  ['อยู่แล้ว', 'ADV', 'O'],
#  [' ', 'space', 'space'],
#  ['ตอน', 'NN', 'O'],
#  ['แรก', 'ADV', 'O'],
#  [' ', 'space', 'space'],
#  ['ๆ', 'PU', 'O'],
#  [' ', 'space', 'space'],
#  ['คน', 'CL', 'O'],
#  ['ก็', 'AUX', 'O'],
#  ['ติง', 'VV', 'O'],
#  ['ว่า', 'COMP', 'O'],
#  [' ', 'space', 'space'],
#  ['หัวเราะ', 'VV', 'O'],
#  ['เยอะ', 'ADV', 'O'],
#  ['ไป', 'VV', 'O'],
#  [' ', 'space', 'space'],
#  ['พอ', 'P', 'O'],
#  ['หลัง', 'CNJ', 'O'],
#  [' ', 'space', 'space'],
#  ['ๆ', 'PU', 'O'],
#  [' ', 'space', 'space'],
#  ['หัวเราะ', 'VV', 'O'],
#  ['น้อย', 'ADV', 'O'],
#  ['ลง', 'VV', 'O'],
#  ['ก็', 'AUX', 'O'],
#  ['บอก', 'VV', 'O'],
#  ['ว่า', 'COMP', 'O'],
#  [' ', 'space', 'space'],
#  ['หัวเราะ', 'VV', 'O'],
#  ['อีก', 'ADV', 'O'],
#  ['ได้', 'AUX', 'O'],
#  ['มั้ย', 'PAR', 'O'],
#  [' ', 'space', 'space'],
#  ['ชอบ', 'VV', 'O'],
#  ['เสียง', 'NN', 'O'],
#  ['หัวเราะ', 'VV', 'O'],
#  [' ', 'space', 'space'],
#  ['มัน', 'PPER', 'O'],
#  ['เป็น', 'VV', 'O'],
#  ['ธรรมชาติ', 'NN', 'O'],
#  ['ของ', 'P', 'O'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  ['ครับ', 'PAR', 'O'],
#  ['"', 'PU', 'O'],
#  [' ', 'space', 'space'],
#  [' ', 'space', 'space'],
#  ['จะ', 'AUX', 'O'],
#  ['ทำ', 'VV', 'O'],
#  ['ให้', 'COMP', 'O'],
#  ['ลด', 'VV', 'O'],
#  ['ความ', 'FXN', 'O'],
#  ['หวือหวา', 'VV', 'O'],
#  ['ใน', 'P', 'O'],
#  ['การ', 'FXN', 'O'],
#  ['จัด', 'VV', 'O'],
#  ['รายการ', 'NN', 'O'],
#  ['มั้ย', 'PAR', 'O'],
#  [' ', 'space', 'space'],
#  [' ', 'space', 'space'],
#  ['"', 'PU', 'O'],
#  ['แต่ละ', 'PDT', 'O'],
#  ['คน', 'CL', 'O'],
#  ['ก็', 'AUX', 'O'],
#  ['มี', 'VV', 'O'],
#  ['สไตล์', 'NN', 'O'],
#  ['การ', 'FXN', 'O'],
#  ['จัด', 'VV', 'O'],
#  ['รายการ', 'NN', 'O'],
#  ['ที่', 'COMP', 'O'],
#  ['แตกต่าง', 'VV', 'O'],
#  ['กัน', 'REFX', 'O'],
#  ['ไป', 'VV', 'O'],
#  [' ', 'space', 'space'],
#  ['ดีเจ', 'NN', 'O'],
#  ['ก็', 'AUX', 'O'],
#  ['มี', 'VV', 'O'],
#  ['หลาย', 'PDT', 'O'],
#  ['คน', 'CL', 'O'],
#  [' ', 'space', 'space'],
#  ['เพราะฉะนั้น', 'CNJ', 'O'],
#  ['การ', 'FXN', 'O'],
#  ['จัด', 'VV', 'O'],
#  ['รายการ', 'NN', 'O'],
#  ['ก็', 'AUX', 'O'],
#  ['คง', 'AUX', 'O'],
#  ['เหมือน', 'ADV', 'O'],
#  ['เดิม', 'ADV', 'O'],
#  [' ', 'space', 'space'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  ['ก็', 'CNJ', 'O'],
#  ['ยัง', 'AUX', 'O'],
#  ['จัด', 'VV', 'O'],
#  ['รายการ', 'NN', 'O'],
#  ['เหมือน', 'VV', 'O'],
#  ['เดิม', 'ADV', 'O'],
#  [' ', 'space', 'space'],
#  ['แล้ว', 'AUX', 'O'],
#  ['ก็', 'AUX', 'O'],
#  ['ออก', 'VV', 'O'],
#  ['ทำ', 'VV', 'O'],
#  ['ข่าว', 'NN', 'O'],
#  ['ตาม', 'VV', 'O'],
#  ['ปกติ', 'ADV', 'O'],
#  ['"', 'PU', 'O'],
#  [' ', 'space', 'space'],
#  [' ', 'space', 'space'],
#  ['พี่', 'NN', 'TTL_B'],
#  ['ฉอด', 'NR', 'PER_B'],
#  ['-', 'PU', 'O'],
#  ['สายทิพย์', 'NR', 'PER_B'],
#  [' ', 'space', 'space'],
#  ['ให้', 'COMP', 'O'],
#  ['คำ', 'NN', 'O'],
#  ['แนะนำ', 'JJV', 'O'],
#  ['อย่าง', 'FXAV', 'O'],
#  ['ไร', 'PDEM', 'O'],
#  ['บ้าง', 'PDEM', 'O'],
#  [' ', 'space', 'space'],
#  [' ', 'space', 'space'],
#  ['"', 'PU', 'O'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  ['ไม่', 'NEG', 'O'],
#  ['อยาก', 'VV', 'O'],
#  ['จะ', 'AUX', 'O'],
#  ['พาดพิง', 'VV', 'O'],
#  ['ถึง', 'VV', 'O'],
#  [' ', 'space', 'space'],
#  ['เพราะ', 'CNJ', 'O'],
#  ['ท่าน', 'PPER', 'O'],
#  ['เอง', 'REFX', 'O'],
#  ['ก็', 'AUX', 'O'],
#  ['ไม่', 'NEG', 'O'],
#  ['ได้', 'AUX', 'O'],
#  ['ลง', 'VV', 'O'],
#  ['มา', 'VV', 'O'],
#  ['ข้อง', 'VV', 'O'],
#  ['เกี่ยว', 'P', 'O'],
#  ['กับ', 'P', 'O'],
#  ['ตรง', 'NN', 'O'],
#  ['นี้', 'DDEM', 'O'],
#  [' ', 'space', 'space'],
#  ['ก็', 'AUX', 'O'],
#  ['ไม่', 'NEG', 'O'],
#  ['มี', 'VV', 'O'],
#  ['ใคร', 'PDEM', 'O'],
#  ['แนะนำ', 'VV', 'O'],
#  ['อะไร', 'PDEM', 'O'],
#  ['มาก', 'JJA', 'O'],
#  [' ', 'space', 'space'],
#  ['เพราะ', 'CNJ', 'O'],
#  ['เป็น', 'VV', 'O'],
#  ['เรื่อง', 'NN', 'O'],
#  ['ที่', 'COMP', 'O'],
#  ['เกิด', 'VV', 'O'],
#  ['ขึ้น', 'ADV', 'O'],
#  ['ภาย', 'NN', 'O'],
#  ['ใน', 'P', 'O'],
#  ['คลื่น', 'NN', 'O'],
#  ['เรา', 'PPER', 'O'],
#  [' ', 'space', 'space'],
#  ['แต่', 'CNJ', 'O'],
#  ['ถ้า', 'CNJ', 'O'],
#  ['เกิด', 'VV', 'O'],
#  ['อะไร', 'PDEM', 'O'],
#  ['ขึ้น', 'ADV', 'O'],
#  ['จริง', 'ADV', 'O'],
#  ['ๆ', 'PU', 'O'],
#  [' ', 'space', 'space'],
#  ['คง', 'AUX', 'O'],
#  ['ต้อง', 'AUX', 'O'],
#  ['ปรึกษา', 'VV', 'O'],
#  ['กับ', 'P', 'O'],
#  ['ผู้', 'FXN', 'O'],
#  ['ใหญ่', 'JJA', 'O'],
#  ['อีก', 'ADV', 'O'],
#  ['ที', 'ADV', 'O'],
#  ['ครับ', 'PAR', 'O'],
#  ['"', 'PU', 'O'],
#  [' ', 'space', 'space'],
#  [' ', 'space', 'space'],
#  ['ถึง', 'VV', 'O'],
#  ['ใคร', 'PINT', 'O'],
#  [' ', 'space', 'space'],
#  ['ก็', 'AUX', 'O'],
#  ['เลย', 'PAR', 'O'],
#  ['ไม่', 'NEG', 'O'],
#  ['รู้', 'VV', 'O'],
#  ['ว่า', 'COMP', 'O'],
#  [' ', 'space', 'space'],
#  ['จะ', 'AUX', 'O'],
#  ['ต้อง', 'AUX', 'O'],
#  ['ไป', 'VV', 'O'],
#  ['ขอโทษ', 'VV', 'O'],
#  ['ใคร', 'PDEM', 'O'],
#  ['เหมือน', 'ADV', 'O'],
#  ['กัน', 'REFX', 'O'],
#  [' ', 'space', 'space'],
#  ['เพราะ', 'CNJ', 'O'],
#  ['ไม่', 'NEG', 'O'],
#  ['ได้', 'AUX', 'O'],
#  ['มี', 'VV', 'O'],
#  ['เจตนา', 'VV', 'O'],
#  ['ตรง', 'P', 'O'],
#  ['นั้น', 'DDEM', 'O'],
#  [' ', 'space', 'space'],
#  [' ', 'space', 'space'],
#  ['การ', 'NN', 'O'],
#  ['ที่', 'COMP', 'O'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  ['พูด', 'VV', 'O'],
#  ['ออก', 'ADV', 'O'],
#  ['ไป', 'VV', 'O'],
#  ['ใคร', 'PINT', 'O'],
#  ['จะ', 'AUX', 'O'],
#  ['ไป', 'VV', 'O'],
#  ['คิด', 'VV', 'O'],
#  ['หรือ', 'CNJ', 'O'],
#  ['ตีความ', 'VV', 'O'],
#  ['ต่อ', 'ADV', 'O'],
#  ['ก็', 'AUX', 'O'],
#  ['เป็น', 'VV', 'O'],
#  ['สิทธิ', 'NN', 'O'],
#  ['ส่วน', 'NN', 'O'],
#  ['บุคคล', 'NN', 'O'],
#  ['อยู่แล้ว', 'ADV', 'O'],
#  ['ไง', 'PINT', 'O'],
#  ['ครับ', 'PAR', 'O'],
#  [' ', 'space', 'space'],
#  [' ', 'space', 'space'],
#  ['อยาก', 'VV', 'O'],
#  ['ให้', 'COMP', 'O'],
#  ['ทุก', 'PDT', 'O'],
#  ['คน', 'CL', 'O'],
#  ['ได้', 'AUX', 'O'],
#  ['ย้อนกลับ', 'VV', 'O'],
#  ['ไป', 'VV', 'O'],
#  ['ฟัง', 'VV', 'O'],
#  ['รายการ', 'NN', 'O'],
#  [' ', 'space', 'space'],
#  ['วัน', 'NN', 'O'],
#  ['นั้น', 'DDEM', 'O'],
#  ['พูด', 'VV', 'O'],
#  ['กว้าง', 'ADV', 'O'],
#  ['มาก', 'ADV', 'O'],
#  [' ', 'space', 'space'],
#  ['ไม่', 'NEG', 'O'],
#  ['ได้', 'AUX', 'O'],
#  ['ชี้', 'VV', 'O'],
#  ['ชัด', 'ADV', 'O'],
#  ['ระบุ', 'VV', 'O'],
#  ['ไป', 'VV', 'O'],
#  ['ที่', 'P', 'O'],
#  ['ใคร', 'PDEM', 'O'],
#  ['พูด', 'VV', 'O'],
#  ['แค่', 'PDT', 'O'],
#  ['ว่า', 'COMP', 'O'],
#  [' ', 'space', 'space'],
#  ['นางเอก', 'NN', 'O'],
#  ['หน้า', 'P', 'O'],
#  ['คม', 'NN', 'O'],
#  ['คน', 'CL', 'O'],
#  ['หนึ่ง', 'NN', 'O'],
#  ['เท่านั้น', 'ADV', 'O'],
#  ['เอง', 'REFX', 'O'],
#  ['ครับ', 'PAR', 'O'],
#  ['"', 'PU', 'O'],
#  ['\n', 'space', 'space']]

# %%
trainer = TrainModel(LSTMTagger, best2010,1)
trainer.train(40)
# Out:
# Training
# Num of training text file: 4975
#  epoch 0: 67m 42s loss:0.6702 accuracy POS:0.8899 accuracy NER:0.8990epoch: 0
# F1 (POS): 0.9437235068174514 F1 (NER) 0.7548343663672029
#  epoch 1: 135m 22s loss:0.4469 accuracy POS:0.9039 accuracy NER:0.9527epoch: 1
# F1 (POS): 0.951482087930586 F1 (NER) 0.791063244729606
#  epoch 2: 202m 42s loss:0.5822 accuracy POS:0.8868 accuracy NER:0.9009epoch: 2
# F1 (POS): 0.9550017598359527 F1 (NER) 0.7993966128036933
#  epoch 3: 270m 0s loss:0.4015 accuracy POS:0.9202 accuracy NER:0.95564epoch: 3
# F1 (POS): 0.9570753056758535 F1 (NER) 0.8071556023241981
#  epoch 4: 337m 20s loss:0.5096 accuracy POS:0.9031 accuracy NER:0.9104epoch: 4
# F1 (POS): 0.9574731816303732 F1 (NER) 0.8087188203408516
#  epoch 5: 404m 37s loss:0.3442 accuracy POS:0.9194 accuracy NER:0.9593epoch: 5
# F1 (POS): 0.9583377966853872 F1 (NER) 0.8129313309641178
#  epoch 6: 471m 57s loss:0.4818 accuracy POS:0.9050 accuracy NER:0.9281epoch: 6
# F1 (POS): 0.9585214317413194 F1 (NER) 0.8129142120765832
#  epoch 7: 539m 16s loss:0.3445 accuracy POS:0.9372 accuracy NER:0.9497epoch: 7
# F1 (POS): 0.9593018807290312 F1 (NER) 0.8161471920911713
#  epoch 8: 606m 41s loss:0.4818 accuracy POS:0.8990 accuracy NER:0.9340epoch: 8
# F1 (POS): 0.9594778643242995 F1 (NER) 0.8161529798432507
#  epoch 9: 673m 59s loss:0.3911 accuracy POS:0.9224 accuracy NER:0.9497epoch: 9
# F1 (POS): 0.9598604373574915 F1 (NER) 0.8172858225928735
#  epoch 10: 741m 22s loss:0.4662 accuracy POS:0.9109 accuracy NER:0.9277epoch: 10
# F1 (POS): 0.9603883881432965 F1 (NER) 0.8181090293505365
#  epoch 11: 808m 42s loss:0.3759 accuracy POS:0.9180 accuracy NER:0.9564epoch: 11
# F1 (POS): 0.9601129355593983 F1 (NER) 0.8214513049013367
#  epoch 12: 876m 9s loss:0.4348 accuracy POS:0.9122 accuracy NER:0.93818epoch: 12
# F1 (POS): 0.9604955085925904 F1 (NER) 0.8186263309418269
#  epoch 13: 943m 33s loss:0.3689 accuracy POS:0.9224 accuracy NER:0.9549epoch: 13
# F1 (POS): 0.9601971016267006 F1 (NER) 0.8198945679578272
#  epoch 14: 1011m 4s loss:0.4431 accuracy POS:0.9018 accuracy NER:0.95226epoch: 14
# F1 (POS): 0.9602583133120113 F1 (NER) 0.8201379688427979
#  epoch 15: 1078m 25s loss:0.3822 accuracy POS:0.9121 accuracy NER:0.9608epoch: 15
# F1 (POS): 0.9609392933110931 F1 (NER) 0.822984625211004
#  epoch 16: 1145m 49s loss:0.4364 accuracy POS:0.9072 accuracy NER:0.9518epoch: 16
# F1 (POS): 0.9608398243224632 F1 (NER) 0.8210665391011186
#  epoch 17: 1213m 6s loss:0.3430 accuracy POS:0.9224 accuracy NER:0.96977epoch: 17
# F1 (POS): 0.9605337658959096 F1 (NER) 0.8207592067988669
#  epoch 18: 1245m 52s loss:0.2691 accuracy POS:0.9572 accuracy NER:0.9653

# %%
trainer = TrainModel(LSTMTagger, best2010,2)
trainer.train(40)

# %%
trainer = TrainModel(LSTMTagger, best2010,3)
trainer.train(40)

# %%
filehandle = open('done_bilstm_ba_no_clp.txt', 'w')
filehandle.write('Hello, world!\n')
filehandle.close()
