# %%
# %load_ext autoreload
# %autoreload 2
import torch
import math
from pathlib import Path
import os
os.chdir("/home/datamind/can/BASIL/")
mypath = Path().absolute()
print(mypath)
from basil.select_device import device
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# /home/datamind/can/BASIL

# %%
# !pwd
# Out:
# /home/datamind/can/BASIL

# %%
torch.device(device)
# Out:
# device(type='cuda', index=0)

# %%
from pathlib import Path
import os
os.chdir("/home/datamind/can/BASIL/")
mypath = Path().absolute()
print(mypath)
# Out:
# /home/datamind/can/BASIL

# %%
affixes = r"^การ|^ความ|^นัก|^ผู้|^ไอ้|กร$|^ที่\w+|^อย่าง|^แบบ|^โดย|^น่า"

# %%
import sys
sys.path.append('/root/can/TALLIP/BASIL/')

# %%
import basil

# %%
from basil.select_device import device

# %%
# %autoreload 2
from basil.preprocessing.prep_best_corpus import Best2010NECTEC, BestSyllable2010NECTEC
from basil.preprocessing.prep_pytorch_syllable import PytorchPrepWordLevelWithSyllable
from basil.models.multitasks.wordlvl_lstm import LSTMTagger
from basil.training.train_word_lvl_unk import TrainModel

# %%
best2010  = Best2010NECTEC()
# Out:
# Preprocessing BEST2010 corpus
# Done!

# %%
best2010.train_data[0]
# Out:
# [['นุ้ย', 'NR', 'PER_B'],
#  ['EFM', 'FWN', 'ORG_B'],
#  ['งง', 'VV', 'O'],
#  ['หยาด', 'NR', 'PER_B'],
#  [' ', 'space', 'space'],
#  ['ขู่', 'VV', 'O'],
#  ['ฟ้อง', 'VV', 'O'],
#  ['ยัน', 'VV', 'O'],
#  ['ไม่', 'NEG', 'O'],
#  ['เจตนา', 'VV', 'O'],
#  ['พาดพิง', 'VV', 'O'],
#  [' ', 'space', 'space'],
#  ["'", 'PU', 'O'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  [' ', 'space', 'space'],
#  ['EFM', 'FWN', 'ORG_B'],
#  ["'", 'PU', 'O'],
#  [' ', 'space', 'space'],
#  ['งง', 'VV', 'O'],
#  [' ', 'space', 'space'],
#  ["'", 'PU', 'O'],
#  ['หยาด', 'NR', 'PER_B'],
#  ["'", 'PU', 'O'],
#  [' ', 'space', 'space'],
#  ['ขู่', 'VV', 'O'],
#  ['ฟ้อง', 'VV', 'O'],
#  [' ', 'space', 'space'],
#  ['ยัน', 'VV', 'O'],
#  ['ไม่', 'NEG', 'O'],
#  ['เจตนา', 'VV', 'O'],
#  ['พาดพิง', 'VV', 'O'],
#  ['ใคร', 'PDEM', 'O'],
#  [' ', 'space', 'space'],
#  ['แจง', 'VV', 'O'],
#  ['หัวเราะ', 'VV', 'O'],
#  ['เปล่า', 'NN', 'O'],
#  ['เยาะเย้ย', 'NN', 'O'],
#  [' ', 'space', 'space'],
#  ['แค่', 'PDT', 'O'],
#  ['สไตล์', 'NN', 'O'],
#  ['การ', 'FXN', 'O'],
#  ['จัด', 'VV', 'O'],
#  ['รายการ', 'NN', 'O'],
#  [' ', 'space', 'space'],
#  ['หลังจาก', 'CNJ', 'O'],
#  [' ', 'space', 'space'],
#  ['นางเอก', 'NN', 'O'],
#  ['สาว', 'JJA', 'O'],
#  [' ', 'space', 'space'],
#  ['หยาดทิพย์', 'NR', 'PER_B'],
#  [' ', 'space', 'space'],
#  ['ราชปาล', 'NR', 'PER_I'],
#  [' ', 'space', 'space'],
#  ['เปรย', 'NN', 'O'],
#  [' ', 'space', 'space'],
#  ['ๆ', 'PU', 'O'],
#  [' ', 'space', 'space'],
#  ['ว่า', 'COMP', 'O'],
#  [' ', 'space', 'space'],
#  ['อยาก', 'VV', 'O'],
#  ['จะ', 'AUX', 'O'],
#  ['ให้', 'COMP', 'O'],
#  ['ทาง', 'NN', 'O'],
#  [' ', 'space', 'space'],
#  ['EFM', 'FWN', 'ORG_B'],
#  [' ', 'space', 'space'],
#  ['รับผิดชอบ', 'VV', 'O'],
#  [' ', 'space', 'space'],
#  [' ', 'space', 'space'],
#  ['หลังจาก', 'CNJ', 'O'],
#  ['ปูด', 'VV', 'O'],
#  ['ข่าว', 'NN', 'O'],
#  ['ทำ', 'VV', 'O'],
#  ['ให้', 'COMP', 'O'],
#  ['เสีย', 'VV', 'O'],
#  ['ชื่อ', 'NN', 'O'],
#  ['ไม่', 'NEG', 'O'],
#  ['เช่น', 'NN', 'O'],
#  ['นั้น', 'DDEM', 'O'],
#  ['คง', 'AUX', 'O'],
#  ['ต้อง', 'AUX', 'O'],
#  ['พึ่ง', 'VV', 'O'],
#  ['กระบวน', 'NN', 'O'],
#  ['ทาง', 'NN', 'O'],
#  ['กฎหมาย', 'NN', 'O'],
#  [' ', 'space', 'space'],
#  [' ', 'space', 'space'],
#  ['ล่าสุด', 'ADV', 'O'],
#  [' ', 'space', 'space'],
#  ['ดีเจ', 'NN', 'TTL_B'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  [' ', 'space', 'space'],
#  ['คู่', 'NN', 'O'],
#  ['กรณี', 'NN', 'O'],
#  [' ', 'space', 'space'],
#  ['ออก', 'VV', 'O'],
#  ['มา', 'VV', 'O'],
#  ['ให้', 'VV', 'O'],
#  ['สัมภาษณ์', 'VV', 'O'],
#  ['เป็น', 'VV', 'O'],
#  ['ครั้ง', 'CL', 'O'],
#  ['แรก', 'JJA', 'O'],
#  [' ', 'space', 'space'],
#  ['ถึง', 'VV', 'O'],
#  ['เรื่องราว', 'NN', 'O'],
#  ['ที่', 'COMP', 'O'],
#  ['เกิด', 'VV', 'O'],
#  ['ขึ้น', 'ADV', 'O'],
#  ['ว่า', 'NN', 'O'],
#  [' ', 'space', 'space'],
#  ['ไม่', 'NEG', 'O'],
#  ['มี', 'VV', 'O'],
#  ['เจตนา', 'VV', 'O'],
#  ['จะ', 'AUX', 'O'],
#  ['พาดพิง', 'VV', 'O'],
#  ['ใคร', 'PDEM', 'O'],
#  [' ', 'space', 'space'],
#  [' ', 'space', 'space'],
#  ['ทั้งนี้', 'CNJ', 'O'],
#  [' ', 'space', 'space'],
#  ['ทำ', 'VV', 'O'],
#  ['ทุก', 'PDT', 'O'],
#  ['อย่าง', 'CL', 'O'],
#  ['ไป', 'VV', 'O'],
#  ['ตาม', 'VV', 'O'],
#  ['หน้าที่', 'NN', 'O'],
#  ['จริง', 'JJA', 'O'],
#  [' ', 'space', 'space'],
#  ['ๆ', 'PU', 'O'],
#  [' ', 'space', 'space'],
#  ['"', 'PU', 'O'],
#  ['คือ', 'VV', 'O'],
#  ['ตอน', 'ADV', 'O'],
#  ['นี้', 'DDEM', 'O'],
#  [' ', 'space', 'space'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  [' ', 'space', 'space'],
#  ['งง', 'VV', 'O'],
#  [' ', 'space', 'space'],
#  ['กับ', 'P', 'O'],
#  ['เรื่องราว', 'NN', 'O'],
#  ['ที่', 'COMP', 'O'],
#  ['เกิด', 'VV', 'O'],
#  ['ขึ้น', 'ADV', 'O'],
#  ['เหมือน', 'ADV', 'O'],
#  ['กัน', 'REFX', 'O'],
#  [' ', 'space', 'space'],
#  ['เพราะ', 'CNJ', 'O'],
#  ['ตอน', 'NN', 'O'],
#  ['ที่', 'COMP', 'O'],
#  [' ', 'space', 'space'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  [' ', 'space', 'space'],
#  ['ทำ', 'VV', 'O'],
#  ['รายการ', 'NN', 'O'],
#  [' ', 'space', 'space'],
#  ['ก็', 'AUX', 'O'],
#  ['ทำ', 'JJV', 'O'],
#  ['หน้าที่', 'NN', 'O'],
#  ['ไป', 'VV', 'O'],
#  ['ตาม', 'VV', 'O'],
#  ['ปกติ', 'ADV', 'O'],
#  [' ', 'space', 'space'],
#  ['เพื่อ', 'CNJ', 'O'],
#  ['ความ', 'FXN', 'O'],
#  ['สนุกสนาน', 'VV', 'O'],
#  ['ตลอด', 'ADV', 'O'],
#  [' ', 'space', 'space'],
#  ['ตอน', 'NN', 'O'],
#  ['จัด', 'VV', 'O'],
#  ['รายการ', 'NN', 'O'],
#  ['ไม่', 'NEG', 'O'],
#  ['ได้', 'AUX', 'O'],
#  ['คิด', 'VV', 'O'],
#  ['ถึง', 'VV', 'O'],
#  ['ใคร', 'PINT', 'O'],
#  [' ', 'space', 'space'],
#  ['หรือ', 'CNJ', 'O'],
#  ['พูด', 'VV', 'O'],
#  ['ถึง', 'P', 'O'],
#  ['ใคร', 'PINT', 'O'],
#  [' ', 'space', 'space'],
#  ['แล้ว', 'AUX', 'O'],
#  ['ก็', 'AUX', 'O'],
#  ['ไม่', 'NEG', 'O'],
#  ['ได้', 'AUX', 'O'],
#  ['มี', 'VV', 'O'],
#  ['เจตนา', 'VV', 'O'],
#  ['จะ', 'AUX', 'O'],
#  ['เอ่ย', 'VV', 'O'],
#  ['ถึง', 'P', 'O'],
#  ['ใคร', 'PINT', 'O'],
#  ['ด้วย', 'P', 'O'],
#  [' ', 'space', 'space'],
#  [' ', 'space', 'space'],
#  ['แม้กระทั่ง', 'CNJ', 'O'],
#  ['ตอน', 'NN', 'O'],
#  ['ที่', 'COMP', 'O'],
#  ['เล่า', 'VV', 'O'],
#  [' ', 'space', 'space'],
#  ['ๆ', 'PU', 'O'],
#  [' ', 'space', 'space'],
#  ['ไป', 'VV', 'O'],
#  ['ยัง', 'P', 'O'],
#  ['หัน', 'VV', 'O'],
#  ['หน้า', 'NN', 'O'],
#  ['มอง', 'VV', 'O'],
#  ['กับ', 'P', 'O'],
#  [' ', 'space', 'space'],
#  ['พี่', 'NN', 'TTL_B'],
#  ['ปอ', 'NR', 'PER_B'],
#  ['-', 'PU', 'O'],
#  ['วรฐก์', 'NR', 'PER_B'],
#  [' ', 'space', 'space'],
#  ['ว่า', 'COMP', 'O'],
#  ['มัน', 'PPER', 'O'],
#  ['เป็น', 'VV', 'O'],
#  ['แค่', 'PDT', 'O'],
#  ['เรื่อง', 'NN', 'O'],
#  [' ', 'space', 'space'],
#  ['ๆ', 'PU', 'O'],
#  [' ', 'space', 'space'],
#  ['หนึ่ง', 'NN', 'O'],
#  ['เท่านั้น', 'ADV', 'O'],
#  ['เอง', 'REFX', 'O'],
#  [' ', 'space', 'space'],
#  [' ', 'space', 'space'],
#  ['แล้ว', 'AUX', 'O'],
#  ['เรา', 'PPER', 'O'],
#  ['สอง', 'CD', 'MEA_B'],
#  ['คน', 'CL', 'MEA_I'],
#  ['ก็', 'AUX', 'O'],
#  ['ไม่', 'NEG', 'O'],
#  ['รู้', 'VV', 'O'],
#  ['เรื่อง', 'NN', 'O'],
#  ['นี้', 'DDEM', 'O'],
#  [' ', 'space', 'space'],
#  [' ', 'space', 'space'],
#  ['แล้ว', 'AUX', 'O'],
#  ['ตอน', 'NN', 'O'],
#  ['ที่', 'COMP', 'O'],
#  ['พูด', 'VV', 'O'],
#  ['ออก', 'ADV', 'O'],
#  ['ไป', 'VV', 'O'],
#  ['ก็', 'AUX', 'O'],
#  ['ไม่', 'NEG', 'O'],
#  ['ได้', 'AUX', 'O'],
#  ['มี', 'VV', 'O'],
#  ['โอกาส', 'NN', 'O'],
#  ['จะ', 'AUX', 'O'],
#  ['นึก', 'VV', 'O'],
#  ['ถึง', 'VV', 'O'],
#  ['ใคร', 'PINT', 'O'],
#  ['ด้วย', 'P', 'O'],
#  ['ซ้ำ', 'ADV', 'O'],
#  [' ', 'space', 'space'],
#  ['เพราะ', 'CNJ', 'O'],
#  ['ต้อง', 'AUX', 'O'],
#  ['เตรียม', 'VV', 'O'],
#  ['ข่าว', 'NN', 'O'],
#  ['ต่อไป', 'ADV', 'O'],
#  [' ', 'space', 'space'],
#  ['รายการ', 'NN', 'O'],
#  ['เรา', 'PPER', 'O'],
#  ['เป็น', 'VV', 'O'],
#  ['รายการ', 'NN', 'O'],
#  ['สด', 'JJA', 'O'],
#  [' ', 'space', 'space'],
#  ['2', 'CD', 'MEA_B'],
#  [' ', 'space', 'space'],
#  ['ชั่วโมง', 'CL', 'MEA_B'],
#  [' ', 'space', 'space'],
#  [' ', 'space', 'space'],
#  ['วัน', 'NN', 'O'],
#  ['นี้', 'DDEM', 'O'],
#  [' ', 'space', 'space'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  ['อยาก', 'VV', 'O'],
#  ['ให้', 'COMP', 'O'],
#  ['ดู', 'VV', 'O'],
#  ['ที่', 'P', 'O'],
#  ['เจตนา', 'VV', 'O'],
#  ['มาก', 'ADV', 'O'],
#  ['กว่า', 'ADV', 'O'],
#  [' ', 'space', 'space'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  ['ยืนยัน', 'VV', 'O'],
#  ['ว่า', 'COMP', 'O'],
#  [' ', 'space', 'space'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  ['ไม่', 'NEG', 'O'],
#  ['ได้', 'AUX', 'O'],
#  ['เอ่ย', 'VV', 'O'],
#  ['ถึง', 'P', 'O'],
#  ['ใคร', 'PDEM', 'O'],
#  ['เลย', 'PAR', 'O'],
#  ['แม้', 'CNJ', 'O'],
#  ['ซัก', 'VV', 'O'],
#  ['คน', 'CL', 'O'],
#  ['เดียว', 'CD', 'NUM_B'],
#  ['"', 'PU', 'O'],
#  [' ', 'space', 'space'],
#  ['แล้ว', 'AUX', 'O'],
#  ['ที่', 'COMP', 'O'],
#  ['หยาด', 'NR', 'PER_B'],
#  ['พูด', 'VV', 'O'],
#  ['ถึง', 'VV', 'O'],
#  ['เรื่อง', 'NN', 'O'],
#  ['ฟ้อง', 'VV', 'O'],
#  ['ล่ะ', 'PAR', 'O'],
#  [' ', 'space', 'space'],
#  [' ', 'space', 'space'],
#  ['"', 'PU', 'O'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  ['คิด', 'VV', 'O'],
#  ['ว่า', 'COMP', 'O'],
#  ['ไม่', 'NEG', 'O'],
#  ['น่า', 'AUX', 'O'],
#  ['จะ', 'AUX', 'O'],
#  ['ใหญ่โต', 'VA', 'O'],
#  [' ', 'space', 'space'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  ['ขอ', 'VV', 'O'],
#  ['ยืนยัน', 'VV', 'O'],
#  [' ', 'space', 'space'],
#  ['เรา', 'PPER', 'O'],
#  ['มี', 'VV', 'O'],
#  ['ใจ', 'NN', 'O'],
#  ['บริสุทธิ์', 'JJA', 'O'],
#  ['ไม่', 'NEG', 'O'],
#  ['ได้', 'AUX', 'O'],
#  ['มี', 'VV', 'O'],
#  ['เจตนา', 'VV', 'O'],
#  ['จะ', 'AUX', 'O'],
#  ['พูด', 'VV', 'O'],
#  ['ถึง', 'VV', 'O'],
#  ['ใคร', 'PDEM', 'O'],
#  ['เลย', 'PAR', 'O'],
#  ['ครับ', 'PAR', 'O'],
#  ['"', 'PU', 'O'],
#  [' ', 'space', 'space'],
#  [' ', 'space', 'space'],
#  ['จะ', 'AUX', 'O'],
#  ['มี', 'VV', 'O'],
#  ['การ', 'FXN', 'O'],
#  ['ขอโทษ', 'VV', 'O'],
#  ['กัน', 'REFX', 'O'],
#  ['มั้ย', 'PAR', 'O'],
#  [' ', 'space', 'space'],
#  [' ', 'space', 'space'],
#  ['"', 'PU', 'O'],
#  ['อย่าง', 'FXAV', 'O'],
#  ['ที่', 'COMP', 'O'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  ['บอก', 'VV', 'O'],
#  ['ไป', 'VV', 'O'],
#  ['ว่า', 'COMP', 'O'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  ['ไม่', 'NEG', 'O'],
#  ['ได้', 'AUX', 'O'],
#  ['เอ่ย', 'VV', 'O'],
#  ['เรา', 'PPER', 'O'],
#  ['กุ', 'VV', 'O'],
#  ['ข่าว', 'NN', 'O'],
#  ['ขึ้น', 'ADV', 'O'],
#  ['มา', 'VV', 'O'],
#  ['หรือ', 'CNJ', 'O'],
#  ['เปล่า', 'PINT', 'O'],
#  [' ', 'space', 'space'],
#  ['"', 'PU', 'O'],
#  [' ', 'space', 'space'],
#  ['รายการ', 'NN', 'O'],
#  ['ของ', 'P', 'O'],
#  ['เรา', 'DPER', 'O'],
#  ['เป็น', 'VV', 'O'],
#  ['เรื่องราว', 'NN', 'O'],
#  ['ที่', 'COMP', 'O'],
#  ['ให้', 'COMP', 'O'],
#  ['สีสัน', 'VV', 'O'],
#  ['กับ', 'P', 'O'],
#  ['วงการ', 'NN', 'ORG_B'],
#  ['บันเทิง', 'NN', 'ORG_I'],
#  [' ', 'space', 'space'],
#  ['สนุกสนาน', 'ADV', 'O'],
#  [' ', 'space', 'space'],
#  ['แล้ว', 'AUX', 'O'],
#  ['ใน', 'P', 'O'],
#  ['ส่วน', 'NN', 'O'],
#  ['ของ', 'P', 'O'],
#  ['ข่าว', 'NN', 'O'],
#  ['ก็', 'AUX', 'O'],
#  ['อยู่', 'VV', 'O'],
#  ['ใน', 'P', 'O'],
#  ['กระบวนการ', 'NN', 'O'],
#  [' ', 'space', 'space'],
#  ['การ', 'FXN', 'O'],
#  ['ทำ', 'VV', 'O'],
#  ['ข่าว', 'NN', 'O'],
#  [' ', 'space', 'space'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  ['ไม่', 'NEG', 'O'],
#  ['ขอ', 'VV', 'O'],
#  ['ลง', 'VV', 'O'],
#  ['ลึก', 'ADV', 'O'],
#  ['ดี', 'ADV', 'O'],
#  ['กว่า', 'ADV', 'O'],
#  ['ครับ', 'PAR', 'O'],
#  ['"', 'PU', 'O'],
#  [' ', 'space', 'space'],
#  [' ', 'space', 'space'],
#  ['หยาด', 'NR', 'PER_B'],
#  ['และ', 'CNJ', 'O'],
#  ['คุณ', 'NN', 'O'],
#  ['แม่', 'NN', 'O'],
#  ['ไม่', 'NEG', 'O'],
#  ['พอใจ', 'VV', 'O'],
#  [' ', 'space', 'space'],
#  ['ตรง', 'P', 'O'],
#  ['ที่', 'COMP', 'O'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  ['พูด', 'VV', 'O'],
#  ['ไป', 'VV', 'O'],
#  ['หัวเราะ', 'VV', 'O'],
#  ['ไป', 'VV', 'O'],
#  [' ', 'space', 'space'],
#  ['เหมือน', 'ADV', 'O'],
#  ['ไป', 'VV', 'O'],
#  ['เยาะเย้ย', 'VV', 'O'],
#  ['เค้า', 'NN', 'O'],
#  [' ', 'space', 'space'],
#  [' ', 'space', 'space'],
#  ['"', 'PU', 'O'],
#  ['เกี่ยว', 'P', 'O'],
#  ['กับ', 'P', 'O'],
#  ['เรื่อง', 'NN', 'O'],
#  ['หัวเราะ', 'NN', 'O'],
#  [' ', 'space', 'space'],
#  ['ถ้า', 'CNJ', 'O'],
#  ['ใคร', 'PDEM', 'O'],
#  ['ฟัง', 'VV', 'O'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  ['ตั้งแต่', 'P', 'O'],
#  ['ตอน', 'NN', 'O'],
#  ['จัด', 'VV', 'O'],
#  ['รายการ', 'NN', 'O'],
#  ['ใหม่', 'JJA', 'O'],
#  [' ', 'space', 'space'],
#  ['ๆ', 'PU', 'O'],
#  [' ', 'space', 'space'],
#  ['ก็', 'AUX', 'O'],
#  ['จะ', 'AUX', 'O'],
#  ['รู้', 'VV', 'O'],
#  ['ว่า', 'COMP', 'O'],
#  [' ', 'space', 'space'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  ['จะ', 'AUX', 'O'],
#  ['หัวเราะ', 'VV', 'O'],
#  ['ตลอด', 'ADV', 'O'],
#  ['การ', 'FXN', 'O'],
#  ['จัด', 'VV', 'O'],
#  ['รายการ', 'NN', 'O'],
#  ['อยู่แล้ว', 'ADV', 'O'],
#  [' ', 'space', 'space'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  ['เป็น', 'VV', 'O'],
#  ['คน', 'NN', 'O'],
#  ['อารมณ์', 'NN', 'O'],
#  ['ดี', 'ADV', 'O'],
#  ['ครับ', 'PAR', 'O'],
#  [' ', 'space', 'space'],
#  ['พูด', 'VV', 'O'],
#  ['ไป', 'VV', 'O'],
#  ['ขำ', 'VV', 'O'],
#  ['ไป', 'VV', 'O'],
#  [' ', 'space', 'space'],
#  ['เป็น', 'VV', 'O'],
#  ['สไตล์', 'NN', 'O'],
#  ['การ', 'FXN', 'O'],
#  ['จัด', 'VV', 'O'],
#  ['ของ', 'P', 'O'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  ['อยู่แล้ว', 'ADV', 'O'],
#  [' ', 'space', 'space'],
#  ['ตอน', 'NN', 'O'],
#  ['แรก', 'ADV', 'O'],
#  [' ', 'space', 'space'],
#  ['ๆ', 'PU', 'O'],
#  [' ', 'space', 'space'],
#  ['คน', 'CL', 'O'],
#  ['ก็', 'AUX', 'O'],
#  ['ติง', 'VV', 'O'],
#  ['ว่า', 'COMP', 'O'],
#  [' ', 'space', 'space'],
#  ['หัวเราะ', 'VV', 'O'],
#  ['เยอะ', 'ADV', 'O'],
#  ['ไป', 'VV', 'O'],
#  [' ', 'space', 'space'],
#  ['พอ', 'P', 'O'],
#  ['หลัง', 'CNJ', 'O'],
#  [' ', 'space', 'space'],
#  ['ๆ', 'PU', 'O'],
#  [' ', 'space', 'space'],
#  ['หัวเราะ', 'VV', 'O'],
#  ['น้อย', 'ADV', 'O'],
#  ['ลง', 'VV', 'O'],
#  ['ก็', 'AUX', 'O'],
#  ['บอก', 'VV', 'O'],
#  ['ว่า', 'COMP', 'O'],
#  [' ', 'space', 'space'],
#  ['หัวเราะ', 'VV', 'O'],
#  ['อีก', 'ADV', 'O'],
#  ['ได้', 'AUX', 'O'],
#  ['มั้ย', 'PAR', 'O'],
#  [' ', 'space', 'space'],
#  ['ชอบ', 'VV', 'O'],
#  ['เสียง', 'NN', 'O'],
#  ['หัวเราะ', 'VV', 'O'],
#  [' ', 'space', 'space'],
#  ['มัน', 'PPER', 'O'],
#  ['เป็น', 'VV', 'O'],
#  ['ธรรมชาติ', 'NN', 'O'],
#  ['ของ', 'P', 'O'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  ['ครับ', 'PAR', 'O'],
#  ['"', 'PU', 'O'],
#  [' ', 'space', 'space'],
#  [' ', 'space', 'space'],
#  ['จะ', 'AUX', 'O'],
#  ['ทำ', 'VV', 'O'],
#  ['ให้', 'COMP', 'O'],
#  ['ลด', 'VV', 'O'],
#  ['ความ', 'FXN', 'O'],
#  ['หวือหวา', 'VV', 'O'],
#  ['ใน', 'P', 'O'],
#  ['การ', 'FXN', 'O'],
#  ['จัด', 'VV', 'O'],
#  ['รายการ', 'NN', 'O'],
#  ['มั้ย', 'PAR', 'O'],
#  [' ', 'space', 'space'],
#  [' ', 'space', 'space'],
#  ['"', 'PU', 'O'],
#  ['แต่ละ', 'PDT', 'O'],
#  ['คน', 'CL', 'O'],
#  ['ก็', 'AUX', 'O'],
#  ['มี', 'VV', 'O'],
#  ['สไตล์', 'NN', 'O'],
#  ['การ', 'FXN', 'O'],
#  ['จัด', 'VV', 'O'],
#  ['รายการ', 'NN', 'O'],
#  ['ที่', 'COMP', 'O'],
#  ['แตกต่าง', 'VV', 'O'],
#  ['กัน', 'REFX', 'O'],
#  ['ไป', 'VV', 'O'],
#  [' ', 'space', 'space'],
#  ['ดีเจ', 'NN', 'O'],
#  ['ก็', 'AUX', 'O'],
#  ['มี', 'VV', 'O'],
#  ['หลาย', 'PDT', 'O'],
#  ['คน', 'CL', 'O'],
#  [' ', 'space', 'space'],
#  ['เพราะฉะนั้น', 'CNJ', 'O'],
#  ['การ', 'FXN', 'O'],
#  ['จัด', 'VV', 'O'],
#  ['รายการ', 'NN', 'O'],
#  ['ก็', 'AUX', 'O'],
#  ['คง', 'AUX', 'O'],
#  ['เหมือน', 'ADV', 'O'],
#  ['เดิม', 'ADV', 'O'],
#  [' ', 'space', 'space'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  ['ก็', 'CNJ', 'O'],
#  ['ยัง', 'AUX', 'O'],
#  ['จัด', 'VV', 'O'],
#  ['รายการ', 'NN', 'O'],
#  ['เหมือน', 'VV', 'O'],
#  ['เดิม', 'ADV', 'O'],
#  [' ', 'space', 'space'],
#  ['แล้ว', 'AUX', 'O'],
#  ['ก็', 'AUX', 'O'],
#  ['ออก', 'VV', 'O'],
#  ['ทำ', 'VV', 'O'],
#  ['ข่าว', 'NN', 'O'],
#  ['ตาม', 'VV', 'O'],
#  ['ปกติ', 'ADV', 'O'],
#  ['"', 'PU', 'O'],
#  [' ', 'space', 'space'],
#  [' ', 'space', 'space'],
#  ['พี่', 'NN', 'TTL_B'],
#  ['ฉอด', 'NR', 'PER_B'],
#  ['-', 'PU', 'O'],
#  ['สายทิพย์', 'NR', 'PER_B'],
#  [' ', 'space', 'space'],
#  ['ให้', 'COMP', 'O'],
#  ['คำ', 'NN', 'O'],
#  ['แนะนำ', 'JJV', 'O'],
#  ['อย่าง', 'FXAV', 'O'],
#  ['ไร', 'PDEM', 'O'],
#  ['บ้าง', 'PDEM', 'O'],
#  [' ', 'space', 'space'],
#  [' ', 'space', 'space'],
#  ['"', 'PU', 'O'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  ['ไม่', 'NEG', 'O'],
#  ['อยาก', 'VV', 'O'],
#  ['จะ', 'AUX', 'O'],
#  ['พาดพิง', 'VV', 'O'],
#  ['ถึง', 'VV', 'O'],
#  [' ', 'space', 'space'],
#  ['เพราะ', 'CNJ', 'O'],
#  ['ท่าน', 'PPER', 'O'],
#  ['เอง', 'REFX', 'O'],
#  ['ก็', 'AUX', 'O'],
#  ['ไม่', 'NEG', 'O'],
#  ['ได้', 'AUX', 'O'],
#  ['ลง', 'VV', 'O'],
#  ['มา', 'VV', 'O'],
#  ['ข้อง', 'VV', 'O'],
#  ['เกี่ยว', 'P', 'O'],
#  ['กับ', 'P', 'O'],
#  ['ตรง', 'NN', 'O'],
#  ['นี้', 'DDEM', 'O'],
#  [' ', 'space', 'space'],
#  ['ก็', 'AUX', 'O'],
#  ['ไม่', 'NEG', 'O'],
#  ['มี', 'VV', 'O'],
#  ['ใคร', 'PDEM', 'O'],
#  ['แนะนำ', 'VV', 'O'],
#  ['อะไร', 'PDEM', 'O'],
#  ['มาก', 'JJA', 'O'],
#  [' ', 'space', 'space'],
#  ['เพราะ', 'CNJ', 'O'],
#  ['เป็น', 'VV', 'O'],
#  ['เรื่อง', 'NN', 'O'],
#  ['ที่', 'COMP', 'O'],
#  ['เกิด', 'VV', 'O'],
#  ['ขึ้น', 'ADV', 'O'],
#  ['ภาย', 'NN', 'O'],
#  ['ใน', 'P', 'O'],
#  ['คลื่น', 'NN', 'O'],
#  ['เรา', 'PPER', 'O'],
#  [' ', 'space', 'space'],
#  ['แต่', 'CNJ', 'O'],
#  ['ถ้า', 'CNJ', 'O'],
#  ['เกิด', 'VV', 'O'],
#  ['อะไร', 'PDEM', 'O'],
#  ['ขึ้น', 'ADV', 'O'],
#  ['จริง', 'ADV', 'O'],
#  ['ๆ', 'PU', 'O'],
#  [' ', 'space', 'space'],
#  ['คง', 'AUX', 'O'],
#  ['ต้อง', 'AUX', 'O'],
#  ['ปรึกษา', 'VV', 'O'],
#  ['กับ', 'P', 'O'],
#  ['ผู้', 'FXN', 'O'],
#  ['ใหญ่', 'JJA', 'O'],
#  ['อีก', 'ADV', 'O'],
#  ['ที', 'ADV', 'O'],
#  ['ครับ', 'PAR', 'O'],
#  ['"', 'PU', 'O'],
#  [' ', 'space', 'space'],
#  [' ', 'space', 'space'],
#  ['ถึง', 'VV', 'O'],
#  ['ใคร', 'PINT', 'O'],
#  [' ', 'space', 'space'],
#  ['ก็', 'AUX', 'O'],
#  ['เลย', 'PAR', 'O'],
#  ['ไม่', 'NEG', 'O'],
#  ['รู้', 'VV', 'O'],
#  ['ว่า', 'COMP', 'O'],
#  [' ', 'space', 'space'],
#  ['จะ', 'AUX', 'O'],
#  ['ต้อง', 'AUX', 'O'],
#  ['ไป', 'VV', 'O'],
#  ['ขอโทษ', 'VV', 'O'],
#  ['ใคร', 'PDEM', 'O'],
#  ['เหมือน', 'ADV', 'O'],
#  ['กัน', 'REFX', 'O'],
#  [' ', 'space', 'space'],
#  ['เพราะ', 'CNJ', 'O'],
#  ['ไม่', 'NEG', 'O'],
#  ['ได้', 'AUX', 'O'],
#  ['มี', 'VV', 'O'],
#  ['เจตนา', 'VV', 'O'],
#  ['ตรง', 'P', 'O'],
#  ['นั้น', 'DDEM', 'O'],
#  [' ', 'space', 'space'],
#  [' ', 'space', 'space'],
#  ['การ', 'NN', 'O'],
#  ['ที่', 'COMP', 'O'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  ['พูด', 'VV', 'O'],
#  ['ออก', 'ADV', 'O'],
#  ['ไป', 'VV', 'O'],
#  ['ใคร', 'PINT', 'O'],
#  ['จะ', 'AUX', 'O'],
#  ['ไป', 'VV', 'O'],
#  ['คิด', 'VV', 'O'],
#  ['หรือ', 'CNJ', 'O'],
#  ['ตีความ', 'VV', 'O'],
#  ['ต่อ', 'ADV', 'O'],
#  ['ก็', 'AUX', 'O'],
#  ['เป็น', 'VV', 'O'],
#  ['สิทธิ', 'NN', 'O'],
#  ['ส่วน', 'NN', 'O'],
#  ['บุคคล', 'NN', 'O'],
#  ['อยู่แล้ว', 'ADV', 'O'],
#  ['ไง', 'PINT', 'O'],
#  ['ครับ', 'PAR', 'O'],
#  [' ', 'space', 'space'],
#  [' ', 'space', 'space'],
#  ['อยาก', 'VV', 'O'],
#  ['ให้', 'COMP', 'O'],
#  ['ทุก', 'PDT', 'O'],
#  ['คน', 'CL', 'O'],
#  ['ได้', 'AUX', 'O'],
#  ['ย้อนกลับ', 'VV', 'O'],
#  ['ไป', 'VV', 'O'],
#  ['ฟัง', 'VV', 'O'],
#  ['รายการ', 'NN', 'O'],
#  [' ', 'space', 'space'],
#  ['วัน', 'NN', 'O'],
#  ['นั้น', 'DDEM', 'O'],
#  ['พูด', 'VV', 'O'],
#  ['กว้าง', 'ADV', 'O'],
#  ['มาก', 'ADV', 'O'],
#  [' ', 'space', 'space'],
#  ['ไม่', 'NEG', 'O'],
#  ['ได้', 'AUX', 'O'],
#  ['ชี้', 'VV', 'O'],
#  ['ชัด', 'ADV', 'O'],
#  ['ระบุ', 'VV', 'O'],
#  ['ไป', 'VV', 'O'],
#  ['ที่', 'P', 'O'],
#  ['ใคร', 'PDEM', 'O'],
#  ['พูด', 'VV', 'O'],
#  ['แค่', 'PDT', 'O'],
#  ['ว่า', 'COMP', 'O'],
#  [' ', 'space', 'space'],
#  ['นางเอก', 'NN', 'O'],
#  ['หน้า', 'P', 'O'],
#  ['คม', 'NN', 'O'],
#  ['คน', 'CL', 'O'],
#  ['หนึ่ง', 'NN', 'O'],
#  ['เท่านั้น', 'ADV', 'O'],
#  ['เอง', 'REFX', 'O'],
#  ['ครับ', 'PAR', 'O'],
#  ['"', 'PU', 'O'],
#  ['\n', 'space', 'space']]

# %%
trainer = TrainModel(LSTMTagger, best2010,1)
trainer.train(40)
# Out:
# Training
# Num of training text file: 4975
#  epoch 0: 2m 3s loss:0.9060 accuracy POS:0.8518 accuracy NER:0.89549epoch: 0
# F1 (POS): 0.9376291737473017 F1 (NER) 0.7243983010854177
#  epoch 1: 4m 15s loss:0.4848 accuracy POS:0.9054 accuracy NER:0.9497epoch: 1
# F1 (POS): 0.9478765143830504 F1 (NER) 0.7703807195249738
#  epoch 2: 6m 27s loss:0.7219 accuracy POS:0.8659 accuracy NER:0.8959epoch: 2
# F1 (POS): 0.9519380201036571 F1 (NER) 0.7840951147298297
#  epoch 3: 8m 39s loss:0.4159 accuracy POS:0.9128 accuracy NER:0.9534epoch: 3
# F1 (POS): 0.9536804556171345 F1 (NER) 0.7951890350473738
#  epoch 4: 10m 51s loss:0.6165 accuracy POS:0.8854 accuracy NER:0.9131epoch: 4
# F1 (POS): 0.9545108335789277 F1 (NER) 0.7975334971486855
#  epoch 5: 13m 3s loss:0.3358 accuracy POS:0.9209 accuracy NER:0.96153epoch: 5
# F1 (POS): 0.9549974356422759 F1 (NER) 0.8026139564956356
#  epoch 6: 15m 15s loss:0.5831 accuracy POS:0.8927 accuracy NER:0.9150epoch: 6
# F1 (POS): 0.9558458258862791 F1 (NER) 0.8021740645251203
#  epoch 7: 17m 27s loss:0.3360 accuracy POS:0.9416 accuracy NER:0.9623epoch: 7
# F1 (POS): 0.9564225625952035 F1 (NER) 0.8058905966411654
#  epoch 8: 19m 38s loss:0.5408 accuracy POS:0.8954 accuracy NER:0.9163epoch: 8
# F1 (POS): 0.9567793496233694 F1 (NER) 0.8071949755241525
#  epoch 9: 21m 50s loss:0.3883 accuracy POS:0.9209 accuracy NER:0.9542epoch: 9
# F1 (POS): 0.9569567347438684 F1 (NER) 0.805482998543723
#  epoch 10: 24m 2s loss:0.5295 accuracy POS:0.8986 accuracy NER:0.92226epoch: 10
# F1 (POS): 0.9575734379485217 F1 (NER) 0.8105120114240965
#  epoch 11: 26m 14s loss:0.3927 accuracy POS:0.9091 accuracy NER:0.9579epoch: 11
# F1 (POS): 0.9576193665677926 F1 (NER) 0.8096442033648984
#  epoch 12: 28m 26s loss:0.4876 accuracy POS:0.9036 accuracy NER:0.9345epoch: 12
# F1 (POS): 0.9578004968249898 F1 (NER) 0.8095896089539866
#  epoch 13: 30m 38s loss:0.3800 accuracy POS:0.9217 accuracy NER:0.9586epoch: 13
# F1 (POS): 0.9574591851574041 F1 (NER) 0.808427966787705
#  epoch 14: 32m 50s loss:0.5044 accuracy POS:0.8968 accuracy NER:0.9345epoch: 14
# F1 (POS): 0.9575437938464717 F1 (NER) 0.8085490668272125
#  epoch 15: 35m 1s loss:0.4283 accuracy POS:0.9106 accuracy NER:0.95426epoch: 15
# F1 (POS): 0.9577387171215025 F1 (NER) 0.8066011496384202
#  epoch 16: 37m 13s loss:0.4829 accuracy POS:0.9059 accuracy NER:0.9350epoch: 16
# F1 (POS): 0.9580666891209161 F1 (NER) 0.8088929846791845
#  epoch 17: 39m 25s loss:0.3336 accuracy POS:0.9224 accuracy NER:0.9741epoch: 17
# F1 (POS): 0.9575411040690732 F1 (NER) 0.8094118731563421
#  epoch 18: 41m 37s loss:0.4778 accuracy POS:0.9050 accuracy NER:0.9290epoch: 18
# F1 (POS): 0.9582499339821581 F1 (NER) 0.8075963404491269
#  epoch 19: 43m 48s loss:0.3657 accuracy POS:0.9172 accuracy NER:0.9638epoch: 19
# F1 (POS): 0.9578569870290917 F1 (NER) 0.8103254769921435
#  epoch 20: 46m 0s loss:0.4476 accuracy POS:0.9068 accuracy NER:0.93450epoch: 20
# F1 (POS): 0.9578319708520866 F1 (NER) 0.8074276904668769
#  epoch 21: 48m 12s loss:0.3031 accuracy POS:0.9350 accuracy NER:0.9719epoch: 21
# F1 (POS): 0.9586249918673673 F1 (NER) 0.8089092996555683
#  epoch 22: 50m 24s loss:0.4264 accuracy POS:0.9063 accuracy NER:0.9468epoch: 22
# F1 (POS): 0.95793913229846 F1 (NER) 0.8105977264393106
#  epoch 23: 52m 36s loss:0.3552 accuracy POS:0.9150 accuracy NER:0.9660epoch: 23
# F1 (POS): 0.9579647965217525 F1 (NER) 0.8096622369878184
#  epoch 24: 54m 48s loss:0.4399 accuracy POS:0.9131 accuracy NER:0.9363epoch: 24
# F1 (POS): 0.958132094390313 F1 (NER) 0.809057330977999
#  epoch 25: 57m 0s loss:0.3774 accuracy POS:0.9202 accuracy NER:0.96384epoch: 25
# F1 (POS): 0.9582972925389815 F1 (NER) 0.8087267690176613
#  epoch 26: 59m 11s loss:0.4432 accuracy POS:0.9118 accuracy NER:0.9404epoch: 26
# F1 (POS): 0.9588194999866062 F1 (NER) 0.8109760301519087
#  epoch 27: 61m 23s loss:0.3244 accuracy POS:0.9268 accuracy NER:0.9667epoch: 27
# F1 (POS): 0.9586736373169631 F1 (NER) 0.8104123473853951
#  epoch 28: 63m 35s loss:0.4361 accuracy POS:0.9036 accuracy NER:0.9431epoch: 28
# F1 (POS): 0.958628977320566 F1 (NER) 0.8107375769266097
#  epoch 29: 65m 48s loss:0.3281 accuracy POS:0.9254 accuracy NER:0.9704epoch: 29
# F1 (POS): 0.9585865854218656 F1 (NER) 0.8099158349813734
#  epoch 30: 68m 0s loss:0.4863 accuracy POS:0.8868 accuracy NER:0.94364epoch: 30
# F1 (POS): 0.9585642548761445 F1 (NER) 0.8070321343590455
#  epoch 31: 70m 12s loss:0.3451 accuracy POS:0.9224 accuracy NER:0.9711epoch: 31
# F1 (POS): 0.9583459320016382 F1 (NER) 0.8076593577068235
#  epoch 32: 72m 24s loss:0.4125 accuracy POS:0.9077 accuracy NER:0.9490epoch: 32
# F1 (POS): 0.9586511779227987 F1 (NER) 0.8086394086394086
#  epoch 33: 74m 36s loss:0.3009 accuracy POS:0.9298 accuracy NER:0.9741epoch: 33
# F1 (POS): 0.9582832604885068 F1 (NER) 0.806997273189444
#  epoch 34: 76m 48s loss:0.3963 accuracy POS:0.9177 accuracy NER:0.9495epoch: 34
# F1 (POS): 0.958731325006123 F1 (NER) 0.8114212265883217
#  epoch 35: 78m 59s loss:0.3739 accuracy POS:0.9254 accuracy NER:0.9579epoch: 35
# F1 (POS): 0.9587793387702306 F1 (NER) 0.8105190629306384
#  epoch 36: 81m 11s loss:0.4313 accuracy POS:0.9113 accuracy NER:0.9477epoch: 36
# F1 (POS): 0.9583518317233355 F1 (NER) 0.8105639943095774
#  epoch 37: 83m 23s loss:0.3083 accuracy POS:0.9320 accuracy NER:0.9719epoch: 37
# F1 (POS): 0.9583154736390914 F1 (NER) 0.8093205675395085
#  epoch 38: 85m 35s loss:0.3935 accuracy POS:0.9136 accuracy NER:0.9577epoch: 38
# F1 (POS): 0.958764030753805 F1 (NER) 0.8096944635883299
#  epoch 39: 87m 46s loss:0.2795 accuracy POS:0.9416 accuracy NER:0.9711epoch: 39
# F1 (POS): 0.9585729976311026 F1 (NER) 0.8072205828107708

# %%
filehandle = open('done_bilstm_u.txt', 'w')
filehandle.write('seed1')
filehandle.close()

# %%
trainer = TrainModel(LSTMTagger, best2010,2)
trainer.train(40)
# Out:
# Training
# Num of training text file: 4975
#  epoch 0: 2m 4s loss:0.8433 accuracy POS:0.8604 accuracy NER:0.89453epoch: 0
# F1 (POS): 0.9377684210526316 F1 (NER) 0.7276563818812718
#  epoch 1: 4m 15s loss:0.4563 accuracy POS:0.9054 accuracy NER:0.9497epoch: 1
# F1 (POS): 0.9482845726358334 F1 (NER) 0.7645431938085387
#  epoch 2: 6m 27s loss:0.6623 accuracy POS:0.8831 accuracy NER:0.8963epoch: 2
# F1 (POS): 0.9519183660971279 F1 (NER) 0.7830719557195573
#  epoch 3: 8m 39s loss:0.3956 accuracy POS:0.9261 accuracy NER:0.9497epoch: 3
# F1 (POS): 0.9543566876542974 F1 (NER) 0.7914534642511409
#  epoch 4: 10m 52s loss:0.5386 accuracy POS:0.8949 accuracy NER:0.9100epoch: 4
# F1 (POS): 0.9549283377025967 F1 (NER) 0.796875
#  epoch 5: 13m 5s loss:0.4445 accuracy POS:0.9069 accuracy NER:0.95124epoch: 5
# F1 (POS): 0.956695459816525 F1 (NER) 0.7999816370564201
#  epoch 6: 15m 22s loss:0.5150 accuracy POS:0.8949 accuracy NER:0.9195epoch: 6
# F1 (POS): 0.9564262315157824 F1 (NER) 0.801685809559096
#  epoch 7: 17m 39s loss:0.3965 accuracy POS:0.9180 accuracy NER:0.9593epoch: 7
# F1 (POS): 0.9568275666759791 F1 (NER) 0.8036578307674499
#  epoch 8: 19m 56s loss:0.5346 accuracy POS:0.8918 accuracy NER:0.9113epoch: 8
# F1 (POS): 0.9571567449230322 F1 (NER) 0.8059687702115864
#  epoch 9: 22m 12s loss:0.3919 accuracy POS:0.9158 accuracy NER:0.9586epoch: 9
# F1 (POS): 0.9576772632980963 F1 (NER) 0.8063959507649834
#  epoch 10: 24m 28s loss:0.4961 accuracy POS:0.9013 accuracy NER:0.9336epoch: 10
# F1 (POS): 0.9579290998365845 F1 (NER) 0.8064835038510174
#  epoch 11: 26m 45s loss:0.3591 accuracy POS:0.9128 accuracy NER:0.9652epoch: 11
# F1 (POS): 0.9582019410341978 F1 (NER) 0.8076931935966832
#  epoch 12: 29m 1s loss:0.4812 accuracy POS:0.9068 accuracy NER:0.93316epoch: 12
# F1 (POS): 0.9580340091012427 F1 (NER) 0.8083919308357349
#  epoch 13: 31m 18s loss:0.3359 accuracy POS:0.9194 accuracy NER:0.9682epoch: 13
# F1 (POS): 0.9582996896489704 F1 (NER) 0.8079354094579009
#  epoch 14: 33m 34s loss:0.4869 accuracy POS:0.9040 accuracy NER:0.9322epoch: 14
# F1 (POS): 0.9585471802820675 F1 (NER) 0.8099097227032394
#  epoch 15: 35m 51s loss:0.3686 accuracy POS:0.9209 accuracy NER:0.9638epoch: 15
# F1 (POS): 0.9590230124802425 F1 (NER) 0.8100953295384405
#  epoch 16: 38m 8s loss:0.4483 accuracy POS:0.9027 accuracy NER:0.93862epoch: 16
# F1 (POS): 0.9587489187761694 F1 (NER) 0.8096532031501865
#  epoch 17: 40m 24s loss:0.3589 accuracy POS:0.9246 accuracy NER:0.9675epoch: 17
# F1 (POS): 0.9588086936886943 F1 (NER) 0.8061252771618624
#  epoch 18: 42m 39s loss:0.4825 accuracy POS:0.9036 accuracy NER:0.9345epoch: 18
# F1 (POS): 0.9589225640770495 F1 (NER) 0.8089722375436662
#  epoch 19: 44m 54s loss:0.3205 accuracy POS:0.9276 accuracy NER:0.9704epoch: 19
# F1 (POS): 0.9586425162739612 F1 (NER) 0.8110634982469808
#  epoch 20: 47m 10s loss:0.4286 accuracy POS:0.9127 accuracy NER:0.9372epoch: 20
# F1 (POS): 0.9591690681485053 F1 (NER) 0.809521617017358
#  epoch 21: 49m 26s loss:0.3218 accuracy POS:0.9350 accuracy NER:0.9660epoch: 21
# F1 (POS): 0.9592113219389358 F1 (NER) 0.8082844066386207
#  epoch 22: 51m 43s loss:0.4345 accuracy POS:0.9104 accuracy NER:0.9436epoch: 22
# F1 (POS): 0.9583486407053636 F1 (NER) 0.8109970371391166
#  epoch 23: 54m 1s loss:0.3303 accuracy POS:0.9290 accuracy NER:0.97197epoch: 23
# F1 (POS): 0.9591525092904791 F1 (NER) 0.8087429197880504
#  epoch 24: 56m 20s loss:0.4313 accuracy POS:0.9122 accuracy NER:0.9440epoch: 24
# F1 (POS): 0.9590110605074822 F1 (NER) 0.8075503045966401
#  epoch 25: 58m 40s loss:0.3445 accuracy POS:0.9290 accuracy NER:0.9660epoch: 25
# F1 (POS): 0.9593671423814828 F1 (NER) 0.809494267135406
#  epoch 26: 60m 57s loss:0.4516 accuracy POS:0.9086 accuracy NER:0.9436epoch: 26
# F1 (POS): 0.9588531541322883 F1 (NER) 0.8105029619633586
#  epoch 27: 63m 13s loss:0.3994 accuracy POS:0.9209 accuracy NER:0.9556epoch: 27
# F1 (POS): 0.9590368454084834 F1 (NER) 0.8101173020527861
#  epoch 28: 65m 29s loss:0.4236 accuracy POS:0.9086 accuracy NER:0.9459epoch: 28
# F1 (POS): 0.9591170538868076 F1 (NER) 0.8095259841081378
#  epoch 29: 67m 43s loss:0.3268 accuracy POS:0.9224 accuracy NER:0.9689epoch: 29
# F1 (POS): 0.9588310261817375 F1 (NER) 0.8092127878996219
#  epoch 30: 69m 58s loss:0.4045 accuracy POS:0.9095 accuracy NER:0.9499epoch: 30
# F1 (POS): 0.9585500357822144 F1 (NER) 0.8105997979241297
#  epoch 31: 72m 12s loss:0.3015 accuracy POS:0.9335 accuracy NER:0.9719epoch: 31
# F1 (POS): 0.9589602078971842 F1 (NER) 0.8111618514353902
#  epoch 32: 74m 26s loss:0.4241 accuracy POS:0.9200 accuracy NER:0.9436epoch: 32
# F1 (POS): 0.9589112397048468 F1 (NER) 0.8070329062586414
#  epoch 33: 76m 40s loss:0.3465 accuracy POS:0.9276 accuracy NER:0.9652epoch: 33
# F1 (POS): 0.9587973700123232 F1 (NER) 0.8090658076392083
#  epoch 34: 78m 54s loss:0.4276 accuracy POS:0.9181 accuracy NER:0.9449epoch: 34
# F1 (POS): 0.9586557966854212 F1 (NER) 0.8093631669535284
#  epoch 35: 81m 8s loss:0.3184 accuracy POS:0.9283 accuracy NER:0.96670epoch: 35
# F1 (POS): 0.9586039302730527 F1 (NER) 0.8088363353040927
#  epoch 36: 83m 22s loss:0.4255 accuracy POS:0.9104 accuracy NER:0.9513epoch: 36
# F1 (POS): 0.9588469649014708 F1 (NER) 0.8103440398410016
#  epoch 37: 85m 35s loss:0.3209 accuracy POS:0.9261 accuracy NER:0.9682epoch: 37
# F1 (POS): 0.9588791556162769 F1 (NER) 0.8078295912492803
#  epoch 38: 87m 49s loss:0.4091 accuracy POS:0.9127 accuracy NER:0.9527epoch: 38
# F1 (POS): 0.9589973210868733 F1 (NER) 0.8054900873422985
#  epoch 39: 90m 3s loss:0.3230 accuracy POS:0.9335 accuracy NER:0.96671epoch: 39
# F1 (POS): 0.9588747488278634 F1 (NER) 0.8068635828271864

# %%
filehandle = open('done_bilstm_u.txt', 'a+')
filehandle.write('seed2')
filehandle.close()

# %%
trainer = TrainModel(LSTMTagger, best2010,3)
trainer.train(40)
# Out:
# Training
# Num of training text file: 4975
#  epoch 0: 2m 6s loss:0.9294 accuracy POS:0.8445 accuracy NER:0.89405epoch: 0
# F1 (POS): 0.9375643631825369 F1 (NER) 0.7245136738601177
#  epoch 1: 4m 20s loss:0.4361 accuracy POS:0.9158 accuracy NER:0.9556epoch: 1
# F1 (POS): 0.947835372738442 F1 (NER) 0.7667722698471859
#  epoch 2: 6m 34s loss:0.6761 accuracy POS:0.8790 accuracy NER:0.8981epoch: 2
# F1 (POS): 0.9516340169487634 F1 (NER) 0.783879232740115
#  epoch 3: 8m 49s loss:0.4439 accuracy POS:0.8988 accuracy NER:0.9549epoch: 3
# F1 (POS): 0.9535926997688056 F1 (NER) 0.7918948268293247
#  epoch 4: 11m 3s loss:0.6263 accuracy POS:0.8804 accuracy NER:0.90509epoch: 4
# F1 (POS): 0.954062846863398 F1 (NER) 0.7996420540590152
#  epoch 5: 13m 17s loss:0.3912 accuracy POS:0.9150 accuracy NER:0.9630epoch: 5
# F1 (POS): 0.9552553012324888 F1 (NER) 0.8009233610341644
#  epoch 6: 15m 31s loss:0.5714 accuracy POS:0.8827 accuracy NER:0.9100epoch: 6
# F1 (POS): 0.9557818181818181 F1 (NER) 0.802365491651206
#  epoch 7: 17m 45s loss:0.4054 accuracy POS:0.9172 accuracy NER:0.9615epoch: 7
# F1 (POS): 0.956259807861599 F1 (NER) 0.8057783427712931
#  epoch 8: 19m 59s loss:0.5703 accuracy POS:0.8868 accuracy NER:0.9209epoch: 8
# F1 (POS): 0.9571916235495821 F1 (NER) 0.8055568270243054
#  epoch 9: 22m 13s loss:0.3468 accuracy POS:0.9209 accuracy NER:0.9638epoch: 9
# F1 (POS): 0.9573986054663881 F1 (NER) 0.8086832935998534
#  epoch 10: 24m 27s loss:0.5086 accuracy POS:0.8922 accuracy NER:0.9204epoch: 10
# F1 (POS): 0.95739062547837 F1 (NER) 0.8092196612052207
#  epoch 11: 26m 41s loss:0.3578 accuracy POS:0.9239 accuracy NER:0.9660epoch: 11
# F1 (POS): 0.9573976272483734 F1 (NER) 0.8087358446960943
#  epoch 12: 28m 55s loss:0.4867 accuracy POS:0.8990 accuracy NER:0.9318epoch: 12
# F1 (POS): 0.958072466208459 F1 (NER) 0.810818269628812
#  epoch 13: 31m 9s loss:0.3167 accuracy POS:0.9239 accuracy NER:0.96452epoch: 13
# F1 (POS): 0.9579885959205542 F1 (NER) 0.8120135014121376
#  epoch 14: 33m 23s loss:0.4999 accuracy POS:0.8927 accuracy NER:0.9322epoch: 14
# F1 (POS): 0.958281983175009 F1 (NER) 0.8109638221485777
#  epoch 15: 35m 37s loss:0.3326 accuracy POS:0.9254 accuracy NER:0.9660epoch: 15
# F1 (POS): 0.9585833690527218 F1 (NER) 0.8115170022730926
#  epoch 16: 37m 52s loss:0.5101 accuracy POS:0.8918 accuracy NER:0.9272epoch: 16
# F1 (POS): 0.9582899571341089 F1 (NER) 0.8114968958381237
#  epoch 17: 40m 6s loss:0.3624 accuracy POS:0.9187 accuracy NER:0.95863epoch: 17
# F1 (POS): 0.9581542395002851 F1 (NER) 0.8100723402294613
#  epoch 18: 42m 20s loss:0.4816 accuracy POS:0.8927 accuracy NER:0.9290epoch: 18
# F1 (POS): 0.9583488015186249 F1 (NER) 0.8106639653743439
#  epoch 19: 44m 35s loss:0.3344 accuracy POS:0.9224 accuracy NER:0.9689epoch: 19
# F1 (POS): 0.9587554296867524 F1 (NER) 0.8120079193333025
#  epoch 20: 46m 49s loss:0.4379 accuracy POS:0.9031 accuracy NER:0.9359epoch: 20
# F1 (POS): 0.9581730714031482 F1 (NER) 0.8103444276933782
#  epoch 21: 49m 3s loss:0.3503 accuracy POS:0.9224 accuracy NER:0.96304epoch: 21
# F1 (POS): 0.957993356092035 F1 (NER) 0.8120891749023214
#  epoch 22: 51m 17s loss:0.4389 accuracy POS:0.9013 accuracy NER:0.9468epoch: 22
# F1 (POS): 0.9585065099083793 F1 (NER) 0.8084684850718762
#  epoch 23: 53m 31s loss:0.3132 accuracy POS:0.9350 accuracy NER:0.9660epoch: 23
# F1 (POS): 0.9582818282364017 F1 (NER) 0.8109499620750683
#  epoch 24: 55m 45s loss:0.4624 accuracy POS:0.8890 accuracy NER:0.9454epoch: 24
# F1 (POS): 0.9581094527363183 F1 (NER) 0.8099295014581945
#  epoch 25: 57m 59s loss:0.4117 accuracy POS:0.9128 accuracy NER:0.9564epoch: 25
# F1 (POS): 0.9582063961053873 F1 (NER) 0.8120541430400586
#  epoch 26: 60m 13s loss:0.4583 accuracy POS:0.8918 accuracy NER:0.9381epoch: 26
# F1 (POS): 0.9584730323489337 F1 (NER) 0.8096710192405298
#  epoch 27: 62m 27s loss:0.3228 accuracy POS:0.9268 accuracy NER:0.9682epoch: 27
# F1 (POS): 0.9584314085709146 F1 (NER) 0.8111608680675162
#  epoch 28: 64m 41s loss:0.4232 accuracy POS:0.9050 accuracy NER:0.9440epoch: 28
# F1 (POS): 0.9587820615858 F1 (NER) 0.8111635148129492
#  epoch 29: 66m 55s loss:0.2954 accuracy POS:0.9305 accuracy NER:0.9711epoch: 29
# F1 (POS): 0.9588254655960318 F1 (NER) 0.808710033076075
#  epoch 30: 69m 10s loss:0.4511 accuracy POS:0.9027 accuracy NER:0.9422epoch: 30
# F1 (POS): 0.958214050611595 F1 (NER) 0.8082157083976146
#  epoch 31: 71m 24s loss:0.3439 accuracy POS:0.9224 accuracy NER:0.9667epoch: 31
# F1 (POS): 0.9586157537995201 F1 (NER) 0.8130443775423437
#  epoch 32: 73m 38s loss:0.4382 accuracy POS:0.8963 accuracy NER:0.9486epoch: 32
# F1 (POS): 0.9584049291058341 F1 (NER) 0.8100799299748922
#  epoch 33: 75m 52s loss:0.3199 accuracy POS:0.9305 accuracy NER:0.9638epoch: 33
# F1 (POS): 0.9582618945563651 F1 (NER) 0.8115156802424354
#  epoch 34: 78m 6s loss:0.4314 accuracy POS:0.9036 accuracy NER:0.94547epoch: 34
# F1 (POS): 0.9587208278797062 F1 (NER) 0.8124199157971811
#  epoch 35: 80m 20s loss:0.3331 accuracy POS:0.9261 accuracy NER:0.9608epoch: 35
# F1 (POS): 0.9588993915273047 F1 (NER) 0.8109309144218436
#  epoch 36: 82m 34s loss:0.4060 accuracy POS:0.9109 accuracy NER:0.9536epoch: 36
# F1 (POS): 0.958696725357907 F1 (NER) 0.810485544335316
#  epoch 37: 84m 48s loss:0.3205 accuracy POS:0.9327 accuracy NER:0.9682epoch: 37
# F1 (POS): 0.9582633256914969 F1 (NER) 0.8105399288716456
#  epoch 38: 87m 2s loss:0.4156 accuracy POS:0.9104 accuracy NER:0.94862epoch: 38
# F1 (POS): 0.9582029007692012 F1 (NER) 0.8113580928712781
#  epoch 39: 89m 16s loss:0.3467 accuracy POS:0.9128 accuracy NER:0.9704epoch: 39
# F1 (POS): 0.9585447809746876 F1 (NER) 0.8120535611750385

# %%
filehandle = open('done_bilstm_u.txt', 'a+')
filehandle.write('seed3')
filehandle.close()
