# %%
# %load_ext autoreload
# %autoreload 2
import torch
import math
from pathlib import Path
import os
os.chdir("/home/datamind/can/BASIL")
mypath = Path().absolute()
print(mypath)
from basil.select_device import device
# Out:
# /home/datamind/can/BASIL

# %%
# !pwd
# Out:
# /home/datamind/can/BASIL

# %%
torch.device(device)
# Out:
# device(type='cuda', index=1)

# %%
from pathlib import Path
import os
os.chdir("/home/datamind/can/BASIL")
mypath = Path().absolute()
print(mypath)
# Out:
# /home/datamind/can/BASIL

# %%
affixes = r"^การ|^ความ|^นัก|^ผู้|^ไอ้|กร$|^ที่\w+|^อย่าง|^แบบ|^โดย|^น่า"

# %%
import sys
sys.path.append('/home/can/Documents/thai_nlp_research/BASIL')

# %%
import basil

# %%
from basil.select_device import device

# %%
# %autoreload 2
from basil.preprocessing.prep_best_corpus import Best2010NECTEC
from basil.models.multitasks.BiLSTM_B import LSTMTagger
from basil.training.train_char_lvl_BILSTM_UB import TrainModel
# Out:
# /home/datamind/can/BASIL/basil/preprocessing/prep_best_corpus.py:9: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   cfg = yaml.load(ymlfile)

# %%
best2010  = Best2010NECTEC()
# Out:
# Preprocessing BEST2010 corpus
# Done!

# %%
best2010.train_data[0]
# Out:
# [['นุ้ย', 'NR', 'PER_B'],
#  ['EFM', 'FWN', 'ORG_B'],
#  ['งง', 'VV', 'O'],
#  ['หยาด', 'NR', 'PER_B'],
#  [' ', 'space', 'space'],
#  ['ขู่', 'VV', 'O'],
#  ['ฟ้อง', 'VV', 'O'],
#  ['ยัน', 'VV', 'O'],
#  ['ไม่', 'NEG', 'O'],
#  ['เจตนา', 'VV', 'O'],
#  ['พาดพิง', 'VV', 'O'],
#  [' ', 'space', 'space'],
#  ["'", 'PU', 'O'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  [' ', 'space', 'space'],
#  ['EFM', 'FWN', 'ORG_B'],
#  ["'", 'PU', 'O'],
#  [' ', 'space', 'space'],
#  ['งง', 'VV', 'O'],
#  [' ', 'space', 'space'],
#  ["'", 'PU', 'O'],
#  ['หยาด', 'NR', 'PER_B'],
#  ["'", 'PU', 'O'],
#  [' ', 'space', 'space'],
#  ['ขู่', 'VV', 'O'],
#  ['ฟ้อง', 'VV', 'O'],
#  [' ', 'space', 'space'],
#  ['ยัน', 'VV', 'O'],
#  ['ไม่', 'NEG', 'O'],
#  ['เจตนา', 'VV', 'O'],
#  ['พาดพิง', 'VV', 'O'],
#  ['ใคร', 'PDEM', 'O'],
#  [' ', 'space', 'space'],
#  ['แจง', 'VV', 'O'],
#  ['หัวเราะ', 'VV', 'O'],
#  ['เปล่า', 'NN', 'O'],
#  ['เยาะเย้ย', 'NN', 'O'],
#  [' ', 'space', 'space'],
#  ['แค่', 'PDT', 'O'],
#  ['สไตล์', 'NN', 'O'],
#  ['การ', 'FXN', 'O'],
#  ['จัด', 'VV', 'O'],
#  ['รายการ', 'NN', 'O'],
#  [' ', 'space', 'space'],
#  ['หลังจาก', 'CNJ', 'O'],
#  [' ', 'space', 'space'],
#  ['นางเอก', 'NN', 'O'],
#  ['สาว', 'JJA', 'O'],
#  [' ', 'space', 'space'],
#  ['หยาดทิพย์', 'NR', 'PER_B'],
#  [' ', 'space', 'space'],
#  ['ราชปาล', 'NR', 'PER_I'],
#  [' ', 'space', 'space'],
#  ['เปรย', 'NN', 'O'],
#  [' ', 'space', 'space'],
#  ['ๆ', 'PU', 'O'],
#  [' ', 'space', 'space'],
#  ['ว่า', 'COMP', 'O'],
#  [' ', 'space', 'space'],
#  ['อยาก', 'VV', 'O'],
#  ['จะ', 'AUX', 'O'],
#  ['ให้', 'COMP', 'O'],
#  ['ทาง', 'NN', 'O'],
#  [' ', 'space', 'space'],
#  ['EFM', 'FWN', 'ORG_B'],
#  [' ', 'space', 'space'],
#  ['รับผิดชอบ', 'VV', 'O'],
#  [' ', 'space', 'space'],
#  [' ', 'space', 'space'],
#  ['หลังจาก', 'CNJ', 'O'],
#  ['ปูด', 'VV', 'O'],
#  ['ข่าว', 'NN', 'O'],
#  ['ทำ', 'VV', 'O'],
#  ['ให้', 'COMP', 'O'],
#  ['เสีย', 'VV', 'O'],
#  ['ชื่อ', 'NN', 'O'],
#  ['ไม่', 'NEG', 'O'],
#  ['เช่น', 'NN', 'O'],
#  ['นั้น', 'DDEM', 'O'],
#  ['คง', 'AUX', 'O'],
#  ['ต้อง', 'AUX', 'O'],
#  ['พึ่ง', 'VV', 'O'],
#  ['กระบวน', 'NN', 'O'],
#  ['ทาง', 'NN', 'O'],
#  ['กฎหมาย', 'NN', 'O'],
#  [' ', 'space', 'space'],
#  [' ', 'space', 'space'],
#  ['ล่าสุด', 'ADV', 'O'],
#  [' ', 'space', 'space'],
#  ['ดีเจ', 'NN', 'TTL_B'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  [' ', 'space', 'space'],
#  ['คู่', 'NN', 'O'],
#  ['กรณี', 'NN', 'O'],
#  [' ', 'space', 'space'],
#  ['ออก', 'VV', 'O'],
#  ['มา', 'VV', 'O'],
#  ['ให้', 'VV', 'O'],
#  ['สัมภาษณ์', 'VV', 'O'],
#  ['เป็น', 'VV', 'O'],
#  ['ครั้ง', 'CL', 'O'],
#  ['แรก', 'JJA', 'O'],
#  [' ', 'space', 'space'],
#  ['ถึง', 'VV', 'O'],
#  ['เรื่องราว', 'NN', 'O'],
#  ['ที่', 'COMP', 'O'],
#  ['เกิด', 'VV', 'O'],
#  ['ขึ้น', 'ADV', 'O'],
#  ['ว่า', 'NN', 'O'],
#  [' ', 'space', 'space'],
#  ['ไม่', 'NEG', 'O'],
#  ['มี', 'VV', 'O'],
#  ['เจตนา', 'VV', 'O'],
#  ['จะ', 'AUX', 'O'],
#  ['พาดพิง', 'VV', 'O'],
#  ['ใคร', 'PDEM', 'O'],
#  [' ', 'space', 'space'],
#  [' ', 'space', 'space'],
#  ['ทั้งนี้', 'CNJ', 'O'],
#  [' ', 'space', 'space'],
#  ['ทำ', 'VV', 'O'],
#  ['ทุก', 'PDT', 'O'],
#  ['อย่าง', 'CL', 'O'],
#  ['ไป', 'VV', 'O'],
#  ['ตาม', 'VV', 'O'],
#  ['หน้าที่', 'NN', 'O'],
#  ['จริง', 'JJA', 'O'],
#  [' ', 'space', 'space'],
#  ['ๆ', 'PU', 'O'],
#  [' ', 'space', 'space'],
#  ['"', 'PU', 'O'],
#  ['คือ', 'VV', 'O'],
#  ['ตอน', 'ADV', 'O'],
#  ['นี้', 'DDEM', 'O'],
#  [' ', 'space', 'space'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  [' ', 'space', 'space'],
#  ['งง', 'VV', 'O'],
#  [' ', 'space', 'space'],
#  ['กับ', 'P', 'O'],
#  ['เรื่องราว', 'NN', 'O'],
#  ['ที่', 'COMP', 'O'],
#  ['เกิด', 'VV', 'O'],
#  ['ขึ้น', 'ADV', 'O'],
#  ['เหมือน', 'ADV', 'O'],
#  ['กัน', 'REFX', 'O'],
#  [' ', 'space', 'space'],
#  ['เพราะ', 'CNJ', 'O'],
#  ['ตอน', 'NN', 'O'],
#  ['ที่', 'COMP', 'O'],
#  [' ', 'space', 'space'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  [' ', 'space', 'space'],
#  ['ทำ', 'VV', 'O'],
#  ['รายการ', 'NN', 'O'],
#  [' ', 'space', 'space'],
#  ['ก็', 'AUX', 'O'],
#  ['ทำ', 'JJV', 'O'],
#  ['หน้าที่', 'NN', 'O'],
#  ['ไป', 'VV', 'O'],
#  ['ตาม', 'VV', 'O'],
#  ['ปกติ', 'ADV', 'O'],
#  [' ', 'space', 'space'],
#  ['เพื่อ', 'CNJ', 'O'],
#  ['ความ', 'FXN', 'O'],
#  ['สนุกสนาน', 'VV', 'O'],
#  ['ตลอด', 'ADV', 'O'],
#  [' ', 'space', 'space'],
#  ['ตอน', 'NN', 'O'],
#  ['จัด', 'VV', 'O'],
#  ['รายการ', 'NN', 'O'],
#  ['ไม่', 'NEG', 'O'],
#  ['ได้', 'AUX', 'O'],
#  ['คิด', 'VV', 'O'],
#  ['ถึง', 'VV', 'O'],
#  ['ใคร', 'PINT', 'O'],
#  [' ', 'space', 'space'],
#  ['หรือ', 'CNJ', 'O'],
#  ['พูด', 'VV', 'O'],
#  ['ถึง', 'P', 'O'],
#  ['ใคร', 'PINT', 'O'],
#  [' ', 'space', 'space'],
#  ['แล้ว', 'AUX', 'O'],
#  ['ก็', 'AUX', 'O'],
#  ['ไม่', 'NEG', 'O'],
#  ['ได้', 'AUX', 'O'],
#  ['มี', 'VV', 'O'],
#  ['เจตนา', 'VV', 'O'],
#  ['จะ', 'AUX', 'O'],
#  ['เอ่ย', 'VV', 'O'],
#  ['ถึง', 'P', 'O'],
#  ['ใคร', 'PINT', 'O'],
#  ['ด้วย', 'P', 'O'],
#  [' ', 'space', 'space'],
#  [' ', 'space', 'space'],
#  ['แม้กระทั่ง', 'CNJ', 'O'],
#  ['ตอน', 'NN', 'O'],
#  ['ที่', 'COMP', 'O'],
#  ['เล่า', 'VV', 'O'],
#  [' ', 'space', 'space'],
#  ['ๆ', 'PU', 'O'],
#  [' ', 'space', 'space'],
#  ['ไป', 'VV', 'O'],
#  ['ยัง', 'P', 'O'],
#  ['หัน', 'VV', 'O'],
#  ['หน้า', 'NN', 'O'],
#  ['มอง', 'VV', 'O'],
#  ['กับ', 'P', 'O'],
#  [' ', 'space', 'space'],
#  ['พี่', 'NN', 'TTL_B'],
#  ['ปอ', 'NR', 'PER_B'],
#  ['-', 'PU', 'O'],
#  ['วรฐก์', 'NR', 'PER_B'],
#  [' ', 'space', 'space'],
#  ['ว่า', 'COMP', 'O'],
#  ['มัน', 'PPER', 'O'],
#  ['เป็น', 'VV', 'O'],
#  ['แค่', 'PDT', 'O'],
#  ['เรื่อง', 'NN', 'O'],
#  [' ', 'space', 'space'],
#  ['ๆ', 'PU', 'O'],
#  [' ', 'space', 'space'],
#  ['หนึ่ง', 'NN', 'O'],
#  ['เท่านั้น', 'ADV', 'O'],
#  ['เอง', 'REFX', 'O'],
#  [' ', 'space', 'space'],
#  [' ', 'space', 'space'],
#  ['แล้ว', 'AUX', 'O'],
#  ['เรา', 'PPER', 'O'],
#  ['สอง', 'CD', 'MEA_B'],
#  ['คน', 'CL', 'MEA_I'],
#  ['ก็', 'AUX', 'O'],
#  ['ไม่', 'NEG', 'O'],
#  ['รู้', 'VV', 'O'],
#  ['เรื่อง', 'NN', 'O'],
#  ['นี้', 'DDEM', 'O'],
#  [' ', 'space', 'space'],
#  [' ', 'space', 'space'],
#  ['แล้ว', 'AUX', 'O'],
#  ['ตอน', 'NN', 'O'],
#  ['ที่', 'COMP', 'O'],
#  ['พูด', 'VV', 'O'],
#  ['ออก', 'ADV', 'O'],
#  ['ไป', 'VV', 'O'],
#  ['ก็', 'AUX', 'O'],
#  ['ไม่', 'NEG', 'O'],
#  ['ได้', 'AUX', 'O'],
#  ['มี', 'VV', 'O'],
#  ['โอกาส', 'NN', 'O'],
#  ['จะ', 'AUX', 'O'],
#  ['นึก', 'VV', 'O'],
#  ['ถึง', 'VV', 'O'],
#  ['ใคร', 'PINT', 'O'],
#  ['ด้วย', 'P', 'O'],
#  ['ซ้ำ', 'ADV', 'O'],
#  [' ', 'space', 'space'],
#  ['เพราะ', 'CNJ', 'O'],
#  ['ต้อง', 'AUX', 'O'],
#  ['เตรียม', 'VV', 'O'],
#  ['ข่าว', 'NN', 'O'],
#  ['ต่อไป', 'ADV', 'O'],
#  [' ', 'space', 'space'],
#  ['รายการ', 'NN', 'O'],
#  ['เรา', 'PPER', 'O'],
#  ['เป็น', 'VV', 'O'],
#  ['รายการ', 'NN', 'O'],
#  ['สด', 'JJA', 'O'],
#  [' ', 'space', 'space'],
#  ['2', 'CD', 'MEA_B'],
#  [' ', 'space', 'space'],
#  ['ชั่วโมง', 'CL', 'MEA_B'],
#  [' ', 'space', 'space'],
#  [' ', 'space', 'space'],
#  ['วัน', 'NN', 'O'],
#  ['นี้', 'DDEM', 'O'],
#  [' ', 'space', 'space'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  ['อยาก', 'VV', 'O'],
#  ['ให้', 'COMP', 'O'],
#  ['ดู', 'VV', 'O'],
#  ['ที่', 'P', 'O'],
#  ['เจตนา', 'VV', 'O'],
#  ['มาก', 'ADV', 'O'],
#  ['กว่า', 'ADV', 'O'],
#  [' ', 'space', 'space'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  ['ยืนยัน', 'VV', 'O'],
#  ['ว่า', 'COMP', 'O'],
#  [' ', 'space', 'space'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  ['ไม่', 'NEG', 'O'],
#  ['ได้', 'AUX', 'O'],
#  ['เอ่ย', 'VV', 'O'],
#  ['ถึง', 'P', 'O'],
#  ['ใคร', 'PDEM', 'O'],
#  ['เลย', 'PAR', 'O'],
#  ['แม้', 'CNJ', 'O'],
#  ['ซัก', 'VV', 'O'],
#  ['คน', 'CL', 'O'],
#  ['เดียว', 'CD', 'NUM_B'],
#  ['"', 'PU', 'O'],
#  [' ', 'space', 'space'],
#  ['แล้ว', 'AUX', 'O'],
#  ['ที่', 'COMP', 'O'],
#  ['หยาด', 'NR', 'PER_B'],
#  ['พูด', 'VV', 'O'],
#  ['ถึง', 'VV', 'O'],
#  ['เรื่อง', 'NN', 'O'],
#  ['ฟ้อง', 'VV', 'O'],
#  ['ล่ะ', 'PAR', 'O'],
#  [' ', 'space', 'space'],
#  [' ', 'space', 'space'],
#  ['"', 'PU', 'O'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  ['คิด', 'VV', 'O'],
#  ['ว่า', 'COMP', 'O'],
#  ['ไม่', 'NEG', 'O'],
#  ['น่า', 'AUX', 'O'],
#  ['จะ', 'AUX', 'O'],
#  ['ใหญ่โต', 'VA', 'O'],
#  [' ', 'space', 'space'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  ['ขอ', 'VV', 'O'],
#  ['ยืนยัน', 'VV', 'O'],
#  [' ', 'space', 'space'],
#  ['เรา', 'PPER', 'O'],
#  ['มี', 'VV', 'O'],
#  ['ใจ', 'NN', 'O'],
#  ['บริสุทธิ์', 'JJA', 'O'],
#  ['ไม่', 'NEG', 'O'],
#  ['ได้', 'AUX', 'O'],
#  ['มี', 'VV', 'O'],
#  ['เจตนา', 'VV', 'O'],
#  ['จะ', 'AUX', 'O'],
#  ['พูด', 'VV', 'O'],
#  ['ถึง', 'VV', 'O'],
#  ['ใคร', 'PDEM', 'O'],
#  ['เลย', 'PAR', 'O'],
#  ['ครับ', 'PAR', 'O'],
#  ['"', 'PU', 'O'],
#  [' ', 'space', 'space'],
#  [' ', 'space', 'space'],
#  ['จะ', 'AUX', 'O'],
#  ['มี', 'VV', 'O'],
#  ['การ', 'FXN', 'O'],
#  ['ขอโทษ', 'VV', 'O'],
#  ['กัน', 'REFX', 'O'],
#  ['มั้ย', 'PAR', 'O'],
#  [' ', 'space', 'space'],
#  [' ', 'space', 'space'],
#  ['"', 'PU', 'O'],
#  ['อย่าง', 'FXAV', 'O'],
#  ['ที่', 'COMP', 'O'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  ['บอก', 'VV', 'O'],
#  ['ไป', 'VV', 'O'],
#  ['ว่า', 'COMP', 'O'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  ['ไม่', 'NEG', 'O'],
#  ['ได้', 'AUX', 'O'],
#  ['เอ่ย', 'VV', 'O'],
#  ['เรา', 'PPER', 'O'],
#  ['กุ', 'VV', 'O'],
#  ['ข่าว', 'NN', 'O'],
#  ['ขึ้น', 'ADV', 'O'],
#  ['มา', 'VV', 'O'],
#  ['หรือ', 'CNJ', 'O'],
#  ['เปล่า', 'PINT', 'O'],
#  [' ', 'space', 'space'],
#  ['"', 'PU', 'O'],
#  [' ', 'space', 'space'],
#  ['รายการ', 'NN', 'O'],
#  ['ของ', 'P', 'O'],
#  ['เรา', 'DPER', 'O'],
#  ['เป็น', 'VV', 'O'],
#  ['เรื่องราว', 'NN', 'O'],
#  ['ที่', 'COMP', 'O'],
#  ['ให้', 'COMP', 'O'],
#  ['สีสัน', 'VV', 'O'],
#  ['กับ', 'P', 'O'],
#  ['วงการ', 'NN', 'ORG_B'],
#  ['บันเทิง', 'NN', 'ORG_I'],
#  [' ', 'space', 'space'],
#  ['สนุกสนาน', 'ADV', 'O'],
#  [' ', 'space', 'space'],
#  ['แล้ว', 'AUX', 'O'],
#  ['ใน', 'P', 'O'],
#  ['ส่วน', 'NN', 'O'],
#  ['ของ', 'P', 'O'],
#  ['ข่าว', 'NN', 'O'],
#  ['ก็', 'AUX', 'O'],
#  ['อยู่', 'VV', 'O'],
#  ['ใน', 'P', 'O'],
#  ['กระบวนการ', 'NN', 'O'],
#  [' ', 'space', 'space'],
#  ['การ', 'FXN', 'O'],
#  ['ทำ', 'VV', 'O'],
#  ['ข่าว', 'NN', 'O'],
#  [' ', 'space', 'space'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  ['ไม่', 'NEG', 'O'],
#  ['ขอ', 'VV', 'O'],
#  ['ลง', 'VV', 'O'],
#  ['ลึก', 'ADV', 'O'],
#  ['ดี', 'ADV', 'O'],
#  ['กว่า', 'ADV', 'O'],
#  ['ครับ', 'PAR', 'O'],
#  ['"', 'PU', 'O'],
#  [' ', 'space', 'space'],
#  [' ', 'space', 'space'],
#  ['หยาด', 'NR', 'PER_B'],
#  ['และ', 'CNJ', 'O'],
#  ['คุณ', 'NN', 'O'],
#  ['แม่', 'NN', 'O'],
#  ['ไม่', 'NEG', 'O'],
#  ['พอใจ', 'VV', 'O'],
#  [' ', 'space', 'space'],
#  ['ตรง', 'P', 'O'],
#  ['ที่', 'COMP', 'O'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  ['พูด', 'VV', 'O'],
#  ['ไป', 'VV', 'O'],
#  ['หัวเราะ', 'VV', 'O'],
#  ['ไป', 'VV', 'O'],
#  [' ', 'space', 'space'],
#  ['เหมือน', 'ADV', 'O'],
#  ['ไป', 'VV', 'O'],
#  ['เยาะเย้ย', 'VV', 'O'],
#  ['เค้า', 'NN', 'O'],
#  [' ', 'space', 'space'],
#  [' ', 'space', 'space'],
#  ['"', 'PU', 'O'],
#  ['เกี่ยว', 'P', 'O'],
#  ['กับ', 'P', 'O'],
#  ['เรื่อง', 'NN', 'O'],
#  ['หัวเราะ', 'NN', 'O'],
#  [' ', 'space', 'space'],
#  ['ถ้า', 'CNJ', 'O'],
#  ['ใคร', 'PDEM', 'O'],
#  ['ฟัง', 'VV', 'O'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  ['ตั้งแต่', 'P', 'O'],
#  ['ตอน', 'NN', 'O'],
#  ['จัด', 'VV', 'O'],
#  ['รายการ', 'NN', 'O'],
#  ['ใหม่', 'JJA', 'O'],
#  [' ', 'space', 'space'],
#  ['ๆ', 'PU', 'O'],
#  [' ', 'space', 'space'],
#  ['ก็', 'AUX', 'O'],
#  ['จะ', 'AUX', 'O'],
#  ['รู้', 'VV', 'O'],
#  ['ว่า', 'COMP', 'O'],
#  [' ', 'space', 'space'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  ['จะ', 'AUX', 'O'],
#  ['หัวเราะ', 'VV', 'O'],
#  ['ตลอด', 'ADV', 'O'],
#  ['การ', 'FXN', 'O'],
#  ['จัด', 'VV', 'O'],
#  ['รายการ', 'NN', 'O'],
#  ['อยู่แล้ว', 'ADV', 'O'],
#  [' ', 'space', 'space'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  ['เป็น', 'VV', 'O'],
#  ['คน', 'NN', 'O'],
#  ['อารมณ์', 'NN', 'O'],
#  ['ดี', 'ADV', 'O'],
#  ['ครับ', 'PAR', 'O'],
#  [' ', 'space', 'space'],
#  ['พูด', 'VV', 'O'],
#  ['ไป', 'VV', 'O'],
#  ['ขำ', 'VV', 'O'],
#  ['ไป', 'VV', 'O'],
#  [' ', 'space', 'space'],
#  ['เป็น', 'VV', 'O'],
#  ['สไตล์', 'NN', 'O'],
#  ['การ', 'FXN', 'O'],
#  ['จัด', 'VV', 'O'],
#  ['ของ', 'P', 'O'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  ['อยู่แล้ว', 'ADV', 'O'],
#  [' ', 'space', 'space'],
#  ['ตอน', 'NN', 'O'],
#  ['แรก', 'ADV', 'O'],
#  [' ', 'space', 'space'],
#  ['ๆ', 'PU', 'O'],
#  [' ', 'space', 'space'],
#  ['คน', 'CL', 'O'],
#  ['ก็', 'AUX', 'O'],
#  ['ติง', 'VV', 'O'],
#  ['ว่า', 'COMP', 'O'],
#  [' ', 'space', 'space'],
#  ['หัวเราะ', 'VV', 'O'],
#  ['เยอะ', 'ADV', 'O'],
#  ['ไป', 'VV', 'O'],
#  [' ', 'space', 'space'],
#  ['พอ', 'P', 'O'],
#  ['หลัง', 'CNJ', 'O'],
#  [' ', 'space', 'space'],
#  ['ๆ', 'PU', 'O'],
#  [' ', 'space', 'space'],
#  ['หัวเราะ', 'VV', 'O'],
#  ['น้อย', 'ADV', 'O'],
#  ['ลง', 'VV', 'O'],
#  ['ก็', 'AUX', 'O'],
#  ['บอก', 'VV', 'O'],
#  ['ว่า', 'COMP', 'O'],
#  [' ', 'space', 'space'],
#  ['หัวเราะ', 'VV', 'O'],
#  ['อีก', 'ADV', 'O'],
#  ['ได้', 'AUX', 'O'],
#  ['มั้ย', 'PAR', 'O'],
#  [' ', 'space', 'space'],
#  ['ชอบ', 'VV', 'O'],
#  ['เสียง', 'NN', 'O'],
#  ['หัวเราะ', 'VV', 'O'],
#  [' ', 'space', 'space'],
#  ['มัน', 'PPER', 'O'],
#  ['เป็น', 'VV', 'O'],
#  ['ธรรมชาติ', 'NN', 'O'],
#  ['ของ', 'P', 'O'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  ['ครับ', 'PAR', 'O'],
#  ['"', 'PU', 'O'],
#  [' ', 'space', 'space'],
#  [' ', 'space', 'space'],
#  ['จะ', 'AUX', 'O'],
#  ['ทำ', 'VV', 'O'],
#  ['ให้', 'COMP', 'O'],
#  ['ลด', 'VV', 'O'],
#  ['ความ', 'FXN', 'O'],
#  ['หวือหวา', 'VV', 'O'],
#  ['ใน', 'P', 'O'],
#  ['การ', 'FXN', 'O'],
#  ['จัด', 'VV', 'O'],
#  ['รายการ', 'NN', 'O'],
#  ['มั้ย', 'PAR', 'O'],
#  [' ', 'space', 'space'],
#  [' ', 'space', 'space'],
#  ['"', 'PU', 'O'],
#  ['แต่ละ', 'PDT', 'O'],
#  ['คน', 'CL', 'O'],
#  ['ก็', 'AUX', 'O'],
#  ['มี', 'VV', 'O'],
#  ['สไตล์', 'NN', 'O'],
#  ['การ', 'FXN', 'O'],
#  ['จัด', 'VV', 'O'],
#  ['รายการ', 'NN', 'O'],
#  ['ที่', 'COMP', 'O'],
#  ['แตกต่าง', 'VV', 'O'],
#  ['กัน', 'REFX', 'O'],
#  ['ไป', 'VV', 'O'],
#  [' ', 'space', 'space'],
#  ['ดีเจ', 'NN', 'O'],
#  ['ก็', 'AUX', 'O'],
#  ['มี', 'VV', 'O'],
#  ['หลาย', 'PDT', 'O'],
#  ['คน', 'CL', 'O'],
#  [' ', 'space', 'space'],
#  ['เพราะฉะนั้น', 'CNJ', 'O'],
#  ['การ', 'FXN', 'O'],
#  ['จัด', 'VV', 'O'],
#  ['รายการ', 'NN', 'O'],
#  ['ก็', 'AUX', 'O'],
#  ['คง', 'AUX', 'O'],
#  ['เหมือน', 'ADV', 'O'],
#  ['เดิม', 'ADV', 'O'],
#  [' ', 'space', 'space'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  ['ก็', 'CNJ', 'O'],
#  ['ยัง', 'AUX', 'O'],
#  ['จัด', 'VV', 'O'],
#  ['รายการ', 'NN', 'O'],
#  ['เหมือน', 'VV', 'O'],
#  ['เดิม', 'ADV', 'O'],
#  [' ', 'space', 'space'],
#  ['แล้ว', 'AUX', 'O'],
#  ['ก็', 'AUX', 'O'],
#  ['ออก', 'VV', 'O'],
#  ['ทำ', 'VV', 'O'],
#  ['ข่าว', 'NN', 'O'],
#  ['ตาม', 'VV', 'O'],
#  ['ปกติ', 'ADV', 'O'],
#  ['"', 'PU', 'O'],
#  [' ', 'space', 'space'],
#  [' ', 'space', 'space'],
#  ['พี่', 'NN', 'TTL_B'],
#  ['ฉอด', 'NR', 'PER_B'],
#  ['-', 'PU', 'O'],
#  ['สายทิพย์', 'NR', 'PER_B'],
#  [' ', 'space', 'space'],
#  ['ให้', 'COMP', 'O'],
#  ['คำ', 'NN', 'O'],
#  ['แนะนำ', 'JJV', 'O'],
#  ['อย่าง', 'FXAV', 'O'],
#  ['ไร', 'PDEM', 'O'],
#  ['บ้าง', 'PDEM', 'O'],
#  [' ', 'space', 'space'],
#  [' ', 'space', 'space'],
#  ['"', 'PU', 'O'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  ['ไม่', 'NEG', 'O'],
#  ['อยาก', 'VV', 'O'],
#  ['จะ', 'AUX', 'O'],
#  ['พาดพิง', 'VV', 'O'],
#  ['ถึง', 'VV', 'O'],
#  [' ', 'space', 'space'],
#  ['เพราะ', 'CNJ', 'O'],
#  ['ท่าน', 'PPER', 'O'],
#  ['เอง', 'REFX', 'O'],
#  ['ก็', 'AUX', 'O'],
#  ['ไม่', 'NEG', 'O'],
#  ['ได้', 'AUX', 'O'],
#  ['ลง', 'VV', 'O'],
#  ['มา', 'VV', 'O'],
#  ['ข้อง', 'VV', 'O'],
#  ['เกี่ยว', 'P', 'O'],
#  ['กับ', 'P', 'O'],
#  ['ตรง', 'NN', 'O'],
#  ['นี้', 'DDEM', 'O'],
#  [' ', 'space', 'space'],
#  ['ก็', 'AUX', 'O'],
#  ['ไม่', 'NEG', 'O'],
#  ['มี', 'VV', 'O'],
#  ['ใคร', 'PDEM', 'O'],
#  ['แนะนำ', 'VV', 'O'],
#  ['อะไร', 'PDEM', 'O'],
#  ['มาก', 'JJA', 'O'],
#  [' ', 'space', 'space'],
#  ['เพราะ', 'CNJ', 'O'],
#  ['เป็น', 'VV', 'O'],
#  ['เรื่อง', 'NN', 'O'],
#  ['ที่', 'COMP', 'O'],
#  ['เกิด', 'VV', 'O'],
#  ['ขึ้น', 'ADV', 'O'],
#  ['ภาย', 'NN', 'O'],
#  ['ใน', 'P', 'O'],
#  ['คลื่น', 'NN', 'O'],
#  ['เรา', 'PPER', 'O'],
#  [' ', 'space', 'space'],
#  ['แต่', 'CNJ', 'O'],
#  ['ถ้า', 'CNJ', 'O'],
#  ['เกิด', 'VV', 'O'],
#  ['อะไร', 'PDEM', 'O'],
#  ['ขึ้น', 'ADV', 'O'],
#  ['จริง', 'ADV', 'O'],
#  ['ๆ', 'PU', 'O'],
#  [' ', 'space', 'space'],
#  ['คง', 'AUX', 'O'],
#  ['ต้อง', 'AUX', 'O'],
#  ['ปรึกษา', 'VV', 'O'],
#  ['กับ', 'P', 'O'],
#  ['ผู้', 'FXN', 'O'],
#  ['ใหญ่', 'JJA', 'O'],
#  ['อีก', 'ADV', 'O'],
#  ['ที', 'ADV', 'O'],
#  ['ครับ', 'PAR', 'O'],
#  ['"', 'PU', 'O'],
#  [' ', 'space', 'space'],
#  [' ', 'space', 'space'],
#  ['ถึง', 'VV', 'O'],
#  ['ใคร', 'PINT', 'O'],
#  [' ', 'space', 'space'],
#  ['ก็', 'AUX', 'O'],
#  ['เลย', 'PAR', 'O'],
#  ['ไม่', 'NEG', 'O'],
#  ['รู้', 'VV', 'O'],
#  ['ว่า', 'COMP', 'O'],
#  [' ', 'space', 'space'],
#  ['จะ', 'AUX', 'O'],
#  ['ต้อง', 'AUX', 'O'],
#  ['ไป', 'VV', 'O'],
#  ['ขอโทษ', 'VV', 'O'],
#  ['ใคร', 'PDEM', 'O'],
#  ['เหมือน', 'ADV', 'O'],
#  ['กัน', 'REFX', 'O'],
#  [' ', 'space', 'space'],
#  ['เพราะ', 'CNJ', 'O'],
#  ['ไม่', 'NEG', 'O'],
#  ['ได้', 'AUX', 'O'],
#  ['มี', 'VV', 'O'],
#  ['เจตนา', 'VV', 'O'],
#  ['ตรง', 'P', 'O'],
#  ['นั้น', 'DDEM', 'O'],
#  [' ', 'space', 'space'],
#  [' ', 'space', 'space'],
#  ['การ', 'NN', 'O'],
#  ['ที่', 'COMP', 'O'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  ['พูด', 'VV', 'O'],
#  ['ออก', 'ADV', 'O'],
#  ['ไป', 'VV', 'O'],
#  ['ใคร', 'PINT', 'O'],
#  ['จะ', 'AUX', 'O'],
#  ['ไป', 'VV', 'O'],
#  ['คิด', 'VV', 'O'],
#  ['หรือ', 'CNJ', 'O'],
#  ['ตีความ', 'VV', 'O'],
#  ['ต่อ', 'ADV', 'O'],
#  ['ก็', 'AUX', 'O'],
#  ['เป็น', 'VV', 'O'],
#  ['สิทธิ', 'NN', 'O'],
#  ['ส่วน', 'NN', 'O'],
#  ['บุคคล', 'NN', 'O'],
#  ['อยู่แล้ว', 'ADV', 'O'],
#  ['ไง', 'PINT', 'O'],
#  ['ครับ', 'PAR', 'O'],
#  [' ', 'space', 'space'],
#  [' ', 'space', 'space'],
#  ['อยาก', 'VV', 'O'],
#  ['ให้', 'COMP', 'O'],
#  ['ทุก', 'PDT', 'O'],
#  ['คน', 'CL', 'O'],
#  ['ได้', 'AUX', 'O'],
#  ['ย้อนกลับ', 'VV', 'O'],
#  ['ไป', 'VV', 'O'],
#  ['ฟัง', 'VV', 'O'],
#  ['รายการ', 'NN', 'O'],
#  [' ', 'space', 'space'],
#  ['วัน', 'NN', 'O'],
#  ['นั้น', 'DDEM', 'O'],
#  ['พูด', 'VV', 'O'],
#  ['กว้าง', 'ADV', 'O'],
#  ['มาก', 'ADV', 'O'],
#  [' ', 'space', 'space'],
#  ['ไม่', 'NEG', 'O'],
#  ['ได้', 'AUX', 'O'],
#  ['ชี้', 'VV', 'O'],
#  ['ชัด', 'ADV', 'O'],
#  ['ระบุ', 'VV', 'O'],
#  ['ไป', 'VV', 'O'],
#  ['ที่', 'P', 'O'],
#  ['ใคร', 'PDEM', 'O'],
#  ['พูด', 'VV', 'O'],
#  ['แค่', 'PDT', 'O'],
#  ['ว่า', 'COMP', 'O'],
#  [' ', 'space', 'space'],
#  ['นางเอก', 'NN', 'O'],
#  ['หน้า', 'P', 'O'],
#  ['คม', 'NN', 'O'],
#  ['คน', 'CL', 'O'],
#  ['หนึ่ง', 'NN', 'O'],
#  ['เท่านั้น', 'ADV', 'O'],
#  ['เอง', 'REFX', 'O'],
#  ['ครับ', 'PAR', 'O'],
#  ['"', 'PU', 'O'],
#  ['\n', 'space', 'space']]

# %%
trainer = TrainModel(LSTMTagger, best2010,2)
trainer.train(40)
# Out:
# Training
# Num of training text file: 4975
#  epoch 0: 59m 21s loss:0.6123 accuracy POS:0.8886 accuracy NER:0.9027epoch: 0
# F1 (POS): 0.9449171346810106 F1 (NER) 0.7626288069613006
#  epoch 1: 118m 16s loss:0.4378 accuracy POS:0.9054 accuracy NER:0.9556epoch: 1
# F1 (POS): 0.9529817742206987 F1 (NER) 0.7889773871646985
#  epoch 2: 176m 46s loss:0.4871 accuracy POS:0.9063 accuracy NER:0.9177epoch: 2
# F1 (POS): 0.9556827398350345 F1 (NER) 0.8003830020062009
#  epoch 3: 235m 16s loss:0.3957 accuracy POS:0.9239 accuracy NER:0.9519epoch: 3
# F1 (POS): 0.9565397034293847 F1 (NER) 0.8053042621899548
#  epoch 4: 293m 40s loss:0.4575 accuracy POS:0.9059 accuracy NER:0.9318epoch: 4
# F1 (POS): 0.9578557546635653 F1 (NER) 0.8088481375358167
#  epoch 5: 352m 2s loss:0.4477 accuracy POS:0.9084 accuracy NER:0.95343epoch: 5
# F1 (POS): 0.9586515065726047 F1 (NER) 0.8127392017495899
#  epoch 6: 410m 37s loss:0.4348 accuracy POS:0.9095 accuracy NER:0.9354epoch: 6
# F1 (POS): 0.9593477894930142 F1 (NER) 0.8127252278100398
#  epoch 7: 469m 5s loss:0.3860 accuracy POS:0.9217 accuracy NER:0.95641epoch: 7
# F1 (POS): 0.9589422620778306 F1 (NER) 0.8137459567341884
#  epoch 8: 527m 36s loss:0.4539 accuracy POS:0.9018 accuracy NER:0.9300epoch: 8
# F1 (POS): 0.9595390760096102 F1 (NER) 0.8142850593682666
#  epoch 9: 586m 0s loss:0.4167 accuracy POS:0.9254 accuracy NER:0.95198epoch: 9
# F1 (POS): 0.959791574211517 F1 (NER) 0.8156064073226544
#  epoch 10: 644m 30s loss:0.4513 accuracy POS:0.8995 accuracy NER:0.9386epoch: 10
# F1 (POS): 0.9602277074693559 F1 (NER) 0.8132250314609313
#  epoch 11: 702m 52s loss:0.3903 accuracy POS:0.9202 accuracy NER:0.9519epoch: 11
# F1 (POS): 0.9603042220759943 F1 (NER) 0.8164662391894667
#  epoch 12: 761m 25s loss:0.4328 accuracy POS:0.9104 accuracy NER:0.9449epoch: 12
# F1 (POS): 0.9603501308399773 F1 (NER) 0.8173522263493374
#  epoch 13: 820m 1s loss:0.3375 accuracy POS:0.9231 accuracy NER:0.96018epoch: 13
# F1 (POS): 0.9609928535357399 F1 (NER) 0.8155192612500862
#  epoch 14: 878m 38s loss:0.4127 accuracy POS:0.9090 accuracy NER:0.9481epoch: 14
# F1 (POS): 0.960273616233339 F1 (NER) 0.8177461317266878
#  epoch 15: 939m 11s loss:0.3566 accuracy POS:0.9231 accuracy NER:0.9571epoch: 15
# F1 (POS): 0.9608168699404717 F1 (NER) 0.8168345093740724
#  epoch 16: 998m 34s loss:0.4287 accuracy POS:0.9090 accuracy NER:0.9454epoch: 16
# F1 (POS): 0.96089338454711 F1 (NER) 0.8172742364632843
#  epoch 17: 1057m 19s loss:0.3693 accuracy POS:0.9254 accuracy NER:0.9564epoch: 17
# F1 (POS): 0.9604036910646242 F1 (NER) 0.8168162667155157
#  epoch 18: 1115m 50s loss:0.4368 accuracy POS:0.9127 accuracy NER:0.9472epoch: 18
# F1 (POS): 0.9608168699404717 F1 (NER) 0.81791452991453
#  epoch 19: 1174m 16s loss:0.3392 accuracy POS:0.9320 accuracy NER:0.9675epoch: 19
# F1 (POS): 0.9616279247708388 F1 (NER) 0.8169474592434494
#  epoch 20: 1232m 53s loss:0.3713 accuracy POS:0.9268 accuracy NER:0.9440epoch: 20
# F1 (POS): 0.9613218663442851 F1 (NER) 0.8170325407329652
#  epoch 21: 1291m 19s loss:0.3120 accuracy POS:0.9350 accuracy NER:0.9704epoch: 21
# F1 (POS): 0.9608321728617993 F1 (NER) 0.8143627719875662
#  epoch 22: 1349m 51s loss:0.4400 accuracy POS:0.9022 accuracy NER:0.9527epoch: 22
# F1 (POS): 0.9611764885916722 F1 (NER) 0.8155033802302211
#  epoch 23: 1408m 16s loss:0.3248 accuracy POS:0.9276 accuracy NER:0.9645epoch: 23
# F1 (POS): 0.9609392933110931 F1 (NER) 0.8152399171050535
#  epoch 24: 1466m 49s loss:0.4110 accuracy POS:0.9100 accuracy NER:0.9404epoch: 24
# F1 (POS): 0.9614748955575619 F1 (NER) 0.8148622092226132
#  epoch 25: 1525m 17s loss:0.3207 accuracy POS:0.9387 accuracy NER:0.9630epoch: 25
# F1 (POS): 0.9611305798276891 F1 (NER) 0.8172996068271177
#  epoch 26: 1583m 56s loss:0.4257 accuracy POS:0.9050 accuracy NER:0.9518epoch: 26
# F1 (POS): 0.961138231288353 F1 (NER) 0.8186122746312148
#  epoch 27: 1642m 22s loss:0.4109 accuracy POS:0.9261 accuracy NER:0.9505epoch: 27
# F1 (POS): 0.9615514101642003 F1 (NER) 0.8172636282802489
#  epoch 28: 1700m 55s loss:0.3909 accuracy POS:0.9122 accuracy NER:0.9554epoch: 28
# F1 (POS): 0.9615055014002173 F1 (NER) 0.8176421081363875
#  epoch 29: 1759m 25s loss:0.3346 accuracy POS:0.9283 accuracy NER:0.9615epoch: 29
# F1 (POS): 0.9610999739850338 F1 (NER) 0.8170850846302397
#  epoch 30: 1818m 1s loss:0.3886 accuracy POS:0.9086 accuracy NER:0.96045epoch: 30
# F1 (POS): 0.9613142148836212 F1 (NER) 0.8148299877099549
#  epoch 31: 1876m 32s loss:0.2982 accuracy POS:0.9379 accuracy NER:0.9689epoch: 31
# F1 (POS): 0.9612223973556552 F1 (NER) 0.8163060348762896
#  epoch 32: 1935m 6s loss:0.4101 accuracy POS:0.9140 accuracy NER:0.94680epoch: 32
# F1 (POS): 0.9611458827490168 F1 (NER) 0.8138987312835753
#  epoch 33: 1993m 34s loss:0.3206 accuracy POS:0.9357 accuracy NER:0.9652epoch: 33
# F1 (POS): 0.9610311108390591 F1 (NER) 0.8151260504201682
#  epoch 34: 2052m 9s loss:0.4085 accuracy POS:0.9154 accuracy NER:0.94683epoch: 34
# F1 (POS): 0.9610540652210507 F1 (NER) 0.8144026634437781
#  epoch 35: 2110m 44s loss:0.3130 accuracy POS:0.9342 accuracy NER:0.9615epoch: 35
# F1 (POS): 0.9612530031983105 F1 (NER) 0.8151849063490978
#  epoch 36: 2170m 14s loss:0.3976 accuracy POS:0.9150 accuracy NER:0.9536epoch: 36
# F1 (POS): 0.9609928535357399 F1 (NER) 0.8145065939063211
#  epoch 37: 2229m 28s loss:0.2831 accuracy POS:0.9364 accuracy NER:0.9645epoch: 37
# F1 (POS): 0.961230048816319 F1 (NER) 0.8152481945333211
#  epoch 38: 2288m 19s loss:0.3926 accuracy POS:0.9168 accuracy NER:0.9531epoch: 38
# F1 (POS): 0.9615514101642003 F1 (NER) 0.8133896949617273
#  epoch 39: 2346m 28s loss:0.2940 accuracy POS:0.9401 accuracy NER:0.9704epoch: 39
# F1 (POS): 0.9609239903897654 F1 (NER) 0.816747711343972

# %%
filehandle = open('done_bilstm_ub2.txt', 'w')
filehandle.write('2\n')
filehandle.close()
