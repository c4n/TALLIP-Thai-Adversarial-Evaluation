# %%
# %load_ext autoreload
# %autoreload 2
import torch
import math
from pathlib import Path
import os
os.chdir("/home/datamind/can/BASIL")
mypath = Path().absolute()
print(mypath)
from basil.select_device import device
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# /home/datamind/can/BASIL

# %%
# !pwd
# Out:
# /home/datamind/can/BASIL/notebook

# %%
torch.device(device)
# Out:
# device(type='cuda', index=0)

# %%
from pathlib import Path
import os
os.chdir("/home/datamind/can/BASIL")
mypath = Path().absolute()
print(mypath)
# Out:
# /home/datamind/can/BASIL

# %%
affixes = r"^การ|^ความ|^นัก|^ผู้|^ไอ้|กร$|^ที่\w+|^อย่าง|^แบบ|^โดย|^น่า"

# %%
import sys
sys.path.append('/home/datamind/can/BASIL')

# %%
import basil

# %%
from basil.select_device import device

# %%
# %autoreload 2
from basil.preprocessing.prep_best_corpus import Best2010NECTEC
from basil.models.multitasks.wordlvl_lstm import LSTMTagger
from basil.training.train_word_lvl import TrainModel
# Out:
# /home/datamind/can/BASIL/basil/preprocessing/prep_best_corpus.py:9: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   cfg = yaml.load(ymlfile)

# %%
best2010  = Best2010NECTEC()
# Out:
# Preprocessing BEST2010 corpus
# Done!

# %%
best2010.train_data[0]
# Out:
# [['นุ้ย', 'NR', 'PER_B'],
#  ['EFM', 'FWN', 'ORG_B'],
#  ['งง', 'VV', 'O'],
#  ['หยาด', 'NR', 'PER_B'],
#  [' ', 'space', 'space'],
#  ['ขู่', 'VV', 'O'],
#  ['ฟ้อง', 'VV', 'O'],
#  ['ยัน', 'VV', 'O'],
#  ['ไม่', 'NEG', 'O'],
#  ['เจตนา', 'VV', 'O'],
#  ['พาดพิง', 'VV', 'O'],
#  [' ', 'space', 'space'],
#  ["'", 'PU', 'O'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  [' ', 'space', 'space'],
#  ['EFM', 'FWN', 'ORG_B'],
#  ["'", 'PU', 'O'],
#  [' ', 'space', 'space'],
#  ['งง', 'VV', 'O'],
#  [' ', 'space', 'space'],
#  ["'", 'PU', 'O'],
#  ['หยาด', 'NR', 'PER_B'],
#  ["'", 'PU', 'O'],
#  [' ', 'space', 'space'],
#  ['ขู่', 'VV', 'O'],
#  ['ฟ้อง', 'VV', 'O'],
#  [' ', 'space', 'space'],
#  ['ยัน', 'VV', 'O'],
#  ['ไม่', 'NEG', 'O'],
#  ['เจตนา', 'VV', 'O'],
#  ['พาดพิง', 'VV', 'O'],
#  ['ใคร', 'PDEM', 'O'],
#  [' ', 'space', 'space'],
#  ['แจง', 'VV', 'O'],
#  ['หัวเราะ', 'VV', 'O'],
#  ['เปล่า', 'NN', 'O'],
#  ['เยาะเย้ย', 'NN', 'O'],
#  [' ', 'space', 'space'],
#  ['แค่', 'PDT', 'O'],
#  ['สไตล์', 'NN', 'O'],
#  ['การ', 'FXN', 'O'],
#  ['จัด', 'VV', 'O'],
#  ['รายการ', 'NN', 'O'],
#  [' ', 'space', 'space'],
#  ['หลังจาก', 'CNJ', 'O'],
#  [' ', 'space', 'space'],
#  ['นางเอก', 'NN', 'O'],
#  ['สาว', 'JJA', 'O'],
#  [' ', 'space', 'space'],
#  ['หยาดทิพย์', 'NR', 'PER_B'],
#  [' ', 'space', 'space'],
#  ['ราชปาล', 'NR', 'PER_I'],
#  [' ', 'space', 'space'],
#  ['เปรย', 'NN', 'O'],
#  [' ', 'space', 'space'],
#  ['ๆ', 'PU', 'O'],
#  [' ', 'space', 'space'],
#  ['ว่า', 'COMP', 'O'],
#  [' ', 'space', 'space'],
#  ['อยาก', 'VV', 'O'],
#  ['จะ', 'AUX', 'O'],
#  ['ให้', 'COMP', 'O'],
#  ['ทาง', 'NN', 'O'],
#  [' ', 'space', 'space'],
#  ['EFM', 'FWN', 'ORG_B'],
#  [' ', 'space', 'space'],
#  ['รับผิดชอบ', 'VV', 'O'],
#  [' ', 'space', 'space'],
#  [' ', 'space', 'space'],
#  ['หลังจาก', 'CNJ', 'O'],
#  ['ปูด', 'VV', 'O'],
#  ['ข่าว', 'NN', 'O'],
#  ['ทำ', 'VV', 'O'],
#  ['ให้', 'COMP', 'O'],
#  ['เสีย', 'VV', 'O'],
#  ['ชื่อ', 'NN', 'O'],
#  ['ไม่', 'NEG', 'O'],
#  ['เช่น', 'NN', 'O'],
#  ['นั้น', 'DDEM', 'O'],
#  ['คง', 'AUX', 'O'],
#  ['ต้อง', 'AUX', 'O'],
#  ['พึ่ง', 'VV', 'O'],
#  ['กระบวน', 'NN', 'O'],
#  ['ทาง', 'NN', 'O'],
#  ['กฎหมาย', 'NN', 'O'],
#  [' ', 'space', 'space'],
#  [' ', 'space', 'space'],
#  ['ล่าสุด', 'ADV', 'O'],
#  [' ', 'space', 'space'],
#  ['ดีเจ', 'NN', 'TTL_B'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  [' ', 'space', 'space'],
#  ['คู่', 'NN', 'O'],
#  ['กรณี', 'NN', 'O'],
#  [' ', 'space', 'space'],
#  ['ออก', 'VV', 'O'],
#  ['มา', 'VV', 'O'],
#  ['ให้', 'VV', 'O'],
#  ['สัมภาษณ์', 'VV', 'O'],
#  ['เป็น', 'VV', 'O'],
#  ['ครั้ง', 'CL', 'O'],
#  ['แรก', 'JJA', 'O'],
#  [' ', 'space', 'space'],
#  ['ถึง', 'VV', 'O'],
#  ['เรื่องราว', 'NN', 'O'],
#  ['ที่', 'COMP', 'O'],
#  ['เกิด', 'VV', 'O'],
#  ['ขึ้น', 'ADV', 'O'],
#  ['ว่า', 'NN', 'O'],
#  [' ', 'space', 'space'],
#  ['ไม่', 'NEG', 'O'],
#  ['มี', 'VV', 'O'],
#  ['เจตนา', 'VV', 'O'],
#  ['จะ', 'AUX', 'O'],
#  ['พาดพิง', 'VV', 'O'],
#  ['ใคร', 'PDEM', 'O'],
#  [' ', 'space', 'space'],
#  [' ', 'space', 'space'],
#  ['ทั้งนี้', 'CNJ', 'O'],
#  [' ', 'space', 'space'],
#  ['ทำ', 'VV', 'O'],
#  ['ทุก', 'PDT', 'O'],
#  ['อย่าง', 'CL', 'O'],
#  ['ไป', 'VV', 'O'],
#  ['ตาม', 'VV', 'O'],
#  ['หน้าที่', 'NN', 'O'],
#  ['จริง', 'JJA', 'O'],
#  [' ', 'space', 'space'],
#  ['ๆ', 'PU', 'O'],
#  [' ', 'space', 'space'],
#  ['"', 'PU', 'O'],
#  ['คือ', 'VV', 'O'],
#  ['ตอน', 'ADV', 'O'],
#  ['นี้', 'DDEM', 'O'],
#  [' ', 'space', 'space'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  [' ', 'space', 'space'],
#  ['งง', 'VV', 'O'],
#  [' ', 'space', 'space'],
#  ['กับ', 'P', 'O'],
#  ['เรื่องราว', 'NN', 'O'],
#  ['ที่', 'COMP', 'O'],
#  ['เกิด', 'VV', 'O'],
#  ['ขึ้น', 'ADV', 'O'],
#  ['เหมือน', 'ADV', 'O'],
#  ['กัน', 'REFX', 'O'],
#  [' ', 'space', 'space'],
#  ['เพราะ', 'CNJ', 'O'],
#  ['ตอน', 'NN', 'O'],
#  ['ที่', 'COMP', 'O'],
#  [' ', 'space', 'space'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  [' ', 'space', 'space'],
#  ['ทำ', 'VV', 'O'],
#  ['รายการ', 'NN', 'O'],
#  [' ', 'space', 'space'],
#  ['ก็', 'AUX', 'O'],
#  ['ทำ', 'JJV', 'O'],
#  ['หน้าที่', 'NN', 'O'],
#  ['ไป', 'VV', 'O'],
#  ['ตาม', 'VV', 'O'],
#  ['ปกติ', 'ADV', 'O'],
#  [' ', 'space', 'space'],
#  ['เพื่อ', 'CNJ', 'O'],
#  ['ความ', 'FXN', 'O'],
#  ['สนุกสนาน', 'VV', 'O'],
#  ['ตลอด', 'ADV', 'O'],
#  [' ', 'space', 'space'],
#  ['ตอน', 'NN', 'O'],
#  ['จัด', 'VV', 'O'],
#  ['รายการ', 'NN', 'O'],
#  ['ไม่', 'NEG', 'O'],
#  ['ได้', 'AUX', 'O'],
#  ['คิด', 'VV', 'O'],
#  ['ถึง', 'VV', 'O'],
#  ['ใคร', 'PINT', 'O'],
#  [' ', 'space', 'space'],
#  ['หรือ', 'CNJ', 'O'],
#  ['พูด', 'VV', 'O'],
#  ['ถึง', 'P', 'O'],
#  ['ใคร', 'PINT', 'O'],
#  [' ', 'space', 'space'],
#  ['แล้ว', 'AUX', 'O'],
#  ['ก็', 'AUX', 'O'],
#  ['ไม่', 'NEG', 'O'],
#  ['ได้', 'AUX', 'O'],
#  ['มี', 'VV', 'O'],
#  ['เจตนา', 'VV', 'O'],
#  ['จะ', 'AUX', 'O'],
#  ['เอ่ย', 'VV', 'O'],
#  ['ถึง', 'P', 'O'],
#  ['ใคร', 'PINT', 'O'],
#  ['ด้วย', 'P', 'O'],
#  [' ', 'space', 'space'],
#  [' ', 'space', 'space'],
#  ['แม้กระทั่ง', 'CNJ', 'O'],
#  ['ตอน', 'NN', 'O'],
#  ['ที่', 'COMP', 'O'],
#  ['เล่า', 'VV', 'O'],
#  [' ', 'space', 'space'],
#  ['ๆ', 'PU', 'O'],
#  [' ', 'space', 'space'],
#  ['ไป', 'VV', 'O'],
#  ['ยัง', 'P', 'O'],
#  ['หัน', 'VV', 'O'],
#  ['หน้า', 'NN', 'O'],
#  ['มอง', 'VV', 'O'],
#  ['กับ', 'P', 'O'],
#  [' ', 'space', 'space'],
#  ['พี่', 'NN', 'TTL_B'],
#  ['ปอ', 'NR', 'PER_B'],
#  ['-', 'PU', 'O'],
#  ['วรฐก์', 'NR', 'PER_B'],
#  [' ', 'space', 'space'],
#  ['ว่า', 'COMP', 'O'],
#  ['มัน', 'PPER', 'O'],
#  ['เป็น', 'VV', 'O'],
#  ['แค่', 'PDT', 'O'],
#  ['เรื่อง', 'NN', 'O'],
#  [' ', 'space', 'space'],
#  ['ๆ', 'PU', 'O'],
#  [' ', 'space', 'space'],
#  ['หนึ่ง', 'NN', 'O'],
#  ['เท่านั้น', 'ADV', 'O'],
#  ['เอง', 'REFX', 'O'],
#  [' ', 'space', 'space'],
#  [' ', 'space', 'space'],
#  ['แล้ว', 'AUX', 'O'],
#  ['เรา', 'PPER', 'O'],
#  ['สอง', 'CD', 'MEA_B'],
#  ['คน', 'CL', 'MEA_I'],
#  ['ก็', 'AUX', 'O'],
#  ['ไม่', 'NEG', 'O'],
#  ['รู้', 'VV', 'O'],
#  ['เรื่อง', 'NN', 'O'],
#  ['นี้', 'DDEM', 'O'],
#  [' ', 'space', 'space'],
#  [' ', 'space', 'space'],
#  ['แล้ว', 'AUX', 'O'],
#  ['ตอน', 'NN', 'O'],
#  ['ที่', 'COMP', 'O'],
#  ['พูด', 'VV', 'O'],
#  ['ออก', 'ADV', 'O'],
#  ['ไป', 'VV', 'O'],
#  ['ก็', 'AUX', 'O'],
#  ['ไม่', 'NEG', 'O'],
#  ['ได้', 'AUX', 'O'],
#  ['มี', 'VV', 'O'],
#  ['โอกาส', 'NN', 'O'],
#  ['จะ', 'AUX', 'O'],
#  ['นึก', 'VV', 'O'],
#  ['ถึง', 'VV', 'O'],
#  ['ใคร', 'PINT', 'O'],
#  ['ด้วย', 'P', 'O'],
#  ['ซ้ำ', 'ADV', 'O'],
#  [' ', 'space', 'space'],
#  ['เพราะ', 'CNJ', 'O'],
#  ['ต้อง', 'AUX', 'O'],
#  ['เตรียม', 'VV', 'O'],
#  ['ข่าว', 'NN', 'O'],
#  ['ต่อไป', 'ADV', 'O'],
#  [' ', 'space', 'space'],
#  ['รายการ', 'NN', 'O'],
#  ['เรา', 'PPER', 'O'],
#  ['เป็น', 'VV', 'O'],
#  ['รายการ', 'NN', 'O'],
#  ['สด', 'JJA', 'O'],
#  [' ', 'space', 'space'],
#  ['2', 'CD', 'MEA_B'],
#  [' ', 'space', 'space'],
#  ['ชั่วโมง', 'CL', 'MEA_B'],
#  [' ', 'space', 'space'],
#  [' ', 'space', 'space'],
#  ['วัน', 'NN', 'O'],
#  ['นี้', 'DDEM', 'O'],
#  [' ', 'space', 'space'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  ['อยาก', 'VV', 'O'],
#  ['ให้', 'COMP', 'O'],
#  ['ดู', 'VV', 'O'],
#  ['ที่', 'P', 'O'],
#  ['เจตนา', 'VV', 'O'],
#  ['มาก', 'ADV', 'O'],
#  ['กว่า', 'ADV', 'O'],
#  [' ', 'space', 'space'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  ['ยืนยัน', 'VV', 'O'],
#  ['ว่า', 'COMP', 'O'],
#  [' ', 'space', 'space'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  ['ไม่', 'NEG', 'O'],
#  ['ได้', 'AUX', 'O'],
#  ['เอ่ย', 'VV', 'O'],
#  ['ถึง', 'P', 'O'],
#  ['ใคร', 'PDEM', 'O'],
#  ['เลย', 'PAR', 'O'],
#  ['แม้', 'CNJ', 'O'],
#  ['ซัก', 'VV', 'O'],
#  ['คน', 'CL', 'O'],
#  ['เดียว', 'CD', 'NUM_B'],
#  ['"', 'PU', 'O'],
#  [' ', 'space', 'space'],
#  ['แล้ว', 'AUX', 'O'],
#  ['ที่', 'COMP', 'O'],
#  ['หยาด', 'NR', 'PER_B'],
#  ['พูด', 'VV', 'O'],
#  ['ถึง', 'VV', 'O'],
#  ['เรื่อง', 'NN', 'O'],
#  ['ฟ้อง', 'VV', 'O'],
#  ['ล่ะ', 'PAR', 'O'],
#  [' ', 'space', 'space'],
#  [' ', 'space', 'space'],
#  ['"', 'PU', 'O'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  ['คิด', 'VV', 'O'],
#  ['ว่า', 'COMP', 'O'],
#  ['ไม่', 'NEG', 'O'],
#  ['น่า', 'AUX', 'O'],
#  ['จะ', 'AUX', 'O'],
#  ['ใหญ่โต', 'VA', 'O'],
#  [' ', 'space', 'space'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  ['ขอ', 'VV', 'O'],
#  ['ยืนยัน', 'VV', 'O'],
#  [' ', 'space', 'space'],
#  ['เรา', 'PPER', 'O'],
#  ['มี', 'VV', 'O'],
#  ['ใจ', 'NN', 'O'],
#  ['บริสุทธิ์', 'JJA', 'O'],
#  ['ไม่', 'NEG', 'O'],
#  ['ได้', 'AUX', 'O'],
#  ['มี', 'VV', 'O'],
#  ['เจตนา', 'VV', 'O'],
#  ['จะ', 'AUX', 'O'],
#  ['พูด', 'VV', 'O'],
#  ['ถึง', 'VV', 'O'],
#  ['ใคร', 'PDEM', 'O'],
#  ['เลย', 'PAR', 'O'],
#  ['ครับ', 'PAR', 'O'],
#  ['"', 'PU', 'O'],
#  [' ', 'space', 'space'],
#  [' ', 'space', 'space'],
#  ['จะ', 'AUX', 'O'],
#  ['มี', 'VV', 'O'],
#  ['การ', 'FXN', 'O'],
#  ['ขอโทษ', 'VV', 'O'],
#  ['กัน', 'REFX', 'O'],
#  ['มั้ย', 'PAR', 'O'],
#  [' ', 'space', 'space'],
#  [' ', 'space', 'space'],
#  ['"', 'PU', 'O'],
#  ['อย่าง', 'FXAV', 'O'],
#  ['ที่', 'COMP', 'O'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  ['บอก', 'VV', 'O'],
#  ['ไป', 'VV', 'O'],
#  ['ว่า', 'COMP', 'O'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  ['ไม่', 'NEG', 'O'],
#  ['ได้', 'AUX', 'O'],
#  ['เอ่ย', 'VV', 'O'],
#  ['เรา', 'PPER', 'O'],
#  ['กุ', 'VV', 'O'],
#  ['ข่าว', 'NN', 'O'],
#  ['ขึ้น', 'ADV', 'O'],
#  ['มา', 'VV', 'O'],
#  ['หรือ', 'CNJ', 'O'],
#  ['เปล่า', 'PINT', 'O'],
#  [' ', 'space', 'space'],
#  ['"', 'PU', 'O'],
#  [' ', 'space', 'space'],
#  ['รายการ', 'NN', 'O'],
#  ['ของ', 'P', 'O'],
#  ['เรา', 'DPER', 'O'],
#  ['เป็น', 'VV', 'O'],
#  ['เรื่องราว', 'NN', 'O'],
#  ['ที่', 'COMP', 'O'],
#  ['ให้', 'COMP', 'O'],
#  ['สีสัน', 'VV', 'O'],
#  ['กับ', 'P', 'O'],
#  ['วงการ', 'NN', 'ORG_B'],
#  ['บันเทิง', 'NN', 'ORG_I'],
#  [' ', 'space', 'space'],
#  ['สนุกสนาน', 'ADV', 'O'],
#  [' ', 'space', 'space'],
#  ['แล้ว', 'AUX', 'O'],
#  ['ใน', 'P', 'O'],
#  ['ส่วน', 'NN', 'O'],
#  ['ของ', 'P', 'O'],
#  ['ข่าว', 'NN', 'O'],
#  ['ก็', 'AUX', 'O'],
#  ['อยู่', 'VV', 'O'],
#  ['ใน', 'P', 'O'],
#  ['กระบวนการ', 'NN', 'O'],
#  [' ', 'space', 'space'],
#  ['การ', 'FXN', 'O'],
#  ['ทำ', 'VV', 'O'],
#  ['ข่าว', 'NN', 'O'],
#  [' ', 'space', 'space'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  ['ไม่', 'NEG', 'O'],
#  ['ขอ', 'VV', 'O'],
#  ['ลง', 'VV', 'O'],
#  ['ลึก', 'ADV', 'O'],
#  ['ดี', 'ADV', 'O'],
#  ['กว่า', 'ADV', 'O'],
#  ['ครับ', 'PAR', 'O'],
#  ['"', 'PU', 'O'],
#  [' ', 'space', 'space'],
#  [' ', 'space', 'space'],
#  ['หยาด', 'NR', 'PER_B'],
#  ['และ', 'CNJ', 'O'],
#  ['คุณ', 'NN', 'O'],
#  ['แม่', 'NN', 'O'],
#  ['ไม่', 'NEG', 'O'],
#  ['พอใจ', 'VV', 'O'],
#  [' ', 'space', 'space'],
#  ['ตรง', 'P', 'O'],
#  ['ที่', 'COMP', 'O'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  ['พูด', 'VV', 'O'],
#  ['ไป', 'VV', 'O'],
#  ['หัวเราะ', 'VV', 'O'],
#  ['ไป', 'VV', 'O'],
#  [' ', 'space', 'space'],
#  ['เหมือน', 'ADV', 'O'],
#  ['ไป', 'VV', 'O'],
#  ['เยาะเย้ย', 'VV', 'O'],
#  ['เค้า', 'NN', 'O'],
#  [' ', 'space', 'space'],
#  [' ', 'space', 'space'],
#  ['"', 'PU', 'O'],
#  ['เกี่ยว', 'P', 'O'],
#  ['กับ', 'P', 'O'],
#  ['เรื่อง', 'NN', 'O'],
#  ['หัวเราะ', 'NN', 'O'],
#  [' ', 'space', 'space'],
#  ['ถ้า', 'CNJ', 'O'],
#  ['ใคร', 'PDEM', 'O'],
#  ['ฟัง', 'VV', 'O'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  ['ตั้งแต่', 'P', 'O'],
#  ['ตอน', 'NN', 'O'],
#  ['จัด', 'VV', 'O'],
#  ['รายการ', 'NN', 'O'],
#  ['ใหม่', 'JJA', 'O'],
#  [' ', 'space', 'space'],
#  ['ๆ', 'PU', 'O'],
#  [' ', 'space', 'space'],
#  ['ก็', 'AUX', 'O'],
#  ['จะ', 'AUX', 'O'],
#  ['รู้', 'VV', 'O'],
#  ['ว่า', 'COMP', 'O'],
#  [' ', 'space', 'space'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  ['จะ', 'AUX', 'O'],
#  ['หัวเราะ', 'VV', 'O'],
#  ['ตลอด', 'ADV', 'O'],
#  ['การ', 'FXN', 'O'],
#  ['จัด', 'VV', 'O'],
#  ['รายการ', 'NN', 'O'],
#  ['อยู่แล้ว', 'ADV', 'O'],
#  [' ', 'space', 'space'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  ['เป็น', 'VV', 'O'],
#  ['คน', 'NN', 'O'],
#  ['อารมณ์', 'NN', 'O'],
#  ['ดี', 'ADV', 'O'],
#  ['ครับ', 'PAR', 'O'],
#  [' ', 'space', 'space'],
#  ['พูด', 'VV', 'O'],
#  ['ไป', 'VV', 'O'],
#  ['ขำ', 'VV', 'O'],
#  ['ไป', 'VV', 'O'],
#  [' ', 'space', 'space'],
#  ['เป็น', 'VV', 'O'],
#  ['สไตล์', 'NN', 'O'],
#  ['การ', 'FXN', 'O'],
#  ['จัด', 'VV', 'O'],
#  ['ของ', 'P', 'O'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  ['อยู่แล้ว', 'ADV', 'O'],
#  [' ', 'space', 'space'],
#  ['ตอน', 'NN', 'O'],
#  ['แรก', 'ADV', 'O'],
#  [' ', 'space', 'space'],
#  ['ๆ', 'PU', 'O'],
#  [' ', 'space', 'space'],
#  ['คน', 'CL', 'O'],
#  ['ก็', 'AUX', 'O'],
#  ['ติง', 'VV', 'O'],
#  ['ว่า', 'COMP', 'O'],
#  [' ', 'space', 'space'],
#  ['หัวเราะ', 'VV', 'O'],
#  ['เยอะ', 'ADV', 'O'],
#  ['ไป', 'VV', 'O'],
#  [' ', 'space', 'space'],
#  ['พอ', 'P', 'O'],
#  ['หลัง', 'CNJ', 'O'],
#  [' ', 'space', 'space'],
#  ['ๆ', 'PU', 'O'],
#  [' ', 'space', 'space'],
#  ['หัวเราะ', 'VV', 'O'],
#  ['น้อย', 'ADV', 'O'],
#  ['ลง', 'VV', 'O'],
#  ['ก็', 'AUX', 'O'],
#  ['บอก', 'VV', 'O'],
#  ['ว่า', 'COMP', 'O'],
#  [' ', 'space', 'space'],
#  ['หัวเราะ', 'VV', 'O'],
#  ['อีก', 'ADV', 'O'],
#  ['ได้', 'AUX', 'O'],
#  ['มั้ย', 'PAR', 'O'],
#  [' ', 'space', 'space'],
#  ['ชอบ', 'VV', 'O'],
#  ['เสียง', 'NN', 'O'],
#  ['หัวเราะ', 'VV', 'O'],
#  [' ', 'space', 'space'],
#  ['มัน', 'PPER', 'O'],
#  ['เป็น', 'VV', 'O'],
#  ['ธรรมชาติ', 'NN', 'O'],
#  ['ของ', 'P', 'O'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  ['ครับ', 'PAR', 'O'],
#  ['"', 'PU', 'O'],
#  [' ', 'space', 'space'],
#  [' ', 'space', 'space'],
#  ['จะ', 'AUX', 'O'],
#  ['ทำ', 'VV', 'O'],
#  ['ให้', 'COMP', 'O'],
#  ['ลด', 'VV', 'O'],
#  ['ความ', 'FXN', 'O'],
#  ['หวือหวา', 'VV', 'O'],
#  ['ใน', 'P', 'O'],
#  ['การ', 'FXN', 'O'],
#  ['จัด', 'VV', 'O'],
#  ['รายการ', 'NN', 'O'],
#  ['มั้ย', 'PAR', 'O'],
#  [' ', 'space', 'space'],
#  [' ', 'space', 'space'],
#  ['"', 'PU', 'O'],
#  ['แต่ละ', 'PDT', 'O'],
#  ['คน', 'CL', 'O'],
#  ['ก็', 'AUX', 'O'],
#  ['มี', 'VV', 'O'],
#  ['สไตล์', 'NN', 'O'],
#  ['การ', 'FXN', 'O'],
#  ['จัด', 'VV', 'O'],
#  ['รายการ', 'NN', 'O'],
#  ['ที่', 'COMP', 'O'],
#  ['แตกต่าง', 'VV', 'O'],
#  ['กัน', 'REFX', 'O'],
#  ['ไป', 'VV', 'O'],
#  [' ', 'space', 'space'],
#  ['ดีเจ', 'NN', 'O'],
#  ['ก็', 'AUX', 'O'],
#  ['มี', 'VV', 'O'],
#  ['หลาย', 'PDT', 'O'],
#  ['คน', 'CL', 'O'],
#  [' ', 'space', 'space'],
#  ['เพราะฉะนั้น', 'CNJ', 'O'],
#  ['การ', 'FXN', 'O'],
#  ['จัด', 'VV', 'O'],
#  ['รายการ', 'NN', 'O'],
#  ['ก็', 'AUX', 'O'],
#  ['คง', 'AUX', 'O'],
#  ['เหมือน', 'ADV', 'O'],
#  ['เดิม', 'ADV', 'O'],
#  [' ', 'space', 'space'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  ['ก็', 'CNJ', 'O'],
#  ['ยัง', 'AUX', 'O'],
#  ['จัด', 'VV', 'O'],
#  ['รายการ', 'NN', 'O'],
#  ['เหมือน', 'VV', 'O'],
#  ['เดิม', 'ADV', 'O'],
#  [' ', 'space', 'space'],
#  ['แล้ว', 'AUX', 'O'],
#  ['ก็', 'AUX', 'O'],
#  ['ออก', 'VV', 'O'],
#  ['ทำ', 'VV', 'O'],
#  ['ข่าว', 'NN', 'O'],
#  ['ตาม', 'VV', 'O'],
#  ['ปกติ', 'ADV', 'O'],
#  ['"', 'PU', 'O'],
#  [' ', 'space', 'space'],
#  [' ', 'space', 'space'],
#  ['พี่', 'NN', 'TTL_B'],
#  ['ฉอด', 'NR', 'PER_B'],
#  ['-', 'PU', 'O'],
#  ['สายทิพย์', 'NR', 'PER_B'],
#  [' ', 'space', 'space'],
#  ['ให้', 'COMP', 'O'],
#  ['คำ', 'NN', 'O'],
#  ['แนะนำ', 'JJV', 'O'],
#  ['อย่าง', 'FXAV', 'O'],
#  ['ไร', 'PDEM', 'O'],
#  ['บ้าง', 'PDEM', 'O'],
#  [' ', 'space', 'space'],
#  [' ', 'space', 'space'],
#  ['"', 'PU', 'O'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  ['ไม่', 'NEG', 'O'],
#  ['อยาก', 'VV', 'O'],
#  ['จะ', 'AUX', 'O'],
#  ['พาดพิง', 'VV', 'O'],
#  ['ถึง', 'VV', 'O'],
#  [' ', 'space', 'space'],
#  ['เพราะ', 'CNJ', 'O'],
#  ['ท่าน', 'PPER', 'O'],
#  ['เอง', 'REFX', 'O'],
#  ['ก็', 'AUX', 'O'],
#  ['ไม่', 'NEG', 'O'],
#  ['ได้', 'AUX', 'O'],
#  ['ลง', 'VV', 'O'],
#  ['มา', 'VV', 'O'],
#  ['ข้อง', 'VV', 'O'],
#  ['เกี่ยว', 'P', 'O'],
#  ['กับ', 'P', 'O'],
#  ['ตรง', 'NN', 'O'],
#  ['นี้', 'DDEM', 'O'],
#  [' ', 'space', 'space'],
#  ['ก็', 'AUX', 'O'],
#  ['ไม่', 'NEG', 'O'],
#  ['มี', 'VV', 'O'],
#  ['ใคร', 'PDEM', 'O'],
#  ['แนะนำ', 'VV', 'O'],
#  ['อะไร', 'PDEM', 'O'],
#  ['มาก', 'JJA', 'O'],
#  [' ', 'space', 'space'],
#  ['เพราะ', 'CNJ', 'O'],
#  ['เป็น', 'VV', 'O'],
#  ['เรื่อง', 'NN', 'O'],
#  ['ที่', 'COMP', 'O'],
#  ['เกิด', 'VV', 'O'],
#  ['ขึ้น', 'ADV', 'O'],
#  ['ภาย', 'NN', 'O'],
#  ['ใน', 'P', 'O'],
#  ['คลื่น', 'NN', 'O'],
#  ['เรา', 'PPER', 'O'],
#  [' ', 'space', 'space'],
#  ['แต่', 'CNJ', 'O'],
#  ['ถ้า', 'CNJ', 'O'],
#  ['เกิด', 'VV', 'O'],
#  ['อะไร', 'PDEM', 'O'],
#  ['ขึ้น', 'ADV', 'O'],
#  ['จริง', 'ADV', 'O'],
#  ['ๆ', 'PU', 'O'],
#  [' ', 'space', 'space'],
#  ['คง', 'AUX', 'O'],
#  ['ต้อง', 'AUX', 'O'],
#  ['ปรึกษา', 'VV', 'O'],
#  ['กับ', 'P', 'O'],
#  ['ผู้', 'FXN', 'O'],
#  ['ใหญ่', 'JJA', 'O'],
#  ['อีก', 'ADV', 'O'],
#  ['ที', 'ADV', 'O'],
#  ['ครับ', 'PAR', 'O'],
#  ['"', 'PU', 'O'],
#  [' ', 'space', 'space'],
#  [' ', 'space', 'space'],
#  ['ถึง', 'VV', 'O'],
#  ['ใคร', 'PINT', 'O'],
#  [' ', 'space', 'space'],
#  ['ก็', 'AUX', 'O'],
#  ['เลย', 'PAR', 'O'],
#  ['ไม่', 'NEG', 'O'],
#  ['รู้', 'VV', 'O'],
#  ['ว่า', 'COMP', 'O'],
#  [' ', 'space', 'space'],
#  ['จะ', 'AUX', 'O'],
#  ['ต้อง', 'AUX', 'O'],
#  ['ไป', 'VV', 'O'],
#  ['ขอโทษ', 'VV', 'O'],
#  ['ใคร', 'PDEM', 'O'],
#  ['เหมือน', 'ADV', 'O'],
#  ['กัน', 'REFX', 'O'],
#  [' ', 'space', 'space'],
#  ['เพราะ', 'CNJ', 'O'],
#  ['ไม่', 'NEG', 'O'],
#  ['ได้', 'AUX', 'O'],
#  ['มี', 'VV', 'O'],
#  ['เจตนา', 'VV', 'O'],
#  ['ตรง', 'P', 'O'],
#  ['นั้น', 'DDEM', 'O'],
#  [' ', 'space', 'space'],
#  [' ', 'space', 'space'],
#  ['การ', 'NN', 'O'],
#  ['ที่', 'COMP', 'O'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  ['พูด', 'VV', 'O'],
#  ['ออก', 'ADV', 'O'],
#  ['ไป', 'VV', 'O'],
#  ['ใคร', 'PINT', 'O'],
#  ['จะ', 'AUX', 'O'],
#  ['ไป', 'VV', 'O'],
#  ['คิด', 'VV', 'O'],
#  ['หรือ', 'CNJ', 'O'],
#  ['ตีความ', 'VV', 'O'],
#  ['ต่อ', 'ADV', 'O'],
#  ['ก็', 'AUX', 'O'],
#  ['เป็น', 'VV', 'O'],
#  ['สิทธิ', 'NN', 'O'],
#  ['ส่วน', 'NN', 'O'],
#  ['บุคคล', 'NN', 'O'],
#  ['อยู่แล้ว', 'ADV', 'O'],
#  ['ไง', 'PINT', 'O'],
#  ['ครับ', 'PAR', 'O'],
#  [' ', 'space', 'space'],
#  [' ', 'space', 'space'],
#  ['อยาก', 'VV', 'O'],
#  ['ให้', 'COMP', 'O'],
#  ['ทุก', 'PDT', 'O'],
#  ['คน', 'CL', 'O'],
#  ['ได้', 'AUX', 'O'],
#  ['ย้อนกลับ', 'VV', 'O'],
#  ['ไป', 'VV', 'O'],
#  ['ฟัง', 'VV', 'O'],
#  ['รายการ', 'NN', 'O'],
#  [' ', 'space', 'space'],
#  ['วัน', 'NN', 'O'],
#  ['นั้น', 'DDEM', 'O'],
#  ['พูด', 'VV', 'O'],
#  ['กว้าง', 'ADV', 'O'],
#  ['มาก', 'ADV', 'O'],
#  [' ', 'space', 'space'],
#  ['ไม่', 'NEG', 'O'],
#  ['ได้', 'AUX', 'O'],
#  ['ชี้', 'VV', 'O'],
#  ['ชัด', 'ADV', 'O'],
#  ['ระบุ', 'VV', 'O'],
#  ['ไป', 'VV', 'O'],
#  ['ที่', 'P', 'O'],
#  ['ใคร', 'PDEM', 'O'],
#  ['พูด', 'VV', 'O'],
#  ['แค่', 'PDT', 'O'],
#  ['ว่า', 'COMP', 'O'],
#  [' ', 'space', 'space'],
#  ['นางเอก', 'NN', 'O'],
#  ['หน้า', 'P', 'O'],
#  ['คม', 'NN', 'O'],
#  ['คน', 'CL', 'O'],
#  ['หนึ่ง', 'NN', 'O'],
#  ['เท่านั้น', 'ADV', 'O'],
#  ['เอง', 'REFX', 'O'],
#  ['ครับ', 'PAR', 'O'],
#  ['"', 'PU', 'O'],
#  ['\n', 'space', 'space']]

# %%
trainer = TrainModel(LSTMTagger, best2010,1)
trainer.train(40)
# Out:
# Training
# Num of training text file: 4975
#  epoch 0: 2m 5s loss:0.5891 accuracy POS:0.9100 accuracy NER:0.90401epoch: 0
# F1 (POS): 0.9403109553613785 F1 (NER) 0.735064446326089
#  epoch 1: 4m 42s loss:0.2758 accuracy POS:0.9608 accuracy NER:0.9593epoch: 1
# F1 (POS): 0.9499288414158262 F1 (NER) 0.779134552883276
#  epoch 2: 7m 31s loss:0.3654 accuracy POS:0.9340 accuracy NER:0.9200epoch: 2
# F1 (POS): 0.95330313556858 F1 (NER) 0.7930277180571931
#  epoch 3: 10m 19s loss:0.2328 accuracy POS:0.9652 accuracy NER:0.9645epoch: 3
# F1 (POS): 0.9549558510719697 F1 (NER) 0.798016376427171
#  epoch 4: 12m 57s loss:0.3077 accuracy POS:0.9490 accuracy NER:0.9313epoch: 4
# F1 (POS): 0.9557439515203452 F1 (NER) 0.8018341859071846
#  epoch 5: 15m 10s loss:0.1999 accuracy POS:0.9689 accuracy NER:0.9689epoch: 5
# F1 (POS): 0.9564478859014186 F1 (NER) 0.8032028715400015
#  epoch 6: 17m 24s loss:0.2680 accuracy POS:0.9559 accuracy NER:0.9449epoch: 6
# F1 (POS): 0.9567845501706276 F1 (NER) 0.8033913840513289
#  epoch 7: 19m 37s loss:0.1609 accuracy POS:0.9741 accuracy NER:0.9771epoch: 7
# F1 (POS): 0.9570600027545259 F1 (NER) 0.8022068586603177
#  epoch 8: 21m 50s loss:0.2416 accuracy POS:0.9599 accuracy NER:0.9586epoch: 8
# F1 (POS): 0.9568075045526191 F1 (NER) 0.8020353434642096
#  epoch 9: 24m 3s loss:0.1488 accuracy POS:0.9756 accuracy NER:0.98004epoch: 9
# F1 (POS): 0.9566850811819977 F1 (NER) 0.8010179517160739
#  epoch 10: 26m 16s loss:0.2291 accuracy POS:0.9640 accuracy NER:0.9618epoch: 10
# F1 (POS): 0.9564172800587631 F1 (NER) 0.8002662504590524
#  epoch 11: 28m 29s loss:0.1369 accuracy POS:0.9756 accuracy NER:0.9844epoch: 11
# F1 (POS): 0.9564019771374356 F1 (NER) 0.7993955075218099
#  epoch 12: 30m 42s loss:0.2129 accuracy POS:0.9659 accuracy NER:0.9672epoch: 12
# F1 (POS): 0.9560270555649073 F1 (NER) 0.7975797579757975
#  epoch 13: 32m 55s loss:0.1243 accuracy POS:0.9771 accuracy NER:0.9867epoch: 13
# F1 (POS): 0.9561494789355288 F1 (NER) 0.7975935463287909
#  epoch 14: 35m 8s loss:0.1978 accuracy POS:0.9654 accuracy NER:0.97310epoch: 14
# F1 (POS): 0.9555985737677323 F1 (NER) 0.7960367106524816
#  epoch 15: 37m 21s loss:0.1185 accuracy POS:0.9778 accuracy NER:0.9881epoch: 15
# F1 (POS): 0.9556444825317153 F1 (NER) 0.7963755577816228
#  epoch 16: 39m 35s loss:0.1886 accuracy POS:0.9718 accuracy NER:0.9740epoch: 16
# F1 (POS): 0.9553613784871532 F1 (NER) 0.7953019370404933
#  epoch 17: 41m 48s loss:0.1164 accuracy POS:0.9771 accuracy NER:0.9896epoch: 17
# F1 (POS): 0.9545656265781137 F1 (NER) 0.7943088322196464
#  epoch 18: 44m 1s loss:0.1830 accuracy POS:0.9704 accuracy NER:0.97408epoch: 18
# F1 (POS): 0.9548946393866589 F1 (NER) 0.7931198801878873
#  epoch 19: 46m 14s loss:0.1185 accuracy POS:0.9771 accuracy NER:0.9896epoch: 19
# F1 (POS): 0.9546344897240884 F1 (NER) 0.7907857224312921
#  epoch 20: 48m 27s loss:0.1787 accuracy POS:0.9709 accuracy NER:0.9750epoch: 20
# F1 (POS): 0.9543590371401901 F1 (NER) 0.7881923865967632
#  epoch 21: 50m 40s loss:0.1135 accuracy POS:0.9800 accuracy NER:0.9896epoch: 21
# F1 (POS): 0.9541983564662494 F1 (NER) 0.7889979104206414
#  epoch 22: 52m 53s loss:0.1795 accuracy POS:0.9704 accuracy NER:0.9763epoch: 22
# F1 (POS): 0.9538004805117297 F1 (NER) 0.789459299412381
#  epoch 23: 55m 6s loss:0.1072 accuracy POS:0.9815 accuracy NER:0.99185epoch: 23
# F1 (POS): 0.9536780571411082 F1 (NER) 0.791045452485612
#  epoch 24: 57m 19s loss:0.1660 accuracy POS:0.9718 accuracy NER:0.9813epoch: 24
# F1 (POS): 0.9535632852311506 F1 (NER) 0.7861752408652973
#  epoch 25: 59m 32s loss:0.1172 accuracy POS:0.9778 accuracy NER:0.9918epoch: 25
# F1 (POS): 0.9538004805117297 F1 (NER) 0.78864137978111
#  epoch 26: 61m 45s loss:0.1717 accuracy POS:0.9722 accuracy NER:0.9795epoch: 26
# F1 (POS): 0.9532648782652609 F1 (NER) 0.7865020051039008
#  epoch 27: 63m 58s loss:0.1062 accuracy POS:0.9785 accuracy NER:0.9926epoch: 27
# F1 (POS): 0.9529741227600349 F1 (NER) 0.7855721506827383
#  epoch 28: 66m 12s loss:0.1575 accuracy POS:0.9731 accuracy NER:0.9822epoch: 28
# F1 (POS): 0.9525303380415321 F1 (NER) 0.7862338607019458
#  epoch 29: 68m 25s loss:0.0969 accuracy POS:0.9807 accuracy NER:0.9955epoch: 29
# F1 (POS): 0.9529970771420264 F1 (NER) 0.7881390779915018
#  epoch 30: 70m 38s loss:0.1575 accuracy POS:0.9763 accuracy NER:0.9781epoch: 30
# F1 (POS): 0.9529741227600349 F1 (NER) 0.7844257984864766
#  epoch 31: 72m 51s loss:0.0975 accuracy POS:0.9800 accuracy NER:0.9918epoch: 31
# F1 (POS): 0.9524920807382129 F1 (NER) 0.7855873912449324
#  epoch 32: 75m 4s loss:0.1624 accuracy POS:0.9759 accuracy NER:0.97778epoch: 32
# F1 (POS): 0.9522242796149784 F1 (NER) 0.7833321904500674
#  epoch 33: 77m 17s loss:0.0936 accuracy POS:0.9800 accuracy NER:0.9948epoch: 33
# F1 (POS): 0.9523084456822808 F1 (NER) 0.7853970712154683
#  epoch 34: 79m 31s loss:0.1582 accuracy POS:0.9736 accuracy NER:0.9786epoch: 34
# F1 (POS): 0.9525073836595406 F1 (NER) 0.7864902950134097
#  epoch 35: 81m 44s loss:0.0975 accuracy POS:0.9793 accuracy NER:0.9940epoch: 35
# F1 (POS): 0.9528057906254304 F1 (NER) 0.784601781949262
#  epoch 36: 83m 58s loss:0.1604 accuracy POS:0.9695 accuracy NER:0.9763epoch: 36
# F1 (POS): 0.9523084456822808 F1 (NER) 0.7860021402062795
#  epoch 37: 86m 11s loss:0.0869 accuracy POS:0.9807 accuracy NER:0.9963epoch: 37
# F1 (POS): 0.9525609438841874 F1 (NER) 0.7830840309226476
#  epoch 38: 88m 24s loss:0.1540 accuracy POS:0.9736 accuracy NER:0.9800epoch: 38
# F1 (POS): 0.9521248106263486 F1 (NER) 0.7852769115203386
#  epoch 39: 90m 37s loss:0.0949 accuracy POS:0.9815 accuracy NER:0.9918epoch: 39
# F1 (POS): 0.9524538234348937 F1 (NER) 0.7862002831179505

# %%
trainer = TrainModel(LSTMTagger, best2010,2)
trainer.train(40)
# Out:
# Training
# Num of training text file: 4975
#  epoch 0: 2m 10s loss:0.5589 accuracy POS:0.9113 accuracy NER:0.9040epoch: 0
# F1 (POS): 0.941007238281788 F1 (NER) 0.7407111466240511
#  epoch 1: 4m 29s loss:0.2776 accuracy POS:0.9475 accuracy NER:0.9608epoch: 1
# F1 (POS): 0.9504338378196397 F1 (NER) 0.7784988253901798
#  epoch 2: 6m 48s loss:0.3264 accuracy POS:0.9490 accuracy NER:0.9163epoch: 2
# F1 (POS): 0.9538616921970404 F1 (NER) 0.7920833333333333
#  epoch 3: 9m 6s loss:0.2227 accuracy POS:0.9593 accuracy NER:0.96458epoch: 3
# F1 (POS): 0.9554531960151192 F1 (NER) 0.7972053771126842
#  epoch 4: 11m 25s loss:0.2658 accuracy POS:0.9581 accuracy NER:0.9404epoch: 4
# F1 (POS): 0.9567692472492999 F1 (NER) 0.8014722797331494
#  epoch 5: 13m 43s loss:0.2034 accuracy POS:0.9623 accuracy NER:0.9689epoch: 5
# F1 (POS): 0.9574043184843987 F1 (NER) 0.8040397533817981
#  epoch 6: 16m 1s loss:0.2367 accuracy POS:0.9622 accuracy NER:0.95499epoch: 6
# F1 (POS): 0.9572589407317857 F1 (NER) 0.8043658088235294
#  epoch 7: 18m 20s loss:0.1884 accuracy POS:0.9652 accuracy NER:0.9726epoch: 7
# F1 (POS): 0.957343106799088 F1 (NER) 0.8051810853638931
#  epoch 8: 20m 39s loss:0.2226 accuracy POS:0.9645 accuracy NER:0.9618epoch: 8
# F1 (POS): 0.9571059115185089 F1 (NER) 0.8053006202366512
#  epoch 9: 22m 57s loss:0.1659 accuracy POS:0.9682 accuracy NER:0.9756epoch: 9
# F1 (POS): 0.9569299279232405 F1 (NER) 0.8043552851293546
#  epoch 10: 25m 15s loss:0.2173 accuracy POS:0.9654 accuracy NER:0.9613epoch: 10
# F1 (POS): 0.9571977290464749 F1 (NER) 0.8037592098359908
#  epoch 11: 27m 34s loss:0.1590 accuracy POS:0.9756 accuracy NER:0.9778epoch: 11
# F1 (POS): 0.9570217454512067 F1 (NER) 0.802506836827712
#  epoch 12: 29m 52s loss:0.2150 accuracy POS:0.9663 accuracy NER:0.9645epoch: 12
# F1 (POS): 0.9567768987099637 F1 (NER) 0.8029518619436875
#  epoch 13: 32m 11s loss:0.1401 accuracy POS:0.9741 accuracy NER:0.9785epoch: 13
# F1 (POS): 0.9560270555649073 F1 (NER) 0.8003906338715905
#  epoch 14: 34m 29s loss:0.2036 accuracy POS:0.9695 accuracy NER:0.9681epoch: 14
# F1 (POS): 0.9560270555649073 F1 (NER) 0.7995816565491212
#  epoch 15: 36m 47s loss:0.1236 accuracy POS:0.9771 accuracy NER:0.9822epoch: 15
# F1 (POS): 0.9560041011829158 F1 (NER) 0.7994016047871616
#  epoch 16: 39m 6s loss:0.1998 accuracy POS:0.9686 accuracy NER:0.97134epoch: 16
# F1 (POS): 0.9554608474757831 F1 (NER) 0.7980797670238664
#  epoch 17: 41m 24s loss:0.1171 accuracy POS:0.9771 accuracy NER:0.9859epoch: 17
# F1 (POS): 0.954986456914625 F1 (NER) 0.7968593079521592
#  epoch 18: 43m 43s loss:0.2000 accuracy POS:0.9695 accuracy NER:0.9722epoch: 18
# F1 (POS): 0.9548946393866589 F1 (NER) 0.7948811533372874
#  epoch 19: 46m 1s loss:0.0995 accuracy POS:0.9793 accuracy NER:0.99036epoch: 19
# F1 (POS): 0.9546727470274076 F1 (NER) 0.7942919668095194
#  epoch 20: 48m 20s loss:0.1935 accuracy POS:0.9709 accuracy NER:0.9731epoch: 20
# F1 (POS): 0.9540759330956281 F1 (NER) 0.7945067751296757
#  epoch 21: 50m 38s loss:0.0968 accuracy POS:0.9822 accuracy NER:0.9896epoch: 21
# F1 (POS): 0.953976464106998 F1 (NER) 0.7931859072171992
#  epoch 22: 52m 57s loss:0.1975 accuracy POS:0.9695 accuracy NER:0.9704epoch: 22
# F1 (POS): 0.9540682816349642 F1 (NER) 0.7924949336247922
#  epoch 23: 55m 15s loss:0.1042 accuracy POS:0.9756 accuracy NER:0.9896epoch: 23
# F1 (POS): 0.9539688126463342 F1 (NER) 0.7938722472985912
#  epoch 24: 57m 34s loss:0.1943 accuracy POS:0.9704 accuracy NER:0.9718epoch: 24
# F1 (POS): 0.9533796501752184 F1 (NER) 0.7921649014918574
#  epoch 25: 59m 52s loss:0.0965 accuracy POS:0.9793 accuracy NER:0.9911epoch: 25
# F1 (POS): 0.9534179074785376 F1 (NER) 0.7922364558920568
#  epoch 26: 62m 10s loss:0.2022 accuracy POS:0.9704 accuracy NER:0.9722epoch: 26
# F1 (POS): 0.9535020735458399 F1 (NER) 0.7906031688050774
#  epoch 27: 64m 29s loss:0.0877 accuracy POS:0.9815 accuracy NER:0.9933epoch: 27
# F1 (POS): 0.9537086629837636 F1 (NER) 0.7920792079207921
#  epoch 28: 66m 48s loss:0.1844 accuracy POS:0.9745 accuracy NER:0.9740epoch: 28
# F1 (POS): 0.9533107870292439 F1 (NER) 0.7890133357566396
#  epoch 29: 69m 6s loss:0.0988 accuracy POS:0.9785 accuracy NER:0.99114epoch: 29
# F1 (POS): 0.9532266209619417 F1 (NER) 0.7920068953003084
#  epoch 30: 71m 25s loss:0.1904 accuracy POS:0.9736 accuracy NER:0.9695epoch: 30
# F1 (POS): 0.9533873016358821 F1 (NER) 0.7897641746111389
#  epoch 31: 73m 43s loss:0.0802 accuracy POS:0.9815 accuracy NER:0.9948epoch: 31
# F1 (POS): 0.9531348034339755 F1 (NER) 0.7893722654213234
#  epoch 32: 76m 2s loss:0.1875 accuracy POS:0.9722 accuracy NER:0.97369epoch: 32
# F1 (POS): 0.952874653771405 F1 (NER) 0.7879697197026528
#  epoch 33: 78m 20s loss:0.0801 accuracy POS:0.9807 accuracy NER:0.9948epoch: 33
# F1 (POS): 0.9528134420860942 F1 (NER) 0.7910682175130312
#  epoch 34: 80m 39s loss:0.1814 accuracy POS:0.9704 accuracy NER:0.9763epoch: 34
# F1 (POS): 0.9524232175922384 F1 (NER) 0.7902962761620006
#  epoch 35: 82m 57s loss:0.0773 accuracy POS:0.9822 accuracy NER:0.9940epoch: 35
# F1 (POS): 0.9528823052320688 F1 (NER) 0.7868949232585596
#  epoch 36: 85m 16s loss:0.1901 accuracy POS:0.9736 accuracy NER:0.9763epoch: 36
# F1 (POS): 0.9525992011875067 F1 (NER) 0.7883619514854184
#  epoch 37: 87m 35s loss:0.0853 accuracy POS:0.9822 accuracy NER:0.9926epoch: 37
# F1 (POS): 0.9523160971429446 F1 (NER) 0.7866858041145512
#  epoch 38: 89m 54s loss:0.1858 accuracy POS:0.9736 accuracy NER:0.9759epoch: 38
# F1 (POS): 0.9524920807382129 F1 (NER) 0.7882802895779265
#  epoch 39: 92m 12s loss:0.0833 accuracy POS:0.9807 accuracy NER:0.9940epoch: 39
# F1 (POS): 0.9521554164690039 F1 (NER) 0.7871208331438446

# %%
trainer = TrainModel(LSTMTagger, best2010,3)
trainer.train(40)
# Out:
# Training
# Num of training text file: 4975
#  epoch 0: 2m 11s loss:0.5221 accuracy POS:0.9127 accuracy NER:0.9118epoch: 0
# F1 (POS): 0.9409842838997965 F1 (NER) 0.7373274068469832
#  epoch 1: 4m 30s loss:0.2394 accuracy POS:0.9519 accuracy NER:0.9586epoch: 1
# F1 (POS): 0.9514055733239476 F1 (NER) 0.7740324011391755
#  epoch 2: 6m 50s loss:0.3532 accuracy POS:0.9327 accuracy NER:0.9290epoch: 2
# F1 (POS): 0.9539688126463342 F1 (NER) 0.7874195123085148
#  epoch 3: 9m 8s loss:0.2027 accuracy POS:0.9601 accuracy NER:0.96604epoch: 3
# F1 (POS): 0.9559658438795966 F1 (NER) 0.7953045773425019
#  epoch 4: 11m 27s loss:0.2778 accuracy POS:0.9545 accuracy NER:0.9427epoch: 4
# F1 (POS): 0.9567386414066446 F1 (NER) 0.7982904008316969
#  epoch 5: 13m 46s loss:0.1779 accuracy POS:0.9630 accuracy NER:0.9704epoch: 5
# F1 (POS): 0.9575649991583394 F1 (NER) 0.8020869404621742
#  epoch 6: 16m 5s loss:0.2498 accuracy POS:0.9581 accuracy NER:0.95227epoch: 6
# F1 (POS): 0.9572589407317857 F1 (NER) 0.8018622231441148
#  epoch 7: 18m 24s loss:0.1646 accuracy POS:0.9697 accuracy NER:0.9689epoch: 7
# F1 (POS): 0.9577562856749353 F1 (NER) 0.8022245714023073
#  epoch 8: 20m 43s loss:0.2353 accuracy POS:0.9618 accuracy NER:0.9563epoch: 8
# F1 (POS): 0.9575956050009947 F1 (NER) 0.8038591103879734
#  epoch 9: 23m 2s loss:0.1549 accuracy POS:0.9704 accuracy NER:0.97269epoch: 9
# F1 (POS): 0.9574425757877179 F1 (NER) 0.8042831647828673
#  epoch 10: 25m 22s loss:0.2257 accuracy POS:0.9622 accuracy NER:0.9604epoch: 10
# F1 (POS): 0.9572665921924496 F1 (NER) 0.8040187235985843
#  epoch 11: 27m 41s loss:0.1424 accuracy POS:0.9711 accuracy NER:0.9741epoch: 11
# F1 (POS): 0.957006442529879 F1 (NER) 0.8021368399424698
#  epoch 12: 30m 0s loss:0.2071 accuracy POS:0.9627 accuracy NER:0.96681epoch: 12
# F1 (POS): 0.9570753056758535 F1 (NER) 0.8011877569666516
#  epoch 13: 32m 18s loss:0.1227 accuracy POS:0.9748 accuracy NER:0.9800epoch: 13
# F1 (POS): 0.956524400508057 F1 (NER) 0.8004846157362959
#  epoch 14: 34m 34s loss:0.2021 accuracy POS:0.9636 accuracy NER:0.9663epoch: 14
# F1 (POS): 0.9562642508454864 F1 (NER) 0.7999179337543028
#  epoch 15: 36m 51s loss:0.1132 accuracy POS:0.9771 accuracy NER:0.9859epoch: 15
# F1 (POS): 0.9559428894976051 F1 (NER) 0.7984341734770963
#  epoch 16: 39m 8s loss:0.1876 accuracy POS:0.9659 accuracy NER:0.97002epoch: 16
# F1 (POS): 0.9555603164644131 F1 (NER) 0.79795665918358
#  epoch 17: 41m 24s loss:0.1220 accuracy POS:0.9741 accuracy NER:0.9874epoch: 17
# F1 (POS): 0.9550094112966165 F1 (NER) 0.7980778032036613
#  epoch 18: 43m 40s loss:0.1851 accuracy POS:0.9677 accuracy NER:0.9700epoch: 18
# F1 (POS): 0.9550859259032549 F1 (NER) 0.798034734917733
#  epoch 19: 45m 57s loss:0.1069 accuracy POS:0.9778 accuracy NER:0.9918epoch: 19
# F1 (POS): 0.9547263072520544 F1 (NER) 0.7972809045341146
#  epoch 20: 48m 14s loss:0.1792 accuracy POS:0.9709 accuracy NER:0.9740epoch: 20
# F1 (POS): 0.9550476685999357 F1 (NER) 0.7976263836585645
#  epoch 21: 50m 30s loss:0.0963 accuracy POS:0.9771 accuracy NER:0.9911epoch: 21
# F1 (POS): 0.9547110043307268 F1 (NER) 0.7962726109994519
#  epoch 22: 52m 47s loss:0.1800 accuracy POS:0.9690 accuracy NER:0.9736epoch: 22
# F1 (POS): 0.9549481996113058 F1 (NER) 0.7952802629176556
#  epoch 23: 55m 3s loss:0.0947 accuracy POS:0.9807 accuracy NER:0.99111epoch: 23
# F1 (POS): 0.9547110043307268 F1 (NER) 0.7962556074338552
#  epoch 24: 57m 20s loss:0.1692 accuracy POS:0.9686 accuracy NER:0.9786epoch: 24
# F1 (POS): 0.954022372870981 F1 (NER) 0.7953837699212309
#  epoch 25: 59m 36s loss:0.0909 accuracy POS:0.9822 accuracy NER:0.9903epoch: 25
# F1 (POS): 0.9542366137695686 F1 (NER) 0.7945280940139551
#  epoch 26: 61m 52s loss:0.1661 accuracy POS:0.9713 accuracy NER:0.9772epoch: 26
# F1 (POS): 0.9542672196122239 F1 (NER) 0.7936544272502518
#  epoch 27: 64m 8s loss:0.0880 accuracy POS:0.9807 accuracy NER:0.99330epoch: 27
# F1 (POS): 0.9540147214103172 F1 (NER) 0.7920009141812364
#  epoch 28: 66m 25s loss:0.1611 accuracy POS:0.9718 accuracy NER:0.9804epoch: 28
# F1 (POS): 0.9539954167575281 F1 (NER) 0.791743035190616
#  epoch 29: 68m 41s loss:0.0860 accuracy POS:0.9815 accuracy NER:0.9933epoch: 29
# F1 (POS): 0.9542938248650468 F1 (NER) 0.7925630204174746
#  epoch 30: 70m 58s loss:0.1613 accuracy POS:0.9713 accuracy NER:0.9809epoch: 30
# F1 (POS): 0.9537582205695004 F1 (NER) 0.7914345324070889
#  epoch 31: 73m 15s loss:0.0954 accuracy POS:0.9785 accuracy NER:0.9940epoch: 31
# F1 (POS): 0.953739268826419 F1 (NER) 0.7890260631001372
#  epoch 32: 75m 31s loss:0.1616 accuracy POS:0.9700 accuracy NER:0.9790epoch: 32
# F1 (POS): 0.9533873016358821 F1 (NER) 0.7895963797595649
#  epoch 33: 77m 48s loss:0.0892 accuracy POS:0.9837 accuracy NER:0.9926epoch: 33
# F1 (POS): 0.9539994184889894 F1 (NER) 0.7883328384459012
#  epoch 34: 80m 4s loss:0.1672 accuracy POS:0.9686 accuracy NER:0.98361epoch: 34
# F1 (POS): 0.9533603430928087 F1 (NER) 0.7890405962936792
#  epoch 35: 82m 21s loss:0.0844 accuracy POS:0.9822 accuracy NER:0.9918epoch: 35
# F1 (POS): 0.9531231469047811 F1 (NER) 0.7907539247900695
#  epoch 36: 84m 37s loss:0.1628 accuracy POS:0.9700 accuracy NER:0.9822epoch: 36
# F1 (POS): 0.9532495753439332 F1 (NER) 0.7904648717831513
#  epoch 37: 86m 54s loss:0.0959 accuracy POS:0.9778 accuracy NER:0.9911epoch: 37
# F1 (POS): 0.9529052596140604 F1 (NER) 0.7909386289791187
#  epoch 38: 89m 10s loss:0.1517 accuracy POS:0.9750 accuracy NER:0.9831epoch: 38
# F1 (POS): 0.9532342724226056 F1 (NER) 0.7895385458030946
#  epoch 39: 91m 27s loss:0.0876 accuracy POS:0.9830 accuracy NER:0.9933epoch: 39
# F1 (POS): 0.953065940288001 F1 (NER) 0.7893645622109318

# %%
trainer = TrainModel(LSTMTagger, best2010,4)
trainer.train(40)
# Out:
# Training
# Num of training text file: 4975
#  epoch 0: 2m 8s loss:0.5984 accuracy POS:0.9118 accuracy NER:0.90908epoch: 0
# F1 (POS): 0.9419789737860957 F1 (NER) 0.7375423147030278
#  epoch 1: 4m 24s loss:0.2792 accuracy POS:0.9527 accuracy NER:0.9608epoch: 1
# F1 (POS): 0.9512754984926622 F1 (NER) 0.7756712227043836
#  epoch 2: 6m 40s loss:0.3313 accuracy POS:0.9427 accuracy NER:0.9300epoch: 2
# F1 (POS): 0.9545579751174499 F1 (NER) 0.7899434897935649
#  epoch 3: 8m 56s loss:0.2373 accuracy POS:0.9601 accuracy NER:0.9615epoch: 3
# F1 (POS): 0.9557209971383537 F1 (NER) 0.7964879127969949
#  epoch 4: 11m 12s loss:0.2668 accuracy POS:0.9568 accuracy NER:0.9386epoch: 4
# F1 (POS): 0.9565397034293847 F1 (NER) 0.7999354853574803
#  epoch 5: 13m 28s loss:0.2093 accuracy POS:0.9645 accuracy NER:0.9630epoch: 5
# F1 (POS): 0.9570829571365174 F1 (NER) 0.8018053284822807
#  epoch 6: 15m 44s loss:0.2365 accuracy POS:0.9627 accuracy NER:0.9490epoch: 6
# F1 (POS): 0.9578021944389183 F1 (NER) 0.8017306851395826
#  epoch 7: 18m 0s loss:0.1765 accuracy POS:0.9734 accuracy NER:0.96827epoch: 7
# F1 (POS): 0.9578940119668845 F1 (NER) 0.8018919911829538
#  epoch 8: 20m 16s loss:0.2243 accuracy POS:0.9636 accuracy NER:0.9554epoch: 8
# F1 (POS): 0.9575420447763479 F1 (NER) 0.8020406762599802
#  epoch 9: 22m 32s loss:0.1503 accuracy POS:0.9748 accuracy NER:0.9748epoch: 9
# F1 (POS): 0.9575267418550201 F1 (NER) 0.8034808825544746
#  epoch 10: 24m 48s loss:0.2135 accuracy POS:0.9659 accuracy NER:0.9604epoch: 10
# F1 (POS): 0.9572053805071388 F1 (NER) 0.802080494230944
#  epoch 11: 27m 4s loss:0.1372 accuracy POS:0.9741 accuracy NER:0.98000epoch: 11
# F1 (POS): 0.9565626578113762 F1 (NER) 0.799945501612244
#  epoch 12: 29m 20s loss:0.2065 accuracy POS:0.9686 accuracy NER:0.9618epoch: 12
# F1 (POS): 0.9562106906208395 F1 (NER) 0.7993662290629245
#  epoch 13: 31m 36s loss:0.1285 accuracy POS:0.9763 accuracy NER:0.9837epoch: 13
# F1 (POS): 0.9560500099468988 F1 (NER) 0.7997363756192899
#  epoch 14: 33m 53s loss:0.1990 accuracy POS:0.9690 accuracy NER:0.9650epoch: 14
# F1 (POS): 0.9556750883743707 F1 (NER) 0.7985424258198854
#  epoch 15: 36m 9s loss:0.1197 accuracy POS:0.9763 accuracy NER:0.98675epoch: 15
# F1 (POS): 0.9556903912956983 F1 (NER) 0.7986172704737212
#  epoch 16: 38m 25s loss:0.1932 accuracy POS:0.9704 accuracy NER:0.9659epoch: 16
# F1 (POS): 0.95551440770043 F1 (NER) 0.7993009691110051
#  epoch 17: 40m 41s loss:0.1218 accuracy POS:0.9756 accuracy NER:0.9837epoch: 17
# F1 (POS): 0.9552466065771956 F1 (NER) 0.7964834965130279
#  epoch 18: 42m 57s loss:0.1835 accuracy POS:0.9731 accuracy NER:0.9686epoch: 18
# F1 (POS): 0.9550476685999357 F1 (NER) 0.7965863817457441
#  epoch 19: 45m 13s loss:0.1045 accuracy POS:0.9771 accuracy NER:0.9903epoch: 19
# F1 (POS): 0.954886987925995 F1 (NER) 0.7968771215207059
#  epoch 20: 47m 30s loss:0.1803 accuracy POS:0.9718 accuracy NER:0.9690epoch: 20
# F1 (POS): 0.9546803984880714 F1 (NER) 0.7969597277368121
#  epoch 21: 49m 46s loss:0.1051 accuracy POS:0.9771 accuracy NER:0.9903epoch: 21
# F1 (POS): 0.9546115353420968 F1 (NER) 0.7935004305851425
#  epoch 22: 52m 2s loss:0.1791 accuracy POS:0.9718 accuracy NER:0.97134epoch: 22
# F1 (POS): 0.9549022908473227 F1 (NER) 0.7955273743778549
#  epoch 23: 54m 17s loss:0.0976 accuracy POS:0.9763 accuracy NER:0.9933epoch: 23
# F1 (POS): 0.9539611611856703 F1 (NER) 0.7941336230309615
#  epoch 24: 56m 33s loss:0.1738 accuracy POS:0.9713 accuracy NER:0.9763epoch: 24
# F1 (POS): 0.9542442652302324 F1 (NER) 0.7936515154960322
#  epoch 25: 58m 49s loss:0.0977 accuracy POS:0.9756 accuracy NER:0.9903epoch: 25
# F1 (POS): 0.9542748710728878 F1 (NER) 0.7933194154488518
#  epoch 26: 61m 5s loss:0.1734 accuracy POS:0.9709 accuracy NER:0.97819epoch: 26
# F1 (POS): 0.9537928290510659 F1 (NER) 0.7908156271418779
#  epoch 27: 63m 22s loss:0.0887 accuracy POS:0.9807 accuracy NER:0.9926epoch: 27
# F1 (POS): 0.9536091939951337 F1 (NER) 0.7906607369758578
#  epoch 28: 65m 38s loss:0.1676 accuracy POS:0.9745 accuracy NER:0.9768epoch: 28
# F1 (POS): 0.9538540407363766 F1 (NER) 0.7899216887980933
#  epoch 29: 67m 54s loss:0.0878 accuracy POS:0.9807 accuracy NER:0.9918epoch: 29
# F1 (POS): 0.9536015425344698 F1 (NER) 0.7920278078728783
#  epoch 30: 70m 10s loss:0.1677 accuracy POS:0.9731 accuracy NER:0.9790epoch: 30
# F1 (POS): 0.9535326793884953 F1 (NER) 0.7897363764236127
#  epoch 31: 72m 26s loss:0.0885 accuracy POS:0.9815 accuracy NER:0.9911epoch: 31
# F1 (POS): 0.9535097250065038 F1 (NER) 0.7915306492564382
#  epoch 32: 74m 42s loss:0.1574 accuracy POS:0.9781 accuracy NER:0.9813epoch: 32
# F1 (POS): 0.9536091939951337 F1 (NER) 0.7912112829350142
#  epoch 33: 76m 58s loss:0.0799 accuracy POS:0.9830 accuracy NER:0.9963epoch: 33
# F1 (POS): 0.9535785881524783 F1 (NER) 0.7925539160045403
#  epoch 34: 79m 14s loss:0.1584 accuracy POS:0.9777 accuracy NER:0.9809epoch: 34
# F1 (POS): 0.9533566957932269 F1 (NER) 0.7888692178491988
#  epoch 35: 81m 30s loss:0.0864 accuracy POS:0.9807 accuracy NER:0.9955epoch: 35
# F1 (POS): 0.9531960151192863 F1 (NER) 0.787073281747838
#  epoch 36: 83m 46s loss:0.1614 accuracy POS:0.9754 accuracy NER:0.9818epoch: 36
# F1 (POS): 0.9535020735458399 F1 (NER) 0.7878127412250828
#  epoch 37: 86m 2s loss:0.0829 accuracy POS:0.9815 accuracy NER:0.99553epoch: 37
# F1 (POS): 0.9527522304007835 F1 (NER) 0.787688670667394
#  epoch 38: 88m 17s loss:0.1516 accuracy POS:0.9772 accuracy NER:0.9804epoch: 38
# F1 (POS): 0.9527139730974643 F1 (NER) 0.7882344943234608
#  epoch 39: 90m 33s loss:0.0810 accuracy POS:0.9844 accuracy NER:0.9940epoch: 39
# F1 (POS): 0.9533719987145546 F1 (NER) 0.7891348363173101

# %%
trainer = TrainModel(LSTMTagger, best2010,5)
trainer.train(40)
# Out:
# Training
# Num of training text file: 4975
#  epoch 0: 2m 8s loss:0.5204 accuracy POS:0.9181 accuracy NER:0.90546epoch: 0
# F1 (POS): 0.9414204171576354 F1 (NER) 0.7425698165765681
#  epoch 1: 4m 25s loss:0.2692 accuracy POS:0.9549 accuracy NER:0.9556epoch: 1
# F1 (POS): 0.951237241189343 F1 (NER) 0.7789938422214476
#  epoch 2: 6m 42s loss:0.3285 accuracy POS:0.9536 accuracy NER:0.9163epoch: 2
# F1 (POS): 0.9540912360169557 F1 (NER) 0.7915133846972537
#  epoch 3: 8m 59s loss:0.2230 accuracy POS:0.9608 accuracy NER:0.9652epoch: 3
# F1 (POS): 0.9559505409582689 F1 (NER) 0.7971185149269239
#  epoch 4: 11m 15s loss:0.2799 accuracy POS:0.9627 accuracy NER:0.9254epoch: 4
# F1 (POS): 0.9566621268000062 F1 (NER) 0.7999353736786226
#  epoch 5: 13m 32s loss:0.2087 accuracy POS:0.9623 accuracy NER:0.9667epoch: 5
# F1 (POS): 0.9566774297213338 F1 (NER) 0.8031535996680421
#  epoch 6: 15m 48s loss:0.2584 accuracy POS:0.9668 accuracy NER:0.9304epoch: 6
# F1 (POS): 0.9566621268000062 F1 (NER) 0.80506993006993
#  epoch 7: 18m 5s loss:0.1951 accuracy POS:0.9667 accuracy NER:0.96829epoch: 7
# F1 (POS): 0.9567233384853169 F1 (NER) 0.8067350262656848
#  epoch 8: 20m 22s loss:0.2447 accuracy POS:0.9690 accuracy NER:0.9354epoch: 8
# F1 (POS): 0.9568763676985936 F1 (NER) 0.8067759261809667
#  epoch 9: 22m 38s loss:0.1805 accuracy POS:0.9719 accuracy NER:0.9726epoch: 9
# F1 (POS): 0.9569758366872236 F1 (NER) 0.807632398753894
#  epoch 10: 24m 55s loss:0.2322 accuracy POS:0.9700 accuracy NER:0.9495epoch: 10
# F1 (POS): 0.9566850811819977 F1 (NER) 0.8056470803587772
#  epoch 11: 27m 11s loss:0.1702 accuracy POS:0.9682 accuracy NER:0.9778epoch: 11
# F1 (POS): 0.9565014461260655 F1 (NER) 0.8051002655434484
#  epoch 12: 29m 28s loss:0.2244 accuracy POS:0.9690 accuracy NER:0.9540epoch: 12
# F1 (POS): 0.9561341760142011 F1 (NER) 0.8051472271832212
#  epoch 13: 31m 45s loss:0.1559 accuracy POS:0.9697 accuracy NER:0.9822epoch: 13
# F1 (POS): 0.9561647818568566 F1 (NER) 0.8055460066460409
#  epoch 14: 34m 2s loss:0.2156 accuracy POS:0.9700 accuracy NER:0.96274epoch: 14
# F1 (POS): 0.9559275865762774 F1 (NER) 0.8053703534569367
#  epoch 15: 36m 18s loss:0.1433 accuracy POS:0.9748 accuracy NER:0.9852epoch: 15
# F1 (POS): 0.9556750883743707 F1 (NER) 0.8027073996158419
#  epoch 16: 38m 35s loss:0.2121 accuracy POS:0.9704 accuracy NER:0.9650epoch: 16
# F1 (POS): 0.9558740263516305 F1 (NER) 0.803714859437751
#  epoch 17: 40m 52s loss:0.1343 accuracy POS:0.9763 accuracy NER:0.9859epoch: 17
# F1 (POS): 0.9554838018577746 F1 (NER) 0.802340999497051
#  epoch 18: 43m 8s loss:0.2074 accuracy POS:0.9709 accuracy NER:0.96541epoch: 18
# F1 (POS): 0.9554838018577746 F1 (NER) 0.8024770348704356
#  epoch 19: 45m 25s loss:0.1207 accuracy POS:0.9763 accuracy NER:0.9874epoch: 19
# F1 (POS): 0.9552925153411786 F1 (NER) 0.800246637283336
#  epoch 20: 47m 41s loss:0.2069 accuracy POS:0.9727 accuracy NER:0.9695epoch: 20
# F1 (POS): 0.954940548150642 F1 (NER) 0.7998543236291624
#  epoch 21: 49m 58s loss:0.1124 accuracy POS:0.9807 accuracy NER:0.9889epoch: 21
# F1 (POS): 0.954841079162012 F1 (NER) 0.7981991041228631
#  epoch 22: 52m 15s loss:0.2067 accuracy POS:0.9704 accuracy NER:0.9677epoch: 22
# F1 (POS): 0.9546191868027607 F1 (NER) 0.795833713191722
#  epoch 23: 54m 32s loss:0.1222 accuracy POS:0.9756 accuracy NER:0.9867epoch: 23
# F1 (POS): 0.9548334277013482 F1 (NER) 0.7950888883817523
#  epoch 24: 56m 48s loss:0.2057 accuracy POS:0.9740 accuracy NER:0.9709epoch: 24
# F1 (POS): 0.9547492616340459 F1 (NER) 0.793897655751163
#  epoch 25: 59m 5s loss:0.1084 accuracy POS:0.9837 accuracy NER:0.99110epoch: 25
# F1 (POS): 0.9544432032074923 F1 (NER) 0.7949485030487108
#  epoch 26: 61m 21s loss:0.2090 accuracy POS:0.9686 accuracy NER:0.9686epoch: 26
# F1 (POS): 0.9544738090501477 F1 (NER) 0.792580791989076
#  epoch 27: 63m 38s loss:0.1013 accuracy POS:0.9837 accuracy NER:0.9874epoch: 27
# F1 (POS): 0.9545579751174499 F1 (NER) 0.7920431526959055
#  epoch 28: 65m 55s loss:0.1920 accuracy POS:0.9704 accuracy NER:0.9713epoch: 28
# F1 (POS): 0.9537316173657551 F1 (NER) 0.7942919668095194
#  epoch 29: 68m 12s loss:0.0962 accuracy POS:0.9793 accuracy NER:0.9903epoch: 29
# F1 (POS): 0.9536474512984529 F1 (NER) 0.7894459827456005
#  epoch 30: 70m 29s loss:0.1781 accuracy POS:0.9731 accuracy NER:0.9754epoch: 30
# F1 (POS): 0.9535632852311506 F1 (NER) 0.79328364991366
#  epoch 31: 72m 45s loss:0.0943 accuracy POS:0.9822 accuracy NER:0.9896epoch: 31
# F1 (POS): 0.9535938910738061 F1 (NER) 0.7902206049579259
#  epoch 32: 75m 2s loss:0.1793 accuracy POS:0.9718 accuracy NER:0.97189epoch: 32
# F1 (POS): 0.9532648782652609 F1 (NER) 0.789400406272111
#  epoch 33: 77m 19s loss:0.0968 accuracy POS:0.9807 accuracy NER:0.9903epoch: 33
# F1 (POS): 0.9531960151192863 F1 (NER) 0.7890621448379324
#  epoch 34: 79m 36s loss:0.1804 accuracy POS:0.9731 accuracy NER:0.9754epoch: 34
# F1 (POS): 0.9534714677031846 F1 (NER) 0.7876419643061174
#  epoch 35: 81m 52s loss:0.1049 accuracy POS:0.9822 accuracy NER:0.9903epoch: 35
# F1 (POS): 0.9533873016358821 F1 (NER) 0.7871763929051208
#  epoch 36: 84m 9s loss:0.1713 accuracy POS:0.9704 accuracy NER:0.97543epoch: 36
# F1 (POS): 0.9529511683780434 F1 (NER) 0.7875065640768054
#  epoch 37: 86m 26s loss:0.0941 accuracy POS:0.9793 accuracy NER:0.9940epoch: 37
# F1 (POS): 0.9524461719742299 F1 (NER) 0.7878829290513607
#  epoch 38: 88m 42s loss:0.1745 accuracy POS:0.9745 accuracy NER:0.9759epoch: 38
# F1 (POS): 0.952862996246944 F1 (NER) 0.789040720259586
#  epoch 39: 90m 58s loss:0.0950 accuracy POS:0.9822 accuracy NER:0.9948epoch: 39
# F1 (POS): 0.9528287450074219 F1 (NER) 0.7889276491641372
