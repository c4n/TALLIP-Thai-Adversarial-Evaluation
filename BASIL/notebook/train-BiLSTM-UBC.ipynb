# %%
# %load_ext autoreload
# %autoreload 2
import torch
import math
from pathlib import Path
import os
os.chdir("/home/datamind/can/BASIL/")
mypath = Path().absolute()
print(mypath)
from basil.select_device import device
# Out:
# /home/datamind/can/BASIL

# %%
torch.device(device)
# Out:
# device(type='cuda', index=3)

# %%
from pathlib import Path
import os
os.chdir("/home/datamind/can/BASIL/")
mypath = Path().absolute()
print(mypath)
# Out:
# /home/datamind/can/BASIL

# %%
affixes = r"^การ|^ความ|^นัก|^ผู้|^ไอ้|กร$|^ที่\w+|^อย่าง|^แบบ|^โดย|^น่า"

# %%
import sys
sys.path.append("/home/datamind/can/BASIL/")

# %%
import basil

# %%
from basil.select_device import device

# %%
# %autoreload 2
from basil.preprocessing.prep_best_corpus import Best2010NECTEC, BestSyllable2010NECTEC
from basil.preprocessing.prep_pytorch_syllable import PytorchPrepWordLevelWithSyllable
from basil.models.multitasks.BILSTM_UBC import LSTMTagger
from basil.training.train_BILSTM_U_BC import TrainModel
# Out:
# /home/datamind/can/BASIL/basil/preprocessing/prep_best_corpus.py:9: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   cfg = yaml.load(ymlfile)

# %%
best2010  = Best2010NECTEC()
# Out:
# Preprocessing BEST2010 corpus
# Done!

# %%
best2010.train_data[0]
# Out:
# [['นุ้ย', 'NR', 'PER_B'],
#  ['EFM', 'FWN', 'ORG_B'],
#  ['งง', 'VV', 'O'],
#  ['หยาด', 'NR', 'PER_B'],
#  [' ', 'space', 'space'],
#  ['ขู่', 'VV', 'O'],
#  ['ฟ้อง', 'VV', 'O'],
#  ['ยัน', 'VV', 'O'],
#  ['ไม่', 'NEG', 'O'],
#  ['เจตนา', 'VV', 'O'],
#  ['พาดพิง', 'VV', 'O'],
#  [' ', 'space', 'space'],
#  ["'", 'PU', 'O'],
#  ['นุ้ย', 'NR', 'PER_B'],
#  [' ', 'space', 'space'],
#  ['EFM', 'FWN', 'ORG_B'],
#  ["'", 'PU', 'O'],
#  [' ', 'space', 'space'],
#  ['งง', 'VV', 'O'],
#  [' ', 'space', 'space'],
#  ["'", 'PU', 'O'],
#  ['หยาด', 'NR', 'PER_B'],
#  ["'", 'PU', 'O'],
#  [' ', 'space', 'space'],
#  ['ขู่', 'VV', 'O'],
#  ['ฟ้อง', 'VV', 'O'],
#  [' ', 'space', 'space'],
#  ['ยัน', 'VV', 'O'],
#  ['ไม่', 'NEG', 'O'],
#  ['เจตนา', 'VV', 'O'],
#  ['พาดพิง', 'VV', 'O'],
#  ['ใคร', 'PDEM', 'O'],
#  [' ', 'space', 'space'],
#  ['แจง', 'VV', 'O'],
#  ['หัวเราะ', 'VV', 'O'],
#  ['เปล่า', 'NN', 'O'],
#  ['เยาะเย้ย', 'NN', 'O'],
#  [' ', 'space', 'space'],
#  ['แค่', 'PDT', 'O'],
# ...

# %%
trainer = TrainModel(LSTMTagger, best2010,1)
trainer.train(40)
# Out:
# Training
# Num of training text file: 4975
#  epoch 0: 46m 1s loss:0.6523 accuracy POS:0.8895 accuracy NER:0.90598epoch: 0
# F1 (POS): 0.9437617641207706 F1 (NER) 0.7576009610941689
#  epoch 1: 92m 43s loss:0.4501 accuracy POS:0.9106 accuracy NER:0.9446epoch: 1
# F1 (POS): 0.9527981391647665 F1 (NER) 0.7867532705150488
#  epoch 2: 138m 1s loss:0.5360 accuracy POS:0.8927 accuracy NER:0.91403epoch: 2
# F1 (POS): 0.9553154697231702 F1 (NER) 0.7999908126234554
#  epoch 3: 182m 41s loss:0.4057 accuracy POS:0.9143 accuracy NER:0.9527epoch: 3
# F1 (POS): 0.9572895465744411 F1 (NER) 0.805356486585814
#  epoch 4: 227m 27s loss:0.4490 accuracy POS:0.9122 accuracy NER:0.9404epoch: 4
# F1 (POS): 0.9577180283716162 F1 (NER) 0.8059770326984274
#  epoch 5: 272m 24s loss:0.3493 accuracy POS:0.9231 accuracy NER:0.9593epoch: 5
# F1 (POS): 0.9583301452247234 F1 (NER) 0.8122246821719581
#  epoch 6: 317m 28s loss:0.4311 accuracy POS:0.9104 accuracy NER:0.9395epoch: 6
# ...

# %%
# trainer = TrainModel(LSTMTagger, best2010,3)
# trainer.train(40)
# Out:
# Training
# Num of training text file: 4975
#  epoch 0: 44m 30s loss:0.7296 accuracy POS:0.8740 accuracy NER:0.9004epoch: 0
# F1 (POS): 0.9443432751312225 F1 (NER) 0.7520811714516316
#  epoch 1: 89m 0s loss:0.4347 accuracy POS:0.9165 accuracy NER:0.94908epoch: 1
# F1 (POS): 0.953065940288001 F1 (NER) 0.7834856019428704
#  epoch 2: 133m 57s loss:0.5320 accuracy POS:0.9013 accuracy NER:0.9204epoch: 2
# F1 (POS): 0.9551088802852464 F1 (NER) 0.7969594285190952
#  epoch 3: 178m 46s loss:0.4388 accuracy POS:0.9069 accuracy NER:0.9468epoch: 3
# F1 (POS): 0.9574425757877179 F1 (NER) 0.8026526412074092
#  epoch 4: 223m 41s loss:0.5031 accuracy POS:0.9040 accuracy NER:0.9209epoch: 4
# F1 (POS): 0.9580393897194974 F1 (NER) 0.8087351470385833
#  epoch 5: 268m 34s loss:0.3992 accuracy POS:0.9143 accuracy NER:0.9542epoch: 5
# F1 (POS): 0.9589499135384945 F1 (NER) 0.8078267267543456
#  epoch 6: 313m 32s loss:0.4903 accuracy POS:0.9045 accuracy NER:0.9222epoch: 6
# ...

# %%
# trainer = TrainModel(LSTMTagger, best2010,4)
# trainer.train(40)

# %%
# trainer = TrainModel(LSTMTagger, best2010,5)
# trainer.train(40)

# %%
filehandle = open('done_bilstm_ubc.txt', 'w')
filehandle.write('seed1\n')
filehandle.close()
